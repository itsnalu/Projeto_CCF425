# %% [markdown]
# <a href="https://colab.research.google.com/github/itsnalu/Projeto_CCF425/blob/Entrega2/Projeto_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatório de Análise e Documentação do Código do Projeto SPSafe

# %% [markdown]
# ---
# Integrantes do grupo:
# - | 5389 | Ana Luísa Moreira Rodrigues
# - | 5377 | Lucas da Costa Moreira
# - | 5373 | Aléxia Karoline Augusta
# - | 5798 | Daniel Martins de Abreu
#
# Projeto desenvolvido para a análise dos dados de criminalidade de São Paulo (SPSafe).
#
# ---

# %% [markdown]
# # Importação de Bibliotecas e Montagem do Ambiente

# %% [markdown]
# No início do código, são importadas as bibliotecas essenciais para a manipulação dos dados:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Além disso, o código utiliza o módulo `drive` do Google Colab para montar o Google Drive e acessar o arquivo CSV com os dados.

# %%
from google.colab import drive
drive.mount('/content/drive')
df= pd.read_csv("/content/drive/MyDrive/SPSafe_2022.csv", delimiter=";")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-75-dfd12d9c4b81>:3: DtypeWarning: Columns (10,11,16,17,19,20,21,22,24,25,26,27,28,29,30,31,32,35,36,38,39,41,42,43,44,45,46,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("/content/drive/MyDrive/SPSafe_2022.csv", delimiter=";")

# %% [markdown]
# Foi feita uma análise de quais colunas e seus tipos de dados estão presentes no arquivo importado (aumentar essa descrição)

# %%
# Tipos de dados de cada coluna do dataframe
df.dtypes
# Out:
# NUM_BO                        float64
# ANO_BO                          int64
# CODIGO_BOLETIM                 object
# NATUREZA_APURADA               object
# DATA_OCORRENCIA                object
# HORA_OCORRENCIA                object
# PERIODO_OCORRENCIA             object
# CIDADE                        float64
# LOGRADOURO                     object
# NUMERO_LOGRADOURO             float64
# BAIRRO                         object
# UF                             object
# TIPO_LOCAL                     object
# LATITUDE                      float64
# LONGITUDE                     float64
# DELEGACIA_ELABORACAO           object
# DEPARTAMENTO_ELABORACAO        object
# SECCIONAL_ELABORACAO           object
# DELEGACIA_CIRCUNSCRICAO        object
# DEPARTAMENTO_CIRCUNSCRICAO     object
# SECCIONAL_CIRCUNSCRICAO        object
# TIPO_PESSOA                    object
# SEXO_PESSOA                    object
# IDADE_PESSOA                  float64
# DATA_NASCIMENTO_PESSOA         object
# COR_PELE                       object
# PROFISSAO                      object
# PLACA_VEICULO                  object
# UF_VEICULO                     object
# CIDADE_VEICULO                 object
# COR_VEICULO                    object
# MARCA_VEICULO                  object
# MODELO_VEICULO                 object
# ANO_FABRICACAO                float64
# ANO_MODELO                    float64
# TIPO_VEICULO                   object
# MARCA_CELULAR                  object
# QUANT_CELULAR                 float64
# BO_INICIADO                    object
# BO_EMITIDO                     object
# DATA_HORA_ELABORACAO           object
# DATA_COMUNICACAO               object
# BO_AUTORIA                     object
# FLAGRANTE                      object
# EXAME                          object
# SOLUCAO                        object
# ESPECIE                        object
# STATUS                         object
# FLAG_VITIMA_FATAL              object
# DESDOBRAMENTO                  object
# dtype: object

# %%
pd.set_option('display.max_colwidth', None) #definir a opção para mostrar todo o conteúdo das células
pd.set_option('display.max_rows', None) #definir a opção para mostrar todas as linhas
pd.set_option('display.max_columns', None)  # Exibir todas as colunas do DataFrame
df.head(4)
# Out:
#    NUM_BO  ANO_BO CODIGO_BOLETIM  NATUREZA_APURADA      DATA_OCORRENCIA  \
# 0    21.0    2022        21/2022  HOMICIDIO DOLOSO  2021-12-31 00:00:00
# 1   312.0    2022       312/2022  HOMICIDIO DOLOSO  2022-01-20 00:00:00
# 2   253.0    2022       253/2022  HOMICIDIO DOLOSO  2022-01-16 00:00:00
# 3   305.0    2022       305/2022  HOMICIDIO DOLOSO  2022-01-22 00:00:00
#
#   HORA_OCORRENCIA PERIODO_OCORRENCIA  CIDADE  \
# 0        15:40:00            A TARDE     NaN
# 1        07:00:00         PELA MANHA     NaN
# 2        05:48:00       DE MADRUGADA     NaN
# 3        19:50:00                NaN     NaN
#
#                                      LOGRADOURO  NUMERO_LOGRADOURO BAIRRO  \
# 0  DA VEDACAO DA DIVULGACAO DOS DADOS RELATIVOS                NaN    NaN
# 1                             PRACA DA BANDEIRA               10.0    NaN
# 2                                    RUA PRATES              536.0    NaN
# 3                                   RUA GUARANI              427.0    NaN
#
#     UF   TIPO_LOCAL   LATITUDE  LONGITUDE     DELEGACIA_ELABORACAO  \
# 0  NaN   RESIDENCIA        NaN        NaN  DEL.POL.PLANTAO BIRIGUI
# 1  NaN  VIA PUBLICA -23.550235 -46.639255            08º D.P. BRAS
# 2  NaN  VIA PUBLICA -23.525989 -46.634852      02º D.P. BOM RETIRO
# 3  NaN  VIA PUBLICA -23.528916 -46.633914      02º D.P. BOM RETIRO
#
#   DEPARTAMENTO_ELABORACAO SECCIONAL_ELABORACAO DELEGACIA_CIRCUNSCRICAO  \
# 0  DEINTER 10 - ARACATUBA    DEL.SEC.ARACATUBA            DM - BIRIGUI
# 1                   DECAP    DEL.SEC.1º CENTRO             001 DP - SE
# 2                   DECAP    DEL.SEC.1º CENTRO     002 DP - BOM RETIRO
# 3                   DECAP    DEL.SEC.1º CENTRO     002 DP - BOM RETIRO
#
#   DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO TIPO_PESSOA SEXO_PESSOA  \
# 0                 DEINTER 10           SEC ARACATUBA      VITIMA    FEMININO
# 1                      DECAP                  1ª SEC      VITIMA   MASCULINO
# 2                      DECAP                  1ª SEC      VITIMA   MASCULINO
# 3                      DECAP                  1ª SEC      VITIMA   MASCULINO
#
#    IDADE_PESSOA DATA_NASCIMENTO_PESSOA COR_PELE     PROFISSAO PLACA_VEICULO  \
# 0          55.0             1966-08-15    PARDA           NaN           NaN
# 1          34.0             1987-02-15    PARDA  DESEMPREGADO           NaN
# 2          21.0             2000-06-10    PARDA           NaN           NaN
# 3          48.0             1974-01-06    PARDA   AUTONOMO(A)           NaN
#
#   UF_VEICULO CIDADE_VEICULO COR_VEICULO MARCA_VEICULO MODELO_VEICULO  \
# 0        NaN            NaN         NaN           NaN            NaN
# 1        NaN            NaN         NaN           NaN            NaN
# 2        NaN            NaN         NaN           NaN            NaN
# 3        NaN            NaN         NaN           NaN            NaN
#
#    ANO_FABRICACAO  ANO_MODELO TIPO_VEICULO MARCA_CELULAR  QUANT_CELULAR  \
# 0             NaN         NaN          NaN           NaN            NaN
# 1             NaN         NaN          NaN           NaN            NaN
# 2             NaN         NaN          NaN           NaN            NaN
# 3             NaN         NaN          NaN           NaN            NaN
#
#   BO_INICIADO BO_EMITIDO DATA_HORA_ELABORACAO DATA_COMUNICACAO BO_AUTORIA  \
# 0         NaN        NaN  2021-12-31 00:00:00              NaN        NaN
# 1         NaN        NaN  2022-01-20 09:45:00              NaN        NaN
# 2         NaN        NaN  2022-01-16 00:00:00              NaN        NaN
# 3         NaN        NaN  2022-01-22 00:00:00              NaN        NaN
#
#   FLAGRANTE EXAME SOLUCAO ESPECIE STATUS FLAG_VITIMA_FATAL DESDOBRAMENTO
# 0       NaN   NaN     NaN     NaN    NaN               NaN           NaN
# 1       NaN   NaN     NaN     NaN    NaN               NaN           NaN
# 2       NaN   NaN     NaN     NaN    NaN               NaN           NaN
# 3       NaN   NaN     NaN     NaN    NaN               NaN           NaN

# %% [markdown]
# # Significado e valores de cada coluna

# %% [markdown]
# Antes de tratar os dados, é necessário compreender o significado de cada uma das colunas do dataset original; especialmente aquelas que representam algum tipo de categoria ou classificação. Seguem breves explicações para cada uma das colunas, em ordem:

# %% [markdown]
# ### Dados gerais do boletim de ocorrência
#
# * **NUM BO**: Número do boletim de ocorrência
# * **ANO BO**: Ano do boletim de ocorrência
# * **CODIGO BOLETIM**: Junção do número de boletim com o ano do boletim separados por ‘/’
# * **NATUREZA APURADA**: Tipo de crime cometido
# * **DATA OCORRENCIA**: Data em que o crime ocorreu
# * **HORA OCORRENCIA**: Hora em que o crime ocorreu
# * **PERIODO OCORRENCIA**: Período do dia em que o crime ocorreu
# * **CIDADE**: Código da cidade em que o crime ocorreu, no formato IBGE
# * **LOGRADOURO**: Via em que o crime ocorreu
# * **NUMERO LOGRADOURO**: Número que identifica em uma via o local do crime
# * **BAIRRO**: Bairro em que o crime ocorreu
# * **UF**: Sigla da unidade federativa em que o crime ocorreu
# * **TIPO LOCAL**: Tipo de local em que o crime ocorreu
# * **LATITUDE**: Latitude do ponto em que o crime ocorreu
# * **LONGITUDE**: Longitude do ponto em que o crime ocorreu
# * **DELEGACIA ELABORACAO**: Delegacia em que o boletim de ocorrência foi elaborado
# * **DEPARTAMENTO ELABORACAO**: Departamento em que o boletim de ocorrência foi elaborado
# * **SECCIONAL ELABORACAO**: Seccional em que o boletim de ocorrência foi elaborado
# * **DELEGACIA CIRCUNSCRICAO**: Delegacia de circunscrição
# * **DEPARTAMENTO CIRCUNSCRICAO**: Departamento de circunscrição
# * **SECCIONAL CIRCUNSCRICAO**: Seccional de circunscrição
#
# ### Dados sobre a pessoa envolvida na ocorrência
#
# * **TIPO PESSOA**: Indica se a pessoa é a vítima ou autora do crime
# * **SEXO PESSOA**: Gênero
# * **IDADE PESSOA**: Idade
# * **DATA NASCIMENTO PESSOA**: Data de nascimento
# * **COR PELE**: Cor de pele
# * **PROFISSAO**: Profissão
#
# ### Dados sobre o veículo envolvido na ocorrência
#
# * **PLACA VEICULO**: Placa do veículo
# * **UF VEICULO**: Unidade federativa do emplacamento
# * **CIDADE VEICULO**: Cidade do emplacamento
# * **COR VEICULO**: Cor do veículo
# * **MARCA VEICULO**: Marca do veículo
# * **MODELO VEICULO**: Modelo do veículo
# * **ANO FABRICACAO**: Ano de fabricação do veículo
# * **ANO MODELO**: Ano do modelo do veículo
# * **TIPO VEICULO**: Tipo de veículo envolvido
#
# ### Dados sobre o telefone celular envolvido na ocorrência
#
# * **MARCA CELULAR**: Marca do celular
# * **QUANT CELULAR**: Quantidade de celulares
#
# ### Outras informações sobre o boletim de ocorrência
#
# * **BO INICIADO**: Data e hora em que o BO foi iniciado
# * **BO EMITIDO**: Data e hora em que o BO foi concluído
# * **DATA HORA ELABORACAO**: Data e hora de elaboração do BO
# * **DATA COMUNICACAO**: Data em que o BO foi comunicado à delegacia
# * **BO AUTORIA**: Responsável pela realização do BO
# * **FLAGRANTE**: Indica se se trata de uma situação de flagrante
# * **EXAME**: Responsável pelo exame de corpo
# * **SOLUCAO**: Tipo de solução dada ao crime
# * **ESPECIE**: Espécie de patrimônio envolvido no crime
# * **STATUS**: Status do crime
# * **FLAG VITIMA FATAL**: Indica se houve fatalidades
# * **DESDOBRAMENTO**: Desdobramento do caso

# %% [markdown]
# #  Ajustes e Conversões de Dados

# %% [markdown]
# Esta seção trata das transformações necessárias para garantir que os dados estejam no formato adequado para análise.

# %% [markdown]
# ## Tratamento de Valores Nulos e Conversão de Tipos

# %% [markdown]
# ### Tratamento do NUM_BO

# %% [markdown]
# Foi feita o preenchimento de registros onde o campo **NUM_BO** é nulo com base no **CODIGO_BOLETIM**, pois eram valores que estavam preenchidos e o grupo notou que o seu padrão era: "número do BO/ ano do BO", apenas foi necessário remover algumas letras em frente ao número.

# %%
# Mostra os dados com o número de BO nulo
df[df['NUM_BO'].isna()]
# Out:
#       NUM_BO  ANO_BO CODIGO_BOLETIM  NATUREZA_APURADA      DATA_OCORRENCIA  \
# 250      NaN    2022    AM2107/2022  HOMICIDIO DOLOSO  2022-02-28 00:00:00
# 869      NaN    2022    BF3900/2022  HOMICIDIO DOLOSO  2022-04-25 00:00:00
# 2752     NaN    2022    LH5061/2022  HOMICIDIO DOLOSO  2022-12-28 00:00:00
#
#      HORA_OCORRENCIA PERIODO_OCORRENCIA  CIDADE  \
# 250         02:20:00       DE MADRUGADA     NaN
# 869         02:30:00       DE MADRUGADA     NaN
# 2752             NaN    EM HORA INCERTA     NaN
#
#                                         LOGRADOURO  NUMERO_LOGRADOURO BAIRRO  \
# 250                          RUA CARDEAL ARCOVERDE              950.0    NaN
# 869                                 RODOVIA SP 425              373.0    NaN
# 2752  DA VEDACAO DA DIVULGACAO DOS DADOS RELATIVOS                NaN    NaN
#
#        UF       TIPO_LOCAL  LATITUDE  LONGITUDE    DELEGACIA_ELABORACAO  \
# 250   NaN   TEMPLO E AFINS       NaN        NaN  CORREGEDORIA - PLANTAO
# 869   NaN  RODOVIA/ESTRADA       NaN        NaN         DEL.POL.PARAPUA
# 2752  NaN       RESIDENCIA       NaN        NaN  CORREGEDORIA - PLANTAO
#
#          DEPARTAMENTO_ELABORACAO                   SECCIONAL_ELABORACAO  \
# 250   CORREGEDORIA POLICIA CIVIL  DIVISAO CORREGEDORIA DA POLICIA CIVIL
# 869            DEINTER 4 - BAURU                           DEL.SEC.TUPA
# 2752  CORREGEDORIA POLICIA CIVIL  DIVISAO CORREGEDORIA DA POLICIA CIVIL
#
#      DELEGACIA_CIRCUNSCRICAO DEPARTAMENTO_CIRCUNSCRICAO  \
# 250       014 DP - PINHEIROS                      DECAP
# 869             DM - PARAPUA                  DEINTER 4
# 2752     034 DP - VILA SONIA                      DECAP
#
#      SECCIONAL_CIRCUNSCRICAO TIPO_PESSOA SEXO_PESSOA  IDADE_PESSOA  \
# 250                   3ª SEC      VITIMA   MASCULINO          20.0
# 869                 SEC TUPA      VITIMA   MASCULINO          51.0
# 2752                  3ª SEC      VITIMA    FEMININO          44.0
#
#      DATA_NASCIMENTO_PESSOA COR_PELE      PROFISSAO PLACA_VEICULO UF_VEICULO  \
# 250              1987-01-23   BRANCA  DESOCUPADO(A)           NaN        NaN
# 869              1971-05-11   BRANCA            NaN           NaN        NaN
# 2752             1978-05-10   BRANCA  NUTRICIONISTA           NaN        NaN
#
#      CIDADE_VEICULO COR_VEICULO MARCA_VEICULO MODELO_VEICULO  ANO_FABRICACAO  \
# 250             NaN         NaN           NaN            NaN             NaN
# 869             NaN         NaN           NaN            NaN             NaN
# 2752            NaN         NaN           NaN            NaN             NaN
#
#       ANO_MODELO TIPO_VEICULO MARCA_CELULAR  QUANT_CELULAR BO_INICIADO  \
# 250          NaN          NaN           NaN            NaN         NaN
# 869          NaN          NaN           NaN            NaN         NaN
# 2752         NaN          NaN           NaN            NaN         NaN
#
#      BO_EMITIDO DATA_HORA_ELABORACAO DATA_COMUNICACAO BO_AUTORIA FLAGRANTE  \
# 250         NaN  2022-02-28 00:00:00              NaN        NaN       NaN
# 869         NaN  2022-04-25 00:00:00              NaN        NaN       NaN
# 2752        NaN  2022-12-29 00:00:00              NaN        NaN       NaN
#
#      EXAME SOLUCAO ESPECIE STATUS FLAG_VITIMA_FATAL DESDOBRAMENTO
# 250    NaN     NaN     NaN    NaN               NaN           NaN
# 869    NaN     NaN     NaN    NaN               NaN           NaN
# 2752   NaN     NaN     NaN    NaN               NaN           NaN

# %%
# Extrai apenas o número antes da barra
df['NUM_BO'] = df['NUM_BO'].fillna(
    df['CODIGO_BOLETIM'].str.extract(r'\D*(\d+)/\d{4}')[0].astype(float)
)

# %%
# Converte a coluna NUM_BO para inteiro
df['NUM_BO'] = df['NUM_BO'].astype('int')

# %% [markdown]
# ### Conversão de datas

# %% [markdown]
# O código utiliza `pd.to_datetime` para converter as colunas de data, devido as funções do próprio python que vão lidar melhor com esse tipo.

# %%
# Converte para datetime e transforma os valores nulos em NaT (Not a Time)
df['DATA_OCORRENCIA'] = pd.to_datetime(df['DATA_OCORRENCIA'], errors='coerce')
df['DATA_NASCIMENTO_PESSOA'] = pd.to_datetime(df['DATA_NASCIMENTO_PESSOA'], errors='coerce')
df['DATA_HORA_ELABORACAO'] = pd.to_datetime(df['DATA_HORA_ELABORACAO'], errors='coerce')
df['DATA_COMUNICACAO'] = pd.to_datetime(df['DATA_COMUNICACAO'], errors='coerce')

# %% [markdown]
# ### Tratamento de Códigos de Cidade e Integração com Dados do IBGE

# %% [markdown]
# ### Conversão de cidade e remoção de dados

# %% [markdown]
# O grupo percebeu que durante a leitura dos dados, a coluna `CIDADE` não continha o nome das cidades como mencionado no artigo e sim os códigos do [IBGE](https://www.ibge.gov.br/explica/codigos-dos-municipios.php) referentes as essas cidades. Dessa maneira, decidimos analisar se todos eles eram no estado de São Paulo.

# %% [markdown]
# A primeira divergência com poucas linhas atrbuídas foi uma cidade do Paraná, e por ter poucos dados atrelados a ela foi teve todas as suas linhas removidas.

# %%
# Remove cidade com o código do IBGE "4123824.0" que não se refere a São Paulo e possui poucos dados
df.drop(df[df['CIDADE'] == 4123824.0].index, inplace=True)

# %% [markdown]
# A segunda divergência foi um valor que não dizia respeito a nenhuma cidade, portanto os dados com a coluna `CIDADE` com o valor "-1.0" também foram removidos do dataset.

# %%
# Remove cidade com o código do IBGE "-1.0" que não se refere a São Paulo
df.drop(df[df['CIDADE'] == -1.0].index, inplace=True)

# %% [markdown]
# Notamos que existem 21.807 dados com o código do IBGE de uma cidade chamada "Santo André" na Paraíba. No entanto, também existe uma cidade chamada "Santo André" em São Paulo. Dessa forma, os 17 logradouros com o maior número de dados foram pesquisados manualmente com a intenção de verificar se pertencem a esse município em São Paulo e todos corresponderam.
#
# | LOGRADOUROS PESQUISADOS                     | Quantidade |
# |---------------------------------------------|------------|
# | AVENIDA DOS ESTADOS                         | 570        |
# | RUA ITAMBE                                  | 305        |
# | AVENIDA INDUSTRIAL                          | 269        |
# | RUA ORATORIO                                | 228        |
# | AVENIDA DOM PEDRO I                         | 192        |
# | AVENIDA DOM PEDRO II                        | 157        |
# | AVENIDA CAPITAO MARIO TOLEDO DE CAMARGO     | 144        |
# | ESTRADA DO PEDROSO                          | 141        |
# | AVENIDA ITAMARATI                           | 132        |
# | RUA CARIJOS                                 | 130        |
# | RUA GENERAL GLICERIO                        | 124        |
# | ESTRADA CATA PRETA                          | 117        |
# | AVENIDA PEREIRA BARRETO                     | 114        |
# | AVENIDA QUEIROS FILHO                       | 107        |
# | AVENIDA QUEIROS DOS SANTOS                  | 103        |
# | AVENIDA VALENTIM MAGALHAES                  | 100        |
# | RUA CORONEL OLIVEIRA LIMA                   | 98         |
#
#  Logo, a coluna referente a cidade de Paraíba (2513851) será alterada para o código do IBGE referente a cidade de São Paulo (3547809).

# %%
# Alterando a coluna 'CIDADE' de 2513851.0 para 3547809.0
df.loc[df["CIDADE"] == 2513851.0, "CIDADE"] = '3547809.0'
# Out:
# <ipython-input-84-5ca468cee51f>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '3547809.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df["CIDADE"] == 2513851.0, "CIDADE"] = '3547809.0'

# %% [markdown]
# ### Conversão do código da cidade para cidade no IBGE

# %% [markdown]
# Foi feita a integração com um dataset externo com dados do IBGE permite que os códigos sejam convertidos em nomes, facilitando a interpretação das colunas `CIDADE` e `CIDADE_VEICULO`.  Durante essa conversão, nota-se que a coluna `CIDADE_VEICULO` possui dados que não se limitam ao município de São Paulo, mas pertencem também a outros estados.

# %% [markdown]
# Importaremos a biblioteca cKDTree para podermos fazer uma busca mais rapida

# %%
from scipy.spatial import cKDTree

# %%
#Converter de float para string
df['CIDADE'] = df['CIDADE'].astype('string')
df['CIDADE_VEICULO'] = df['CIDADE_VEICULO'].astype('string')

#Altera os valores nulos em CIDADE por "DESCONHECIDO"
df['CIDADE'] = df['CIDADE'].fillna('DESCONHECIDO')
df['CIDADE_VEICULO'] = df['CIDADE_VEICULO'].fillna('DESCONHECIDO')

# %% [markdown]
# Podemos tentar adicionar cidades por meio da latitude e longitude já que temos varias cidade com valores desconhecido

# %%
# Vamos identificar as linhas onde CIDADE é nula ou 'DESCONHECIDO' e onde existem valores válidos em LATITUDE e LONGITUDE
cidades_nulas = df['CIDADE'].isna() | (df['CIDADE'] == 'DESCONHECIDO')
lat_long_validos = df['LATITUDE'].notna() & df['LONGITUDE'].notna()
cidades_lat_long = cidades_nulas & lat_long_validos

# %%
#Carregar o dataframe do IBGE com os dados dos municípios
url = "https://raw.githubusercontent.com/kelvins/municipios-brasileiros/refs/heads/main/csv/municipios.csv"
df_ibge = pd.read_csv(url, delimiter=",", low_memory=False)

# %%
# Coordenadas do IBGE
ibge_coords = df_ibge[['latitude', 'longitude']].values
tree = cKDTree(ibge_coords)

# %% [markdown]
# Podemos verificar que temos essa quantidade de CIDADES que estão como desconhecido

# %%
cidades_desconhecidas = (df['CIDADE'] == 'DESCONHECIDO').sum()
print(f'Cidades desconhecidas atualmente: {cidades_desconhecidas}')
# Out:
# Cidades desconhecidas atualmente: 695437

# %%
# Coordenadas das linhas com cidade desconhecida
coords_para_busca = df.loc[cidades_lat_long, ['LATITUDE', 'LONGITUDE']].values

# %%
# Busca da cidade mais próxima com KDTree
distancias, indices_mais_proximos = tree.query(coords_para_busca)

# %%
# Códigos IBGE correspondentes às coordenadas encontradas
codigos_ibge_encontrados = df_ibge.iloc[indices_mais_proximos]['codigo_ibge'].astype(str).values

# %%
# Preencher a coluna CIDADE com os códigos encontrados
df.loc[cidades_lat_long, 'CIDADE'] = codigos_ibge_encontrados

# %%
# Mostrar quantas ainda continuam como 'DESCONHECIDO'
cidades_desconhecidas = (df['CIDADE'] == 'DESCONHECIDO').sum()
print(f'Cidades desconhecidas após preenchimento por coordenada: {cidades_desconhecidas}')
# Out:
# Cidades desconhecidas após preenchimento por coordenada: 111365

# %% [markdown]
# Tambem faremos o oposto uma vez que pode ser util para frente

# %%
# Identifica as linhas onde LATITUDE ou LONGITUDE são nulas, mas onde há um código IBGE válido na coluna CIDADE
lat_long_nulos = df['LATITUDE'].isna() | df['LONGITUDE'].isna()
cidade_validas = df['CIDADE'].notna() & (df['CIDADE'] != 'DESCONHECIDO')
lat_long_cidade = lat_long_nulos & cidade_validas

# %%
# Função auxiliar: dado o código IBGE, retorna a latitude e longitude da base do IBGE
def posicaoIBGE(codigo_ibge, df_ref):
    # Como o código IBGE pode estar como string, convertemos para float para garantir a comparação correta
    row_ref = df_ref[df_ref['codigo_ibge'] == float(codigo_ibge)]
    if not row_ref.empty:
        return row_ref.iloc[0]['latitude'], row_ref.iloc[0]['longitude']
    else:
        return np.nan, np.nan

# %%
# Aplicar a função para preencher as coordenadas faltantes
df.loc[lat_long_cidade, ['LATITUDE', 'LONGITUDE']] = df.loc[lat_long_cidade].apply(
    lambda row: pd.Series(posicaoIBGE(row['CIDADE'], df_ibge)), axis=1
)

# %%
#Converter a coluna 'CIDADE' para numérico; valores não conversíveis virão como NaN
df['CIDADE_numeric'] = pd.to_numeric(df['CIDADE'], errors='coerce')
df['CIDADE_VEICULO_numeric'] = pd.to_numeric(df['CIDADE_VEICULO'], errors='coerce')

# %%
# Realiza o merge com o dataframe do IBGE para obter o nome da cidade
df = pd.merge(
    df,
    df_ibge[['codigo_ibge', 'nome']],
    left_on='CIDADE_numeric',
    right_on='codigo_ibge',
    how='left'
)

# Cria a nova coluna NOME_CIDADE com os nomes mapeados e, se não houver correspondência, atribui 'DESCONHECIDO'
df['NOME_CIDADE'] = df['nome'].fillna('DESCONHECIDO')

# %%
df.drop(columns=['CIDADE_numeric', 'codigo_ibge', 'nome'], inplace=True)

# %%
df = pd.merge(
    df,
    df_ibge[['codigo_ibge', 'nome']],
    left_on='CIDADE_VEICULO_numeric',
    right_on='codigo_ibge',
    how='left'
)
df['CIDADE_VEICULO'] = df['nome'].fillna('DESCONHECIDO')

# %%
df.drop(columns=['CIDADE_VEICULO_numeric', 'codigo_ibge', 'nome'], inplace=True)

# %% [markdown]
# ### Tratamento de DELEGACIA_ELABORACAO e DELEGACIA_CIRCUNSCRICAO

# %%
# Verifica se todas as linhas têm a mesma delegacia nas duas colunas
sao_iguais = (df['DELEGACIA_ELABORACAO'] == df['DELEGACIA_CIRCUNSCRICAO']).all()

print("Delegacias são idênticas:", sao_iguais)
# Out:
# Delegacias são idênticas: False

# %%
freq_elaboracao = df['DELEGACIA_ELABORACAO'].value_counts()
freq_circunscricao = df['DELEGACIA_CIRCUNSCRICAO'].value_counts()
print(freq_elaboracao.sum())
print(freq_circunscricao.sum())
# Out:
# 720411
# 720411

# %%
divergencias = df[df['DELEGACIA_ELABORACAO'] != df['DELEGACIA_CIRCUNSCRICAO']]
divergencias[['DELEGACIA_ELABORACAO', 'DELEGACIA_CIRCUNSCRICAO']].drop_duplicates()
# Out:
#                   DELEGACIA_ELABORACAO  \
# 0              DEL.POL.PLANTAO BIRIGUI
# 1                        08º D.P. BRAS
# 2                  02º D.P. BOM RETIRO
# 4                  02º D.P. BOM RETIRO
# 6                        08º D.P. BRAS
# 8                        08º D.P. BRAS
# 10                      91º D.P. CEASA
# 11              89º D.P. JARDIM TABOAO
# 15                   33º D.P. PIRITUBA
# 17                  14º D.P. PINHEIROS
# 18                    93º D.P. JAGUARE
# 19                  20º D.P. AGUA FRIA
# 20                 13º D.P. CASA VERDE
# 21                 13º D.P. CASA VERDE
# 22              72º D.P. VILA PENTEADO
# 23                     73º D.P. JACANA
# 24                       04ª DDM NORTE
# 25              72º D.P. VILA PENTEADO
# 27                     73º D.P. JACANA
# 29            10º D.P. PENHA DE FRANCA
# 30              18º D.P. ALTO DA MOOCA
# 31                31º D.P. VILA CARRAO
# 32                31º D.P. VILA CARRAO
# 33             52º D.P. PARQUE S.JORGE
# 34            10º D.P. PENHA DE FRANCA
# 35              101º D.P. JDIM IMBUIAS
# 36                25º D.P. PARELHEIROS
# 37              47º D.P. CAPAO REDONDO
# 40              47º D.P. CAPAO REDONDO
# 41              98º D.P. JARDIM MIRIAM
# 42              47º D.P. CAPAO REDONDO
# 43              101º D.P. JDIM IMBUIAS
# 46             50º D.P. ITAIM PAULISTA
# 47            53º D.P. PARQUE DO CARMO
# 48                 63º D.P. VILA JACUI
# 50            53º D.P. PARQUE DO CARMO
# 52                 49º D.P. SAO MATEUS
# 53            53º D.P. PARQUE DO CARMO
# 55                 49º D.P. SAO MATEUS
# 57               DEL.INV.GER. CRUZEIRO
# 58            DEL.SEC.CRUZEIRO PLANTAO
# 61               DEL.INV.GER. CRUZEIRO
# 62                   DEL.POL.LAVRINHAS
# 63                   DEL.POL.APARECIDA
# 64       DEL.SEC.GUARATINGUETA PLANTAO
# 65                      DEL.POL.LORENA
# 66                      DEL.POL.LORENA
# 67             DEL.SEC.JACAREI PLANTAO
# 68                    DEL.POL.CACAPAVA
# 71         DEL.SEC.POL.SJCAMPOS PL SUL
# 72          04º D.P. S.JOSE DOS CAMPOS
# 73         DEL.SEC.POL.SJCAMPOS PL SUL
# 74         DEL.SEC.POL.SJCAMPOS PL SUL
# 75         DEL.SEC.POL.SJCAMPOS PL SUL
# 76               DEL.POL.CARAGUATATUBA
# 77              01º D.P. CARAGUATATUBA
# 80               DEL.POL.CARAGUATATUBA
# 81                     DEL.POL.UBATUBA
# 83             DEL.SEC.TAUBATE PLANTAO
# 84               DEL.POL.PLANTAO PINDA
# 85            01º D.P. PINDAMONHANGABA
# 86               DEL.POL.PLANTAO PINDA
# 87            01º D.P. PINDAMONHANGABA
# 89             DEL.SEC.TAUBATE PLANTAO
# 90             DEL.SEC.TAUBATE PLANTAO
# 92             DEL.SEC.TAUBATE PLANTAO
# 93               CPJ ARACATUBA PLANTAO
# 95             DEL.POL.PLANTAO BIRIGUI
# 96             DEL.POL.GENERAL SALGADO
# 97                  DEL.POL.VALPARAISO
# 98         3ªHOMICIDIOS-DEIC-DEINTER 2
# 99            PLANTAO - 01 DP CAMPINAS
# 100        3ªHOMICIDIOS-DEIC-DEINTER 2
# 101           PLANTAO - 01 DP CAMPINAS
# 102            DEL.POL.PLANTAO VINHEDO
# 103        DEL.SEC.2ª CAMPINAS-PLANTAO
# 104              1ª DIG-DEIC-DEINTER 2
# 105                   02ª DDM CAMPINAS
# 108        DEL.SEC.2ª CAMPINAS-PLANTAO
# 110        DEL.SEC.2ª CAMPINAS-PLANTAO
# 112         DEL.POL.PLANTAO INDAIATUBA
# 113      DEL.POL.BOM JESUS DOS PERDOES
# 114       DEL.POL.CAMPO LIMPO PAULISTA
# 115            DEL.POL.PLANTAO ITATIBA
# 116         PLANTAO - 01º D.P. JUNDIAI
# 117         DEL.SEC.MOGI GUACU PLANTAO
# 118            DEL.INV.GER. MOGI GUACU
# 119               DEL.POL.TAQUARITINGA
# 120           DEL.SEC.BARRETOS PLANTAO
# 123                     DEL.POL.COLINA
# 124          DEL.POL.PLANTAO BEBEDOURO
# 125                 DEL.POL.TERRA ROXA
# 126             DEL.SEC.FRANCA PLANTAO
# 127          DEL.POL.PLANTAO ITUVERAVA
# 128               DEL.POL.JARDINOPOLIS
# 129                 CPJ RIBEIRAO PRETO
# 130                 CPJ RIBEIRAO PRETO
# 132          DEL.POL.S.ROSA DE VITERBO
# 133         DEL.SEC.SAO CARLOS PLANTAO
# 134            DEL.INV.GER. SAO CARLOS
# 136           DEL.SEC.BARRETOS PLANTAO
# 137        DEL.SEC.SERTAOZINHO PLANTAO
# 139           DEL.SEC.BAURU PL SUB-REG
# 140              DEL.SEC.BAURU PLANTAO
# 142                            CPJ JAU
# 143                           CPJ LINS
# 144                           CPJ LINS
# 145          DEL.SEC.CATANDUVA PLANTAO
# 146          DEL.SEC.CATANDUVA PLANTAO
# 147      DEL.SEC.FERNANDOPOLIS PLANTAO
# 148                     DEL.POL.ADOLFO
# 149                   DEL.POL.MIRASSOL
# 151               DEL.POL.NOVA GRANADA
# 152      DEL.SEC.S.J RIO PRETO PLANTAO
# 153      DEL.SEC.S.J RIO PRETO PLANTAO
# 154      DEL.SEC.S.J RIO PRETO PLANTAO
# 157      DEL.SEC.S.J RIO PRETO PLANTAO
# 158      DEL.SEC.S.J RIO PRETO PLANTAO
# 159             DEL.POL.JOSE BONIFACIO
# 160                    DEL.POL.CARDOSO
# 161        DEL.SEC.VOTUPORANGA PLANTAO
# 162        DEL.SEC.VOTUPORANGA PLANTAO
# 163           DEL.SEC.ITANHAEM PLANTAO
# 164                    DEL.POL.PERUIBE
# 166                    DEL.POL.PERUIBE
# 167             DEL.POL.BARRA DO TURVO
# 168                     DEL.POL.CAJATI
# 169     02º D.P.PRAIA GRANDE-BOQUEIRAO
# 170                   CPJ PRAIA GRANDE
# 173                  DEL.POL.S.VICENTE
# 174               02º D.P. SAO VICENTE
# 176                  DEL.POL.S.VICENTE
# 178                  02º D.P. REGISTRO
# 179                   02º D.P. GUARUJA
# 180                    DEL.POL.GUARUJA
# 182                         CPJ SANTOS
# 183                DEL.POL.TAQUARITUBA
# 184              DEL.POL.PLANTAO TATUI
# 185            DEL.SEC.ITAPEVA PLANTAO
# 186         DEL.POL.ARACOIABA DA SERRA
# 187                     DEL.POL.IBIUNA
# 188                DEL.POL.PLANTAO ITU
# 189     PLANTAO DE SOROCABA - Z. NORTE
# 190        3ªHOMICIDIOS-DEIC-DEINTER 7
# 191     PLANTAO DE SOROCABA - Z. NORTE
# 192                      DEL.POL.TIETE
# 193         DEL.POL.PEDRINHAS PAULISTA
# 194                 DEL.POL.COSMOPOLIS
# 195        DEL.POL.PLANTAO HORTOLANDIA
# 196                DEL.SEC.CASA BRANCA
# 197                     DEL.POL.MOCOCA
# 198                       DEL.POL.LEME
# 200                       DEL.POL.LEME
# 202                   02º D.P. LIMEIRA
# 203        3ªHOMICIDIOS-DEIC-DEINTER 9
# 204                    DEL.POL.S.PEDRO
# 205          DEL.SEC.RIO CLARO PLANTAO
# 207          DEL.SEC.RIO CLARO PLANTAO
# 208        DEL.SEC.S.JOAO DA BOA VISTA
# 209                    DEL.POL.BARUERI
# 210               01º D.P. CARAPICUIBA
# 212               01º D.P. CARAPICUIBA
# 216      DEL.POL.PIRAPORA DO BOM JESUS
# 217        DEL.POL.SANTANA DE PARNAIBA
# 218                   03º D.P. DIADEMA
# 221             SETOR HOM.SEC. DIADEMA
# 223                   03º D.P. DIADEMA
# 224                  DEL.POL.MAIRIPORA
# 225                 01º D.P. GUARULHOS
# 226                 04º D.P. GUARULHOS
# 227                 07º D.P. GUARULHOS
# 230                 DEL.POL.STA ISABEL
# 231            DEL.POL.ITAQUAQUECETUBA
# 234           01º D.P. MOGI DAS CRUZES
# 235        DEL.SEC.MOGI CRUZES PLANTAO
# 236                     DEL.POL.SUZANO
# 237                    02º D.P. OSASCO
# 238                    05º D.P. OSASCO
# 239     01º DP MAUA-DR.ALFREDO GARBINO
# 240     01º DP MAUA-DR.ALFREDO GARBINO
# 241        DEL.POL.RIO GRANDE DA SERRA
# 242                    CPJ SANTO ANDRE
# 244                    CPJ SANTO ANDRE
# 245       08º D.P. S.BERNARDO DO CAMPO
# 246             DEL.POL.EMBU DAS ARTES
# 248                  DEL.POL.JUQUITIBA
# 249           01º D.P. TABOAO DA SERRA
# 250             CORREGEDORIA - PLANTAO
# 251      06ª DEL.REP.DEL.INT.ESP-DRADE
# 254                     46º D.P. PERUS
# 256                    05º D.P. OSASCO
# 257             89º D.P. JARDIM TABOAO
# 258             89º D.P. JARDIM TABOAO
# 261                 20º D.P. AGUA FRIA
# 262                19º D.P. VILA MARIA
# 264             72º D.P. VILA PENTEADO
# 265             72º D.P. VILA PENTEADO
# 268               11º D.P. SANTO AMARO
# 270             98º D.P. JARDIM MIRIAM
# 271             101º D.P. JDIM IMBUIAS
# 272             47º D.P. CAPAO REDONDO
# 276           100º D.P. JDIM HERCULANO
# 280               DHPP DIV. HOMICIDIOS
# 281                63º D.P. VILA JACUI
# 283                24º D.P. PONTE RASA
# 287           69º D.P. TEOTONIO VILELA
# 289           69º D.P. TEOTONIO VILELA
# 290           DEL.SEC.CRUZEIRO PLANTAO
# 292           DEL.SEC.CRUZEIRO PLANTAO
# 295                     DEL.POL.LORENA
# 296      DEL.SEC.GUARATINGUETA PLANTAO
# 303                     DEL.POL.LORENA
# 304            DEL.SEC.JACAREI PLANTAO
# 311               01º D.P. S.SEBASTIAO
# 312              02º D.P. S. SEBASTIAO
# 316        DEL.POL.NATIVIDADE DA SERRA
# 319            DEL.SEC.TAUBATE PLANTAO
# 321                  DEL.SEC.ANDRADINA
# 325                 DEL.POL.CLEMENTINA
# 326                      DDM PENAPOLIS
# 327           PLANTAO - 01 DP CAMPINAS
# 328           PLANTAO - 04 DP CAMPINAS
# 330                  02º D.P. CAMPINAS
# 331        DEL.SEC.2ª CAMPINAS-PLANTAO
# 336        3ªHOMICIDIOS-DEIC-DEINTER 2
# 337            DEL.POL.PLANTAO ATIBAIA
# 338            DEL.POL.NAZARE PAULISTA
# 339            DEL.POL.PLANTAO ATIBAIA
# 340                  01º D.P. CABREUVA
# 341                    DEL.POL.ITUPEVA
# 342               DEL.INV.GER. JUNDIAI
# 343                   05º D.P. JUNDIAI
# 344         PLANTAO - 01º D.P. JUNDIAI
# 345         PLANTAO - 01º D.P. JUNDIAI
# 347                 DEL.POL.MOGI-MIRIM
# 348         DEL.SEC.ARARAQUARA PLANTAO
# 349            DEL.INV.GER. ARARAQUARA
# 350           DEL.SEC.BARRETOS PLANTAO
# 353           DEL.SEC.BARRETOS PLANTAO
# 355          DEL.POL.PLANTAO BEBEDOURO
# 356             DEL.SEC.FRANCA PLANTAO
# 357                 CPJ RIBEIRAO PRETO
# 359                 CPJ RIBEIRAO PRETO
# 361                 CPJ RIBEIRAO PRETO
# 362                 CPJ RIBEIRAO PRETO
# 363     DEL.POL.PLANTAO PORTO FERREIRA
# 364             DEL.POL.PORTO FERREIRA
# 365     DEL.POL.PLANTAO PORTO FERREIRA
# 369                     DEL.POL.AGUDOS
# 372           DEL.SEC.BAURU PL SUB-REG
# 373           DEL.SEC.BAURU PL SUB-REG
# 374                            CPJ JAU
# 375                           CPJ LINS
# 376                      DEL.POL.GARCA
# 377            DEL.SEC.MARILIA PLANTAO
# 379                  DEL.POL.PALESTINA
# 384                    DEL.POL.PERUIBE
# 385                    DEL.POL.PERUIBE
# 386      03º D.P. PRAIA GRANDE-CAICARA
# 389           DEL.SEC.REGISTRO PLANTAO
# 390                   DEL.POL.BERTIOGA
# 392                    DEL.POL.GUARUJA
# 394                         CPJ SANTOS
# 397                    01º D.P. PIRAJU
# 398              DEL.POL.PLANTAO TATUI
# 399            DEL.SEC.ITAPEVA PLANTAO
# 402     PLANTAO DE SOROCABA - Z. NORTE
# 403                DEL.POL.PLANTAO ITU
# 405                  DEL.POL.MAIRINQUE
# 407                    DEL.POL.PIEDADE
# 408                DEL.POL.PORTO FELIZ
# 409              DEL.POL.PLANTAO SALTO
# 411         DEL.POL.PLANTAO VOTORANTIM
# 412     PLANTAO DE SOROCABA - Z. NORTE
# 414         DEL.POL.PLANTAO VOTORANTIM
# 415                   DEL.POL.PALMITAL
# 416            DEL.SEC.DRACENA PLANTAO
# 417       DEL.POL.MIRANTE PARANAPANEMA
# 418     DEL.SEC.PRES.VENCESLAU PLANTAO
# 419                 02º D.P. AMERICANA
# 420                 01º D.P. AMERICANA
# 421                 03º D.P. AMERICANA
# 425                  DEL.POL.MONTE MOR
# 426      DEL.POL.PLANTAO S.BARB.DOESTE
# 428                     DEL.POL.SUMARE
# 429             DEL.POL.PLANTAO SUMARE
# 430                    DEL.POL.CONCHAL
# 432            DEL.SEC.LIMEIRA PLANTAO
# 433            DEL.SEC.LIMEIRA PLANTAO
# 434         DEL.SEC.PIRACICABA PLANTAO
# 435         DEL.SEC.PIRACICABA PLANTAO
# 436         DEL.SEC.PIRACICABA PLANTAO
# 438                     DEL.POL.BROTAS
# 439          DEL.SEC.RIO CLARO PLANTAO
# 440                  DEL.POL.ITIRAPINA
# 442                   01º D.P. BARUERI
# 443                    DEL.POL.BARUERI
# 447               01º D.P. CARAPICUIBA
# 449                          DDM COTIA
# 450                      DEL.POL.COTIA
# 451                    DEL.POL.ITAPEVI
# 452                    DEL.POL.JANDIRA
# 454                      DEL.POL.COTIA
# 455                   03º D.P. DIADEMA
# 457                  01º D.P. CAIEIRAS
# 458                    DEL.POL.CAJAMAR
# 459           DEL.POL.FRANCISCO MORATO
# 460               DEL.POL.FRANCO ROCHA
# 461                 01º D.P. MAIRIPORA
# 462                  DEL.POL.MAIRIPORA
# 465                      DEL.POL.ARUJA
# 468                 07º D.P. GUARULHOS
# 470                 01º D.P. GUARULHOS
# 471                 09º D.P. GUARULHOS
# 472      DEL.POL.FERRAZ DE VASCONCELOS
# 477        DEL.SEC.MOGI CRUZES PLANTAO
# 479                     DEL.POL.SUZANO
# 481                    05º D.P. OSASCO
# 484       04º D.P. S.BERNARDO DO CAMPO
# 485             DEL.POL.EMBU DAS ARTES
# 488                 DEL.POL.EMBU-GUACU
# 489      01º D.P. ITAPECERICA DA SERRA
# 490       DEL.POL.ITAPECERICA DA SERRA
# 497            03º D.P. CAMPOS ELISEOS
# 499                02º D.P. BOM RETIRO
# 500           16º D.P. VILA CLEMENTINO
# 501       27º DP DR. IGNACIO FRANCISCO
# 502           16º D.P. VILA CLEMENTINO
# 503                    26º D.P. SACOMA
# 504                 14º D.P. PINHEIROS
# 511                  33º D.P. PIRITUBA
# 513                     91º D.P. CEASA
# 514               DHPP DIV. HOMICIDIOS
# 524             101º D.P. JDIM IMBUIAS
# 530                63º D.P. VILA JACUI
# 531                24º D.P. PONTE RASA
# 534                24º D.P. PONTE RASA
# 535                24º D.P. PONTE RASA
# 536            50º D.P. ITAIM PAULISTA
# 546      DEL.SEC.GUARATINGUETA PLANTAO
# 549                  DEL.POL.APARECIDA
# 551         01º D.P. S.JOSE DOS CAMPOS
# 559           DEL.POL.CAMPOS DO JORDAO
# 560              DEL.POL.PLANTAO PINDA
# 564          DEL.POL.REDENCAO DA SERRA
# 565            DEL.SEC.TAUBATE PLANTAO
# 571                  DEL.SEC.ANDRADINA
# 572              DEL.POL.ILHA SOLTEIRA
# 573                  DEL.SEC.ANDRADINA
# 574              CPJ ARACATUBA PLANTAO
# 577              CPJ ARACATUBA PLANTAO
# 579                  DEL.POL.AURIFLAMA
# 582        3ªHOMICIDIOS-DEIC-DEINTER 2
# 586        3ªHOMICIDIOS-DEIC-DEINTER 2
# 587     PLANTAO-DEF.MUL.CAMPINAS-2ªSEC
# 588        3ªHOMICIDIOS-DEIC-DEINTER 2
# 589                   DEL.POL.VALINHOS
# 591        DEL.SEC.2ª CAMPINAS-PLANTAO
# 592        3ªHOMICIDIOS-DEIC-DEINTER 2
# 598            DEL.POL.PLANTAO ATIBAIA
# 599       DEL.SEC.BRAGANCA PTA PLANTAO
# 600                DEL.POL.SERRA NEGRA
# 602                     DEL.POL.JARINU
# 603            DEL.POL.VARZEA PAULISTA
# 604         DEL.SEC.MOGI GUACU PLANTAO
# 606                 DEL.POL.JAGUARIUNA
# 609            DEL.INV.GER. ARARAQUARA
# 610         DEL.SEC.ARARAQUARA PLANTAO
# 611                          DDM MATAO
# 613           DEL.SEC.BARRETOS PLANTAO
# 616          DEL.POL.PLANTAO ITUVERAVA
# 617          DEL.POL.PLANTAO ITUVERAVA
# 618                 CPJ RIBEIRAO PRETO
# 622                DEL.POL.ALTINOPOLIS
# 623     DEL.POL.PLANTAO PORTO FERREIRA
# 624         DEL.SEC.SAO CARLOS PLANTAO
# 625            DEL.INV.GER. SAO CARLOS
# 628        DEL.POL.PLANTAO JABOTICABAL
# 629        DEL.SEC.SERTAOZINHO PLANTAO
# 632                            CPJ JAU
# 634                            CPJ JAU
# 636                           CPJ LINS
# 637                           CPJ LINS
# 638            DEL.SEC.MARILIA PLANTAO
# 639              DEL.INV.GER. OURINHOS
# 640      DEL.SEC.FERNANDOPOLIS PLANTAO
# 641                   DEL.POL.MIRASSOL
# 642                   DEL.POL.MIRASSOL
# 643                     DEL.POL.CEDRAL
# 647      DEL.SEC.S.J RIO PRETO PLANTAO
# 648           DEL.SEC.ITANHAEM PLANTAO
# 650                   DEL.POL.MONGAGUA
# 652                   CPJ PRAIA GRANDE
# 653                   CPJ PRAIA GRANDE
# 656                    DEL.POL.CUBATAO
# 658                    DEL.POL.GUARUJA
# 659              DEL.SEC.AVARE PLANTAO
# 660                     DEL.POL.TAGUAI
# 661                DEL.POL.TAQUARITUBA
# 662                    DEL.POL.BOITUVA
# 663              DEL.POL.PLANTAO TATUI
# 664        3ªHOMICIDIOS-DEIC-DEINTER 7
# 665        3ªHOMICIDIOS-DEIC-DEINTER 7
# 667        3ªHOMICIDIOS-DEIC-DEINTER 7
# 669         DEL.SEC.ADAMANTINA PLANTAO
# 670      DEL.POL.PLANTAO PARAGUACU PTA
# 671         DEL.POL.PARAGUACU PAULISTA
# 672      DEL.POL.PLANTAO PARAGUACU PTA
# 673            DEL.SEC.DRACENA PLANTAO
# 674                     DEL.POL.ROSANA
# 675                 03º D.P. AMERICANA
# 676        DEL.POL.PLANTAO HORTOLANDIA
# 679                DEL.POL.NOVA ODESSA
# 680             DEL.POL.PLANTAO SUMARE
# 682             DEL.POL.PLANTAO SUMARE
# 684                     DEL.POL.ARARAS
# 685                     DDM PIRACICABA
# 686                02º D.P. PIRACICABA
# 687         DEL.SEC.PIRACICABA PLANTAO
# 689         DEL.SEC.PIRACICABA PLANTAO
# 690                  DEL.POL.ITIRAPINA
# 694        DEL.SEC.S.JOAO DA BOA VISTA
# 695                        DDM BARUERI
# 699                     02º D.P. COTIA
# 701                      DEL.POL.COTIA
# 704                        DDM BARUERI
# 706                   DEL.POL.CAIEIRAS
# 708                    DEL.POL.CAJAMAR
# 711       DEL.POL.CAMPO LIMPO PAULISTA
# 723                    08º D.P. OSASCO
# 724     01º DP MAUA-DR.ALFREDO GARBINO
# 726     DEL.POL.RPIRES DR.EVANDRO LIMA
# 727         SETOR HOM.SEC. SANTO ANDRE
# 728         SETOR HOM.SEC. SANTO ANDRE
# 730       03º D.P. S.BERNARDO DO CAMPO
# 731      01º D.P. S.B.C-DR OMAR CASSIM
# 742                      08º D.P. BRAS
# 746       27º DP DR. IGNACIO FRANCISCO
# 747                    26º D.P. SACOMA
# 754           10º D.P. PENHA DE FRANCA
# 756           10º D.P. PENHA DE FRANCA
# 775           10º D.P. PENHA DE FRANCA
# 776                63º D.P. VILA JACUI
# 783           53º D.P. PARQUE DO CARMO
# 784                24º D.P. PONTE RASA
# 796      DEL.SEC.GUARATINGUETA PLANTAO
# 799                    01º D.P. LORENA
# 806                    DEL.POL.PIQUETE
# 808            DEL.SEC.JACAREI PLANTAO
# 810                   DEL.POL.CACAPAVA
# 813                   DEL.POL.ILHABELA
# 815            DEL.POL.PLANTAO UBATUBA
# 819            DEL.SEC.TAUBATE PLANTAO
# 825            DEL.POL.GENERAL SALGADO
# 827           DEL.POL.PLANTAO VALINHOS
# 828           DEL.POL.PLANTAO VALINHOS
# 829                  02º D.P. CAMPINAS
# 835            DEL.POL.PLANTAO ATIBAIA
# 836       DEL.SEC.BRAGANCA PTA PLANTAO
# 840         PLANTAO - 01º D.P. JUNDIAI
# 841         DEL.SEC.MOGI GUACU PLANTAO
# 845          DEL.POL.PLANTAO BEBEDOURO
# 848             DEL.SEC.FRANCA PLANTAO
# 849                DEL.POL.ALTINOPOLIS
# 850                 CPJ RIBEIRAO PRETO
# 851                 CPJ RIBEIRAO PRETO
# 852                    DEL.POL.SERRANA
# 854                      DEL.POL.IBATE
# 857         DEL.SEC.SAO CARLOS PLANTAO
# 859        DEL.SEC.SERTAOZINHO PLANTAO
# 860        DEL.POL.PLANTAO JABOTICABAL
# 861        DEL.SEC.SERTAOZINHO PLANTAO
# 862                     DEL.POL.PONTAL
# 864           DEL.SEC.BAURU PL SUB-REG
# 865           DEL.SEC.BAURU PL SUB-REG
# 866                           CPJ LINS
# 868                     DEL.POL.BASTOS
# 869                    DEL.POL.PARAPUA
# 871                  DEL.POL.MERIDIANO
# 873                     DEL.POL.CEDRAL
# 875             DEL.POL.JOSE BONIFACIO
# 876      DEL.SEC.S.J RIO PRETO PLANTAO
# 878                     DEL.POL.CEDRAL
# 879              DEL.INV.GER. ITANHAEM
# 880            DEL.POL.PEDRO DE TOLEDO
# 886           DEL.SEC.REGISTRO PLANTAO
# 888                DEL.POL.SETE BARRAS
# 889                    DEL.POL.CUBATAO
# 890                        DDM CUBATAO
# 893               DEL.SEC.ITAPETININGA
# 895               DEL.SEC.ITAPETININGA
# 897     PLANTAO DE SOROCABA - Z. NORTE
# 898                      DEL.POL.IPERO
# 900                  DEL.POL.SAO ROQUE
# 902     PLANTAO DE SOROCABA - Z. NORTE
# 903     PLANTAO DE SOROCABA - Z. NORTE
# 906     PLANTAO DE SOROCABA - Z. NORTE
# 907              DEL.SEC.ASSIS PLANTAO
# 908              DEL.SEC.ASSIS PLANTAO
# 909                   DEL.POL.PANORAMA
# 910            DEL.POL.ALVARES MACHADO
# 911      DEL.SEC.PRES.PRUDENTE PLANTAO
# 912                 01º D.P. AMERICANA
# 913             DEL.POL.ARTUR NOGUEIRA
# 916             DEL.POL.PLANTAO SUMARE
# 917        DEL.POL.PLANTAO HORTOLANDIA
# 918                     DEL.POL.ARARAS
# 924          DEL.SEC.RIO CLARO PLANTAO
# 927            DEL.POL.SANTA GERTRUDES
# 928          DEL.SEC.RIO CLARO PLANTAO
# 929        DEL.SEC.S.JOAO DA BOA VISTA
# 930            DEL.POL.PLANTAO BARUERI
# 931            DEL.POL.PLANTAO BARUERI
# 935               02º D.P. CARAPICUIBA
# 946                  33º D.P. PIRITUBA
# 947                 01º D.P. GUARULHOS
# 950                 08º D.P. GUARULHOS
# 953                      DEL.POL.ARUJA
# 955            DEL.POL.ITAQUAQUECETUBA
# 956           01º D.P. MOGI DAS CRUZES
# 957                    05º D.P. OSASCO
# 958                    07º D.P. OSASCO
# 959                    05º D.P. OSASCO
# 960                    05º D.P. OSASCO
# 961                    05º D.P. OSASCO
# 964                    CPJ SANTO ANDRE
# 967                    DDM SANTO ANDRE
# 976           01º D.P. TABOAO DA SERRA
# 985            83º D.P. PARQUE BRISTOL
# 995                    73º D.P. JACANA
# 999               56º D.P. VILA ALPINA
# 1000              31º D.P. VILA CARRAO
# 1011           50º D.P. ITAIM PAULISTA
# 1019               49º D.P. SAO MATEUS
# 1021               DEL. POL. APARECIDA
# 1022                    DEL.POL.LORENA
# 1023                     DEL.POL.CUNHA
# 1040       DEL.SEC.POL.SJCAMPOS PL SUL
# 1044             02º D.P. S. SEBASTIAO
# 1047               CPJ PINDAMONHANGABA
# 1050                    DEIC - TAUBATE
# 1054                   DEL.POL.ITAPURA
# 1058                 DEL.POL.AURIFLAMA
# 1059                 01º D.P. CAMPINAS
# 1062                 01º D.P. VALINHOS
# 1066          PLANTAO - 01 DP CAMPINAS
# 1074        DEL.POL.PLANTAO INDAIATUBA
# 1075      DEL.SEC.BRAGANCA PTA PLANTAO
# 1076                 01º D.P. CABREUVA
# 1079        DEL.SEC.MOGI GUACU PLANTAO
# 1080        DEL.SEC.ARARAQUARA PLANTAO
# 1081                  DEL.POL.IBITINGA
# 1082                     DEL.POL.MATAO
# 1084                   DEL.POL.GUARACI
# 1086                     DEL.POL.GUARA
# 1087                 DEL.POL.IGARAPAVA
# 1088            DEL.SEC.FRANCA PLANTAO
# 1089                CPJ RIBEIRAO PRETO
# 1095        DEL.SEC.SAO CARLOS PLANTAO
# 1099                CPJ RIBEIRAO PRETO
# 1101             DEL.SEC.BAURU PLANTAO
# 1104         DEL.SEC.CATANDUVA PLANTAO
# 1105         DEL.SEC.CATANDUVA PLANTAO
# 1106         DEL.POL.APARECIDA D OESTE
# 1107                  DEL.POL.MIRASSOL
# 1110                   DEL.POL.ITARIRI
# 1114              03º D.P. SAO VICENTE
# 1116                    DEL.POL.JUQUIA
# 1117                  DEL.POL.MIRACATU
# 1123                  DEL.POL.BERTIOGA
# 1124             DEL.SEC.AVARE PLANTAO
# 1127                     DEL.POL.APIAI
# 1128                 DEL.POL.SAO ROQUE
# 1130               DEL.POL.PLANTAO ITU
# 1131    PLANTAO DE SOROCABA - Z. NORTE
# 1135           DEL.SEC.DRACENA PLANTAO
# 1136           DEL.SEC.DRACENA PLANTAO
# 1138                    DEL.POL.NANTES
# 1140                 DEL.POL.RANCHARIA
# 1141     DEL.POL.PLANTAO PRES.EPITACIO
# 1142                04º D.P. AMERICANA
# 1143                04º D.P. AMERICANA
# 1145     DEL.POL.PLANTAO S.BARB.DOESTE
# 1148               DEL.SEC.CASA BRANCA
# 1150               04º D.P. PIRACICABA
# 1151       3ªHOMICIDIOS-DEIC-DEINTER 9
# 1152             1ª DIG-DEIC-DEINTER 9
# 1164                    02º D.P. COTIA
# 1166                       DDM BARUERI
# 1170                02º D.P. GUARULHOS
# 1179                07º D.P. GUARULHOS
# 1180     DEL.POL.FERRAZ DE VASCONCELOS
# 1187     DEL.POL.FERRAZ DE VASCONCELOS
# 1191                   05º D.P. OSASCO
# 1193                     03º D.P. MAUA
# 1195                   CPJ SANTO ANDRE
# 1197                   CPJ SANTO ANDRE
# 1200     01º D.P. S.B.C-DR OMAR CASSIM
# 1201      02º D.P. S.BERNARDO DO CAMPO
# 1203      05º D.P. S.BERNARDO DO CAMPO
# 1205      03º D.P. S.BERNARDO DO CAMPO
# 1206           01º D.P. EMBU DAS ARTES
# 1207    DEL.POL.PLANTAO EMBU DAS ARTES
# 1214                 DEL.POL.JUQUITIBA
# 1221                20º D.P. AGUA FRIA
# 1223                     05ª DDM LESTE
# 1228              DHPP DIV. HOMICIDIOS
# 1245                    DEL.POL.ARAPEI
# 1250        DEL.INV.GER. GUARATINGUETA
# 1252                    DEL.POL.LORENA
# 1254              DEL.INV.GER. JACAREI
# 1259        03º D.P. S.JOSE DOS CAMPOS
# 1264        06º D.P. S.JOSE DOS CAMPOS
# 1279               CPJ PINDAMONHANGABA
# 1283           DEL.SEC.TAUBATE PLANTAO
# 1286           DEL.POL.PEREIRA BARRETO
# 1288                  01º D.P. BIRIGUI
# 1290         DEL.POL.PLANTAO PENAPOLIS
# 1293                  DEL.POL.PAULINIA
# 1298                 06º D.P. CAMPINAS
# 1306           DEL.POL.PLANTAO ITATIBA
# 1309        DEL.SEC.MOGI GUACU PLANTAO
# 1310                    DDM MOGI GUACU
# 1312        DEL.SEC.ARARAQUARA PLANTAO
# 1316         DEL.POL.PLANTAO BEBEDOURO
# 1317            DEL.SEC.FRANCA PLANTAO
# 1318                 DEL.POL.BRODOWSKI
# 1327        DEL.SEC.SAO CARLOS PLANTAO
# 1328        DEL.SEC.SAO CARLOS PLANTAO
# 1329           CPJ S. JOAQUIM DA BARRA
# 1330                DEL.POL.MONTE ALTO
# 1331          DEL.INV.GER. SERTAOZINHO
# 1333                   DEL.POL.AREALVA
# 1334             DEL.SEC.BAURU PLANTAO
# 1335             DEL.SEC.BAURU PLANTAO
# 1338                 DEL.POL.PROMISSAO
# 1341     DEL.SEC.FERNANDOPOLIS PLANTAO
# 1342                    01º D.P. JALES
# 1344              DEL.POL.NOVA GRANADA
# 1348          DEL.SEC.ITANHAEM PLANTAO
# 1349       DEL.SEC.JACUPIRANGA PLANTAO
# 1354                  01º D.P. CUBATAO
# 1355                  02º D.P. CUBATAO
# 1357                  01º D.P. GUARUJA
# 1359           DEL.POL.CERQUEIRA CESAR
# 1360               DEL.POL.TAQUARITUBA
# 1361                  DEL.SEC.BOTUCATU
# 1362                  DEL.SEC.BOTUCATU
# 1364           DEL.POL.RIBEIRAO BRANCO
# 1366        DEL.POL.PLANTAO VOTORANTIM
# 1368                   DEL.POL.PIEDADE
# 1371    PLANTAO DE SOROCABA - Z. NORTE
# 1374     DEL.SEC.PRES.PRUDENTE PLANTAO
# 1377           DEL.POL.SANTO ANASTACIO
# 1383          DDM SANTA BARBARA DOESTE
# 1390              DEL.INV.GER. LIMEIRA
# 1392              DEL.POL.ELIAS FAUSTO
# 1393       3ªHOMICIDIOS-DEIC-DEINTER 9
# 1396        DEL.SEC.PIRACICABA PLANTAO
# 1404       DEL.SEC.S.JOAO DA BOA VISTA
# 1405                   DEL.POL.JANDIRA
# 1406                01º D.P. GUARULHOS
# 1416                  02º D.P. DIADEMA
# 1431          04º D.P. MOGI DAS CRUZES
# 1432       DEL.SEC.MOGI CRUZES PLANTAO
# 1433           DEL.POL.ITAQUAQUECETUBA
# 1437    01º DP MAUA-DR.ALFREDO GARBINO
# 1442              01º D.P. SANTO ANDRE
# 1444      02º D.P. S.BERNARDO DO CAMPO
# 1451          02º D.P. TABOAO DA SERRA
# 1452                    01ª DDM CENTRO
# 1457               95º D.P. HELIOPOLIS
# 1458                 33º D.P. PIRITUBA
# 1459            89º D.P. JARDIM TABOAO
# 1468                14º D.P. PINHEIROS
# 1479        92º D.P. PQ. SANTO ANTONIO
# 1483               06ª DDM SANTO AMARO
# 1498          DEL.SEC.CRUZEIRO PLANTAO
# 1499          DEL.SEC.CRUZEIRO PLANTAO
# 1520             DEL.POL.PLANTAO PINDA
# 1527              DEL.POL.MIRANDOPOLIS
# 1532             CPJ ARACATUBA PLANTAO
# 1533         DEL.POL.PLANTAO PENAPOLIS
# 1539       3ªHOMICIDIOS-DEIC-DEINTER 2
# 1540    PLANTAO-DEF.MUL.CAMPINAS-2ªSEC
# 1541    PLANTAO-DEF.MUL.CAMPINAS-2ªSEC
# 1550      DEL.SEC.BRAGANCA PTA PLANTAO
# 1553        DEL.SEC.MOGI GUACU PLANTAO
# 1559        DEL.SEC.ARARAQUARA PLANTAO
# 1562          DEL.SEC.BARRETOS PLANTAO
# 1563            DEL.SEC.FRANCA PLANTAO
# 1571       3ªHOMICIDIOS-DEIC-DEINTER 3
# 1575            DEL.SEC.FRANCA PLANTAO
# 1581          DEL.SEC.BAURU PL SUB-REG
# 1585          DEL.SEC.OURINHOS PLANTAO
# 1587          DEL.SEC.OURINHOS PLANTAO
# 1588              DEL.POL.SALTO GRANDE
# 1590          DEL.SEC.OURINHOS PLANTAO
# 1592    DEL.POL.PLANTAO NOVO HORIZONTE
# 1596                      DDM ITANHAEM
# 1599                  DEL.POL.CANANEIA
# 1600    01º D.P. PRAIA GRANDE-VL. TUPI
# 1603    02º D.P.PRAIA GRANDE-BOQUEIRAO
# 1607                    DEL.POL.JUQUIA
# 1609                 01º D.P. REGISTRO
# 1614                        CPJ SANTOS
# 1616                        CPJ SANTOS
# 1617                   05º D.P. SANTOS
# 1622              DEL.POL.CAPAO BONITO
# 1624                   DEL.POL.ITARARE
# 1626               DEL.POL.PLANTAO ITU
# 1632       3ªHOMICIDIOS-DEIC-DEINTER 7
# 1634        DEL.SEC.ADAMANTINA PLANTAO
# 1637     DEL.SEC.PRES.PRUDENTE PLANTAO
# 1646                  DEL.POL.PAULINIA
# 1649           DEL.SEC.LIMEIRA PLANTAO
# 1651             01º D.P. PIRASSUNUNGA
# 1656               02º D.P. PIRACICABA
# 1682              DDM FRANCISCO MORATO
# 1696                   02º D.P. SUZANO
# 1697                    DEL.POL.SUZANO
# 1706        SETOR HOM.SEC. SANTO ANDRE
# 1708              05º D.P. SANTO ANDRE
# 1716      06º D.P. S.BERNARDO DO CAMPO
# 1729          16º D.P. VILA CLEMENTINO
# 1730                   26º D.P. SACOMA
# 1732      27º DP DR. IGNACIO FRANCISCO
# 1733                    91º D.P. CEASA
# 1740               13º D.P. CASA VERDE
# 1741            72º D.P. VILA PENTEADO
# 1754              11º D.P. SANTO AMARO
# 1760              11º D.P. SANTO AMARO
# 1770          53º D.P. PARQUE DO CARMO
# 1789               DDM PINDAMONHANGABA
# 1790           DEL.SEC.TAUBATE PLANTAO
# 1794                03º D.P. ARACATUBA
# 1795             DEL.POL.NOVA CASTILHO
# 1802                 09º D.P. CAMPINAS
# 1806           DEL.POL.PLANTAO ATIBAIA
# 1807                   DEL.POL.SOCORRO
# 1810        PLANTAO - 01º D.P. JUNDIAI
# 1811                  07º D.P. JUNDIAI
# 1813                DEL.POL.JAGUARIUNA
# 1815          DEL.SEC.BARRETOS PLANTAO
# 1816                   DEL.POL.EMBAUBA
# 1817                    DEL.POL.GUAIRA
# 1818                CPJ RIBEIRAO PRETO
# 1825        DEL.SEC.SAO CARLOS PLANTAO
# 1828           CPJ S. JOAQUIM DA BARRA
# 1835          DEL.SEC.OURINHOS PLANTAO
# 1836          DEL.SEC.OURINHOS PLANTAO
# 1837                          CPJ TUPA
# 1838           DEL.POL.SANTA FE DO SUL
# 1848                    DEL.POL.TANABI
# 1850                  01º D.P. PERUIBE
# 1855                    DEL.POL.IGUAPE
# 1860                  03º D.P. CUBATAO
# 1863                   01º D.P. SANTOS
# 1866                 01º D.P. BOTUCATU
# 1867                  DEL.SEC.BOTUCATU
# 1868      DEL.POL.CAMPINA MONTE ALEGRE
# 1869             DEL.POL.PLANTAO TATUI
# 1873           DEL.SEC.ITAPEVA PLANTAO
# 1876                      04º D.P. ITU
# 1888     DEL.POL.PLANTAO PRES.EPITACIO
# 1889    DEL.SEC.PRES.VENCESLAU PLANTAO
# 1896              DEL.POL.PIRASSUNUNGA
# 1897                     DDM RIO CLARO
# 1899                 DEL.POL.ANALANDIA
# 1900                  DEL.POL.TORRINHA
# 1915       DEL.POL.SANTANA DE PARNAIBA
# 1921                05º D.P. GUARULHOS
# 1922                03º D.P. GUARULHOS
# 1947    DEL.POL.RPIRES DR.EVANDRO LIMA
# 1948              06º D.P. SANTO ANDRE
# 1960      DEL.POL.ITAPECERICA DA SERRA
# 1973                    01ª DDM CENTRO
# 1974      27º DP DR. IGNACIO FRANCISCO
# 1978                 33º D.P. PIRITUBA
# 1983               13º D.P. CASA VERDE
# 1984            DELEGACIA ELETRONICA 1
# 1985                    91º D.P. CEASA
# 1993              DHPP DIV. HOMICIDIOS
# 2020                    DEL.POL.QUELUZ
# 2025                 DEL.POL.APARECIDA
# 2026           DEL.SEC.JACAREI PLANTAO
# 2038                    DEIC - TAUBATE
# 2043                DEL.POL.GUARARAPES
# 2044          PLANTAO - 01 DP CAMPINAS
# 2052                DEL.POL.JOANOPOLIS
# 2058        PLANTAO - 01º D.P. JUNDIAI
# 2062        DEL.SEC.MOGI GUACU PLANTAO
# 2064           DEL.INV.GER. MOGI GUACU
# 2069        DEL.SEC.ARARAQUARA PLANTAO
# 2070                  DEL.POL.IBITINGA
# 2074                  DEL.POL.BATATAIS
# 2075                DEL.POL.PEDREGULHO
# 2083                CPJ RIBEIRAO PRETO
# 2093          DEL.SEC.BAURU PL SUB-REG
# 2094          DEL.SEC.BAURU PL SUB-REG
# 2096         DEL.SEC.CATANDUVA PLANTAO
# 2097       DISE- DEL.SEC.FERNANDOPOLIS
# 2103             DEL.INV.GER. ITANHAEM
# 2110                   02º D.P. SANTOS
# 2111                   04º D.P. SANTOS
# 2112             DEL.SEC.AVARE PLANTAO
# 2114                    DEL.POL.PIRAJU
# 2115                  DEL.SEC.BOTUCATU
# 2117              DEL.SEC.ITAPETININGA
# 2122                   DEL.POL.ITABERA
# 2123             DEL.POL.PLANTAO TATUI
# 2132       3ªHOMICIDIOS-DEIC-DEINTER 7
# 2135       3ªHOMICIDIOS-DEIC-DEINTER 7
# 2137        DEL.SEC.ADAMANTINA PLANTAO
# 2138           DEL.SEC.DRACENA PLANTAO
# 2139               DEL.POL.PIRAPOZINHO
# 2142     DEL.SEC.PRES.PRUDENTE PLANTAO
# 2143     DEL.SEC.PRES.PRUDENTE PLANTAO
# 2144                01º D.P. AMERICANA
# 2156          DEL.POL.S.BARBARA DOESTE
# 2161                    DEL.POL.MOCOCA
# 2165                    DEL.POL.ARARAS
# 2166              DEL.POL.IRACEMAPOLIS
# 2169              DEL.INV.GER. LIMEIRA
# 2170        DEL.SEC.PIRACICABA PLANTAO
# 2174                       DDM BARUERI
# 2189                06º D.P. GUARULHOS
# 2206                     02º D.P. MAUA
# 2213                   CPJ SANTO ANDRE
# 2220              DDM S.CAETANO DO SUL
# 2222      DEL.POL.ITAPECERICA DA SERRA
# 2227      DEL.POL.ITAPECERICA DA SERRA
# 2233            77º D.P. SANTA CECILIA
# 2235                  78º D.P. JARDINS
# 2242                   26º D.P. SACOMA
# 2244          75º D.P. JARDIM ARPOADOR
# 2252                     04ª DDM NORTE
# 2263              56º D.P. VILA ALPINA
# 2264              31º D.P. VILA CARRAO
# 2266            98º D.P. JARDIM MIRIAM
# 2280          69º D.P. TEOTONIO VILELA
# 2294                   01º D.P. LORENA
# 2304                   DEL.POL.IGARATA
# 2305                 DEL.POL.PARAIBUNA
# 2306           DEL.SEC.JACAREI PLANTAO
# 2309       DEL.SEC.POL.SJCAMPOS PL SUL
# 2321                01º D.P. ANDRADINA
# 2324                  DEL.POL.CASTILHO
# 2328                03º D.P. ARACATUBA
# 2330                 DEL.POL.PENAPOLIS
# 2331                   DEL.POL.BIRIGUI
# 2349      DEL.SEC.BRAGANCA PTA PLANTAO
# 2352       DEL.POL.AMERICO BRASILIENSE
# 2353           DEL.INV.GER. ARARAQUARA
# 2358            DEL.SEC.FRANCA PLANTAO
# 2359                CPJ RIBEIRAO PRETO
# 2370           CPJ S. JOAQUIM DA BARRA
# 2371       DEL.POL.PLANTAO JABOTICABAL
# 2377                  DEL.POL.MACATUBA
# 2378                           CPJ JAU
# 2381                   DEL.POL.QUEIROZ
# 2382         DEL.SEC.CATANDUVA PLANTAO
# 2383                    01º D.P. JALES
# 2384    DEL.POL.PLANTAO NOVO HORIZONTE
# 2389                  DEL.POL.MIRASSOL
# 2390       DEL.SEC.VOTUPORANGA PLANTAO
# 2393             DEL.INV.GER. ITANHAEM
# 2396                  DEL.POL.MONGAGUA
# 2400                   CPJ JACUPIRANGA
# 2406              01º D.P. SAO VICENTE
# 2407                  DIG PRAIA GRANDE
# 2409                    DEL.POL.IGUAPE
# 2410             DEL.POL.ILHA COMPRIDA
# 2417           DEL.SEC.ITAPEVA PLANTAO
# 2418                   DEL.POL.ITARARE
# 2422             DEL.SEC.ASSIS PLANTAO
# 2424             DEL.SEC.ASSIS PLANTAO
# 2425                   DEL.POL.LUTECIA
# 2427                    DEL.POL.TARUMA
# 2429       3ªHOMICIDIOS-DEIC-DEINTER 8
# 2432           DEL.POL.TEODORO SAMPAIO
# 2434                03º D.P. AMERICANA
# 2438               DEL.SEC.CASA BRANCA
# 2444                     DDM RIO CLARO
# 2449                     DEL.POL.COTIA
# 2471                     DDM GUARULHOS
# 2474       DEL.SEC.MOGI CRUZES PLANTAO
# 2479               DEL.POL.SALESOPOLIS
# 2480                   05º D.P. OSASCO
# 2490              02º D.P. SANTO ANDRE
# 2494          DEIC - S. BERNARDO CAMPO
# 2498                DDM EMBU DAS ARTES
# 2517                  78º D.P. JARDINS
# 2520                14º D.P. PINHEIROS
# 2521              DHPP DIV. HOMICIDIOS
# 2537                 33º D.P. PIRITUBA
# 2556              11º D.P. SANTO AMARO
# 2559           50º D.P. ITAIM PAULISTA
# 2572        DEL.INV.GER. GUARATINGUETA
# 2573            01º D.P. GUARATINGUETA
# 2580                  02º D.P. JACAREI
# 2599                03º D.P. ARACATUBA
# 2600                   DEL.POL.BIRIGUI
# 2602                  02º D.P. BIRIGUI
# 2603                   DEL.POL.BIRIGUI
# 2605                 07º D.P. CAMPINAS
# 2615             DDM BRAGANCA PAULISTA
# 2616                  DEL.POL.PIRACAIA
# 2617      DEL.SEC.BRAGANCA PTA PLANTAO
# 2625        DEL.SEC.MOGI GUACU PLANTAO
# 2638      02º D.P. S. JOAQUIM DA BARRA
# 2639       DEL.POL.PLANTAO JABOTICABAL
# 2643           DEL.SEC.MARILIA PLANTAO
# 2644           DEL.SEC.MARILIA PLANTAO
# 2646          DEL.SEC.OURINHOS PLANTAO
# 2647         DEL.SEC.CATANDUVA PLANTAO
# 2648                    01º D.P. JALES
# 2649                    DEL.POL.CEDRAL
# 2660       3ªHOMICIDIOS-DEIC-DEINTER 6
# 2661                   DEL.POL.CUBATAO
# 2664             DEL.POL.PLANTAO TATUI
# 2666              DEL.SEC.ITAPETININGA
# 2670         DEL.POL.SALTO DE PIRAPORA
# 2680                   DEL.POL.ANHUMAS
# 2683                   DEL.POL.TARABAI
# 2684     DEL.POL.EUCLIDES DA CUNHA PTA
# 2686                   02º D.P. SUMARE
# 2694             DEL.POL.CORDEIROPOLIS
# 2697                    DDM PIRACICABA
# 2698        DEL.SEC.PIRACICABA PLANTAO
# 2701                DEL.POL.JAGUARIUNA
# 2714                04º D.P. GUARULHOS
# 2715      03º D.P. AEROP/TUR-GUARULHOS
# 2732          DEL.POL.S.CAETANO DO SUL
# 2745                    01ª DDM CENTRO
# 2748                     12º D.P. PARI
# 2752            CORREGEDORIA - PLANTAO
# 2762                     04ª DDM NORTE
# 2774             85º D.P. JARDIM MIRNA
# 2789             67º D.P. JARDIM ROBRU
# 2809                   02º D.P. LORENA
# 2810                   02º D.P. LORENA
# 2814             CPJ S.JOSE DOS CAMPOS
# 2815             CPJ S.JOSE DOS CAMPOS
# 2830          PLANTAO - 01 DP CAMPINAS
# 2831          PLANTAO - 01 DP CAMPINAS
# 2832          DEL.POL.PLANTAO PAULINIA
# 2842               01º D.P. INDAIATUBA
# 2846                  DEL.POL.CABREUVA
# 2849                  04º D.P. JUNDIAI
# 2852                   DEL.POL.ITAPIRA
# 2853                   DEL.POL.ITAPIRA
# 2857        DEL.SEC.MOGI GUACU PLANTAO
# 2862          DEL.SEC.BARRETOS PLANTAO
# 2882                    DDM MONTE ALTO
# 2884          DEL.POL.LENCOIS PAULISTA
# 2891           DEL.SEC.MARILIA PLANTAO
# 2892                 DEL.POL.CHAVANTES
# 2893          DEL.SEC.OURINHOS PLANTAO
# 2898            01º D.P. FERNANDOPOLIS
# 2899            DEL.POL.JOSE BONIFACIO
# 2901                  DEL.POL.MIRASSOL
# 2906                 DEL.POL.RIOLANDIA
# 2911                 DEL.POL.S.VICENTE
# 2915                 DEL.POL.S.VICENTE
# 2923             DEL.SEC.AVARE PLANTAO
# 2925                  DEL.SEC.BOTUCATU
# 2926                 DEL.POL.CERQUILHO
# 2936       3ªHOMICIDIOS-DEIC-DEINTER 7
# 2940    PLANTAO DE SOROCABA - Z. NORTE
# 2941                      DDM SOROCABA
# 2943     DEL.SEC.PRES.PRUDENTE PLANTAO
# 2948            DEL.POL.PLANTAO SUMARE
# 2951           DEL.SEC.LIMEIRA PLANTAO
# 2954       3ªHOMICIDIOS-DEIC-DEINTER 9
# 2957         DEL.SEC.RIO CLARO PLANTAO
# 2959            DEL.INV.GER. RIO CLARO
# 2985          53º D.P. PARQUE DO CARMO
# 3001              01º D.P. SANTO ANDRE
# 3015              DHPP DIV. HOMICIDIOS
# 3017              56º D.P. VILA ALPINA
# 3021                   DEL.POL.PIRAJUI
# 3025                01º D.P. GUARULHOS
# 3027              03º D.P. SANTO ANDRE
# 3028              DHPP DIV. HOMICIDIOS
# 3031              DHPP DIV. HOMICIDIOS
# 3036              DHPP DIV. HOMICIDIOS
# 3039       DEL.SEC.VOTUPORANGA PLANTAO
# 3040              DEL.POL.PARANAPANEMA
# 3042                01º D.P. GUARULHOS
# 3045              DHPP DIV. HOMICIDIOS
# 3053                  DEL.POL.GUARANTA
# 3054         DEL.POL.LARANJAL PAULISTA
# 3055    PLANTAO DE SOROCABA - Z. NORTE
# 3060              56º D.P. VILA ALPINA
# 3066          DEL.SEC.OURINHOS PLANTAO
# 3067                 DDM FERNANDOPOLIS
# 3070       DEL.POL.PLANTAO HORTOLANDIA
# 3074                  26º D.P.  SACOMA
# 3075                    91º D.P. CEASA
# 3077           18º D.P.  ALTO DA MOOCA
# 3078           47º D.P.  CAPAO REDONDO
# 3079          50º D.P.  ITAIM PAULISTA
# 3082                   DEL.POL.S.SIMAO
# 3085           DEL.SEC.ITAPEVA PLANTAO
# 3090       DEL.SEC.POL.SJCAMPOS PL SUL
# 3092        DEL.SEC.ARARAQUARA PLANTAO
# 3095                  DEL.SEC.BOTUCATU
# 3097                  01º D.P. DIADEMA
# 3103              24º D.P.  PONTE RASA
# 3104             31 D.P. - VILA CARRAO
# 3107                DEL. POL. LOUVEIRA
# 3108    DEL.SEC.S.J  RIO PRETO PLANTAO
# 3113                     DEL.POL.MATAO
# 3115                 DEL.POL.GUARAREMA
# 3116                   06º D.P. OSASCO
# 3119                14º D.P. PINHEIROS
# 3123               13º D.P. CASA VERDE
# 3126              56º D.P. VILA ALPINA
# 3130               49º D.P. SAO MATEUS
# 3135                  DEL.SEC.BOTUCATU
# 3143               DEL.POL.PINHALZINHO
# 3144                   DEL.POL.OLIMPIA
# 3147          DEL.SEC.REGISTRO PLANTAO
# 3148                  DEL.POL.CAPIVARI
# 3162         DEL.INV.GER. ITAPETININGA
# 3163          DEL.POL.S.J.DO RIO PARDO
# 3165          01º D.P. ITAQUAQUECETUBA
# 3166      03º D.P. S.BERNARDO DO CAMPO
# 3177                  DEL.POL.TREMEMBE
# 3179               DEL. POL. NUPORANGA
# 3185              DEL.POL.CAPAO BONITO
# 3190                  03º D.P. DIADEMA
# 3194              DHPP DIV. HOMICIDIOS
# 3195               44º D.P. GUAIANAZES
# 3196              DHPP DIV. HOMICIDIOS
# 3197              DHPP DIV. HOMICIDIOS
# 3198              DHPP DIV. HOMICIDIOS
# 3199                   DEL.POL.CUBATAO
# 3200          16º D.P. VILA CLEMENTINO
# 3201              DHPP DIV. HOMICIDIOS
# 3202         1ª DIG - DEIC - DEINTER 6
# 3203              DHPP DIV. HOMICIDIOS
# 3204              DHPP DIV. HOMICIDIOS
# 3208              01º D.P. S.SEBASTIAO
# 3209                  DEL.SEC.BOTUCATU
# 3210                   CPJ SANTO ANDRE
# 3211     DEL.SEC.PRES.PRUDENTE PLANTAO
# 3212                 DEL.POL.S.VICENTE
# 3214             DEL.SEC.ASSIS PLANTAO
# 3215           DEL.SEC.JACAREI PLANTAO
# 3216                   DEL.POL.GUARUJA
# 3217                           CPJ JAU
# 3218             DEL.POL.PLANTAO TATUI
# 3219            89º D.P. JARDIM TABOAO
# 3220        DEL.SEC.SAO CARLOS PLANTAO
# 3221               DEL.POL.PLANTAO ITU
# 3223              DHPP DIV. HOMICIDIOS
# 3224              DHPP DIV. HOMICIDIOS
# 3225              DHPP DIV. HOMICIDIOS
# 3226              DHPP DIV. HOMICIDIOS
# 3228              DHPP DIV. HOMICIDIOS
# 3229          DEL.SEC.ITANHAEM PLANTAO
# 3230                 DEL.POL.S.VICENTE
# 3233        DEL.SEC.PIRACICABA PLANTAO
# 3235    PLANTAO DE SOROCABA - Z. NORTE
# 3239       DEL.SEC.VOTUPORANGA PLANTAO
# 3241    PLANTAO DE SOROCABA - Z. NORTE
# 3249                   73º D.P. JACANA
# 3250             DEL.SEC.BAURU PLANTAO
# 3251                CPJ RIBEIRAO PRETO
# 3252        SETOR HOM.SEC. SANTO ANDRE
# 3254              DHPP DIV. HOMICIDIOS
# 3255              DHPP DIV. HOMICIDIOS
# 3256              DHPP DIV. HOMICIDIOS
# 3257              DHPP DIV. HOMICIDIOS
# 3258              DHPP DIV. HOMICIDIOS
# 3259              DHPP DIV. HOMICIDIOS
# 3261              DHPP DIV. HOMICIDIOS
# 3262              DHPP DIV. HOMICIDIOS
# 3263              DHPP DIV. HOMICIDIOS
# 3264              DHPP DIV. HOMICIDIOS
# 3265              DHPP DIV. HOMICIDIOS
# 3266              DHPP DIV. HOMICIDIOS
# 3267              DHPP DIV. HOMICIDIOS
# 3268              DHPP DIV. HOMICIDIOS
# 3275                  DEL.SEC.BOTUCATU
# 3276                  DEL.SEC.BOTUCATU
# 3277        DEL.SEC.ADAMANTINA PLANTAO
# 3278            DEL.POL.EMBU DAS ARTES
# 3279       DEL.SEC.2ª CAMPINAS-PLANTAO
# 3280        DEL.SEC.SAO CARLOS PLANTAO
# 3281                  CPJ PRAIA GRANDE
# 3283       DEL.SEC.2ª CAMPINAS-PLANTAO
# 3284                07º D.P. GUARULHOS
# 3287                     DEL.POL.COTIA
# 3290      03º D.P. S.BERNARDO DO CAMPO
# 3291              11º D.P. SANTO AMARO
# 3292       DEL.POL.PLANTAO HORTOLANDIA
# 3294           DEL.POL.ITAQUAQUECETUBA
# 3296        DEL.SEC.MOGI GUACU PLANTAO
# 3298            47º D.P. CAPAO REDONDO
# 3299     DEL.SEC.S.J RIO PRETO PLANTAO
# 3300                  DEL.SEC.4ª NORTE
# 3303              DHPP DIV. HOMICIDIOS
# 3304              DHPP DIV. HOMICIDIOS
# 3305              DHPP DIV. HOMICIDIOS
# 3310              DHPP DIV. HOMICIDIOS
# 3311                    DEL.POL.CEDRAL
# 3313                 DEL.POL.MAIRIPORA
# 3314        DEL.POL.PLANTAO VOTORANTIM
# 3315          DEL.POL.S.CAETANO DO SUL
# 3316       DEL.SEC.SERTAOZINHO PLANTAO
# 3319                01º D.P. GUARULHOS
# 3320               63º D.P. VILA JACUI
# 3321           50º D.P. ITAIM PAULISTA
# 3323          69º D.P. TEOTONIO VILELA
# 3325        DEL.SEC.MOGI GUACU PLANTAO
# 3328                CPJ RIBEIRAO PRETO
# 3330             CPJ ARACATUBA PLANTAO
# 3331        SETOR HOM.SEC. SANTO ANDRE
# 3332       3ªHOMICIDIOS-DEIC-DEINTER 9
# 3333              DHPP DIV. HOMICIDIOS
# 3334              DHPP DIV. HOMICIDIOS
# 3337              DHPP DIV. HOMICIDIOS
# 3338              DHPP DIV. HOMICIDIOS
# 3339              DHPP DIV. HOMICIDIOS
# 3342              DEL.INV.GER. JUNDIAI
# 3346                   DEL.POL.BARUERI
# 3350       DEL.SEC.SERTAOZINHO PLANTAO
# 3351           DEL.SEC.LIMEIRA PLANTAO
# 3352    01º DP MAUA-DR.ALFREDO GARBINO
# 3353           DEL.POL.PLANTAO BIRIGUI
# 3355             21º D.P. VILA MATILDE
# 3359                       01º D.P. SE
# 3360                     08º D.P. BRAS
# 3362                CPJ RIBEIRAO PRETO
# 3396              DHPP DIV. HOMICIDIOS
# 3398              DHPP DIV. HOMICIDIOS
# 3399              DHPP DIV. HOMICIDIOS
# 3400          DEL.SEC.BAURU PL SUB-REG
# ...
# 681601                        DEL.POL.TABATINGA
# 681717                     05º D.P. SANTO ANDRE
# 681827                          04º D.P. OSASCO
# 681950                          DEL.POL.ITUPEVA
# 681956                          04º D.P. SUMARE
# 682005                          DEL.POL.ITUPEVA
# 682096                  06º D.P. RIBEIRAO PRETO
# 682179                         DEL.POL.HOLAMBRA
# 682221                 55º D.P. PARQUE S.RAFAEL
# 682404                         05º D.P. JUNDIAI
# 682483                 100º D.P. JDIM HERCULANO
# 682497                            02º D.P. LEME
# 683009             DEL.POL.ITAPECERICA DA SERRA
# 683020                        01º D.P. BATATAIS
# 683065                       05º D.P. GUARULHOS
# 683129                     DEL.POL.ARACARIGUAMA
# 683204                         05º D.P. JUNDIAI
# 683253                         06º D.P. JUNDIAI
# 683351                         01º D.P. ATIBAIA
# 683374                  28º D.P. FREGUESIA DO O
# 683538                           01º D.P. TATUI
# 683689                         05º D.P. JUNDIAI
# 683714                    36º D.P. VILA MARIANA
# 683715                     DEL.POL.FRANCO ROCHA
# 683723             08º D.P. S.BERNARDO DO CAMPO
# 683739                      49º D.P. SAO MATEUS
# 683742                 69º D.P. TEOTONIO VILELA
# 683752                       01º D.P. GUARULHOS
# 684028                          DEL.POL.ITUPEVA
# 684046                 53º D.P. PARQUE DO CARMO
# 684051                         06º D.P. JUNDIAI
# 684079                      95º D.P. HELIOPOLIS
# 684238                 02º D.P. TABOAO DA SERRA
# 684264                         01º D.P. DIADEMA
# 684394                     DEL.POL.ARACARIGUAMA
# 684437             02º D.P. S.BERNARDO DO CAMPO
# 684484            01º D.P. SANTA BARBARA DOESTE
# 684517                 02º D.P. TABOAO DA SERRA
# 684669                   01º D.P. GUARATINGUETA
# 684916                         DEL.POL.BORACEIA
# 685173                        DEL.POL.SAO ROQUE
# 685220                      03º D.P. SAO CARLOS
# 685283                 66º D.P. JDIM ARICANDUVA
# 685409                         DEL.POL.CAIEIRAS
# 685429                          04º D.P. FRANCA
# 685455                DEL.POL.ENGENHEIRO COELHO
# 685596                           46º D.P. PERUS
# 685627                  22º D.P. SAO MIGUEL PTA
# 685651                          04º D.P. OSASCO
# 685666            DEL.POL.STA RITA PASSA QUATRO
# 685745                      19º D.P. VILA MARIA
# 685752                        09º D.P. CAMPINAS
# 685834                            DEL.POL.ARUJA
# 685971                        01º D.P. OURINHOS
# 686011                      44º D.P. GUAIANAZES
# 686048                     DEL.POL.FRANCO ROCHA
# 686058                         68º D.P. LAGEADO
# 686500                       03º D.P. GUARULHOS
# 686520                          01º D.P. OSASCO
# 686660                     03º D.P. CARAPICUIBA
# 686798                  DEL.POL.ITAQUAQUECETUBA
# 686964                         DEL.POL.CAIEIRAS
# 687473                       04º D.P. GUARULHOS
# 687477                              DEL.POL.POA
# 687480                  02º D.P. RIBEIRAO PRETO
# 687680                      44º D.P. GUAIANAZES
# 687886                       08º D.P. GUARULHOS
# 687926                        DEL.POL.GUARAREMA
# 687990               01º D.P. BRAGANCA PAULISTA
# 688292                      13º D.P. CASA VERDE
# 688349                           DEL.POL.IBIUNA
# 688362                          05º D.P. SUMARE
# 688475                   45º D.P. V BRASILANDIA
# 688491                 01º D.P. PINDAMONHANGABA
# 688560                         DEL.POL.PAULINIA
# 688615                      49º D.P. SAO MATEUS
# 688852                         04º D.P. MARILIA
# 688958                        06º D.P. CAMPINAS
# 689017                             04º D.P. ITU
# 689052                   89º D.P. JARDIM TABOAO
# 689454                  90º D.P. PQ. NOVO MUNDO
# 689546              DEL.POL.SANTANA DE PARNAIBA
# 689645                           46º D.P. PERUS
# 689987                  DEL.POL.PRES. BERNARDES
# 690146                         02º D.P. LIMEIRA
# 690201             DEL.POL.MIRANTE PARANAPANEMA
# 690288               92º D.P. PQ. SANTO ANTONIO
# 690419                    67º D.P. JARDIM ROBRU
# 690517                     DEL.POL.FRANCO ROCHA
# 690622           DEL.POL.RPIRES DR.EVANDRO LIMA
# 690629                 75º D.P. JARDIM ARPOADOR
# 690704                 02º D.P. MOGI DAS CRUZES
# 690711                   74º D.P. PARADA TAIPAS
# 690750                      24º D.P. PONTE RASA
# 690919                         DEL.POL.JAMBEIRO
# 690960                           02º D.P. SALTO
# 691459                        09º D.P. CAMPINAS
# 691512                  22º D.P. SAO MIGUEL PTA
# 691655                        DEL.POL.PORANGABA
# 691903                   47º D.P. CAPAO REDONDO
# 692250                06º D.P. S.JOSE RIO PRETO
# 692404                  DEL.POL.NAZARE PAULISTA
# 692551                           46º D.P. PERUS
# 692567                  90º D.P. PQ. NOVO MUNDO
# 692690                        09º D.P. CAMPINAS
# 692787                          DEL.POL.CUBATAO
# 692829                01º D.P. CAMPOS DO JORDAO
# 693062             17º D.P. DOUTOR ALDO GALIANO
# 693072                           02º D.P. ASSIS
# 693083                          DEL.POL.ATIBAIA
# 693381                     25º D.P. PARELHEIROS
# 693559                       03º D.P. AMERICANA
# 694286                        09º D.P. SOROCABA
# 694390                   47º D.P. CAPAO REDONDO
# 694504                      63º D.P. VILA JACUI
# 694505                           01º D.P. SALTO
# 694718                       14º D.P. PINHEIROS
# 694755             DEL.POL.ITAPECERICA DA SERRA
# 694935                        03º D.P. SOROCABA
# 694951           01º DP MAUA-DR.ALFREDO GARBINO
# 695082                    39º D.P. VILA GUSTAVO
# 695122                            04º D.P. MAUA
# 695137            DOPE - 05ª DP PORTO DE SANTOS
# 695237            DEL.POL.FERRAZ DE VASCONCELOS
# 695328                   47º D.P. CAPAO REDONDO
# 695342                         30º D.P. TATUAPE
# 695440                         93º D.P. JAGUARE
# 695441             04º D.P. S.BERNARDO DO CAMPO
# 695529                          02º D.P. OSASCO
# 695600                 02º D.P. TABOAO DA SERRA
# 695750              DEL.POL.SANTANA DE PARNAIBA
# 695888                       03º D.P. GUARULHOS
# 695992                      44º D.P. GUAIANAZES
# 695999                          DEL.POL.CAJAMAR
# 696050                         04º D.P. LIMEIRA
# 696269                        11º D.P. CAMPINAS
# 696276                        08º D.P. CAMPINAS
# 696312                       20º D.P. AGUA FRIA
# 696491                       DEL.POL.INDAIATUBA
# 696544                              DDM CUBATAO
# 696629                           DEL.POL.SUZANO
# 696733                          01º D.P. GUAIRA
# 696750                         DEL.POL.MIRACATU
# 696831                  83º D.P. PARQUE BRISTOL
# 696962                    67º D.P. JARDIM ROBRU
# 696974                         DEL.POL.CACAPAVA
# 697276                         01º D.P. ITATIBA
# 697518                   98º D.P. JARDIM MIRIAM
# 697765                         04º D.P. DIADEMA
# 697878           DEL.POL.SANTO ANTONIO DE POSSE
# 697911                         02º D.P. JUNDIAI
# 697996             08º D.P. S.BERNARDO DO CAMPO
# 698666                         01º D.P. CUBATAO
# 698781                         04º D.P. LIMEIRA
# 698824                         02º D.P. LIMEIRA
# 698922                        02º D.P. OURINHOS
# 698925                    85º D.P. JARDIM MIRNA
# 699253                 100º D.P. JDIM HERCULANO
# 699694                  83º D.P. PARQUE BRISTOL
# 699696                            07º D.P. LAPA
# 699814                01º D.P. S.CAETANO DO SUL
# 700121                 53º D.P. PARQUE DO CARMO
# 700458                02º D.P. S.CAETANO DO SUL
# 700758                     02º D.P. HORTOLANDIA
# 700786                       05º D.P. GUARULHOS
# 700790                       03º D.P. GUARULHOS
# 700904                       01º D.P. GUARULHOS
# 700984                     04º D.P. SANTO ANDRE
# 701063                        32º D.P. ITAQUERA
# 701087                       07º D.P. GUARULHOS
# 701097                      DEL.POL.PORTO FELIZ
# 701238                           91º D.P. CEASA
# 701334                  DEL.POL.NAZARE PAULISTA
# 701457                       05º D.P. GUARULHOS
# 701472                  01º D.P. EMBU DAS ARTES
# 701480                           DEL.POL.SUZANO
# 701558                    99º D.P. CAMPO GRANDE
# 701756                 53º D.P. PARQUE DO CARMO
# 701890                          DEL.POL.ROSEIRA
# 701909                      49º D.P. SAO MATEUS
# 702311                   74º D.P. PARADA TAIPAS
# 702318                     DEL.POL.FRANCO ROCHA
# 702323                          DEL.POL.ARAMINA
# 702422                       14º D.P. PINHEIROS
# 702544                    DEL.INF.JUV. SOROCABA
# 702723              DEL.POL.S.LOURENCO DA SERRA
# 702900             05º D.P. S.BERNARDO DO CAMPO
# 703034                 69º D.P. TEOTONIO VILELA
# 703053                 64º D.P. CID.AE CARVALHO
# 703132                         01º D.P. CUBATAO
# 703278                           01º D.P. BAURU
# 703340                        06º D.P. CAMPINAS
# 703342                       04º D.P. GUARULHOS
# 703565                        DEL.POL.PROMISSAO
# 703795                        06º D.P. CAMPINAS
# 704208                          05º D.P. SUMARE
# 704483                 75º D.P. JARDIM ARPOADOR
# 704494                  08º D.P. RIBEIRAO PRETO
# 704534                         05º D.P. JUNDIAI
# 704540                         05º D.P. JUNDIAI
# 704621                  90º D.P. PQ. NOVO MUNDO
# 704656                           46º D.P. PERUS
# 704796                             04º D.P. ITU
# 704799               06º D.P. S.JOSE DOS CAMPOS
# 705130                              DEL.POL.POA
# 705214                        70º D.P. VILA EMA
# 705233                   47º D.P. CAPAO REDONDO
# 705351                     DEL.POL.OSVALDO CRUZ
# 705528                        02º D.P. BARRETOS
# 705685                   89º D.P. JARDIM TABOAO
# 705700                         03º D.P. ATIBAIA
# 705723                  DEL.POL.ITAQUAQUECETUBA
# 705746             04º D.P. S.BERNARDO DO CAMPO
# 705885                            DEL.POL.TATUI
# 706017                           DEL.POL.SUZANO
# 706034                       20º D.P. AGUA FRIA
# 706201                         DEL.POL.PEDREIRA
# 706273                  40º D.P. VILA STA MARIA
# 706309             DEL.POL.SANTA MARIA DA SERRA
# 706320                          04º D.P. SUMARE
# 706381                  50º D.P. ITAIM PAULISTA
# 706462                          73º D.P. JACANA
# 706610                 64º D.P. CID.AE CARVALHO
# 707116                        02º D.P. MONGAGUA
# 707238            01º D.P. ITAPECERICA DA SERRA
# 707358                           01º D.P. SALTO
# 707415                 57º D.P. PARQUE DA MOOCA
# 707828                          05º D.P. SUMARE
# 707998                        08º D.P. CAMPINAS
# 708201                            DEL.POL.TATUI
# 708267                       07º D.P. GUARULHOS
# 708284                   47º D.P. CAPAO REDONDO
# 708674                  DEL.POL.VARZEA PAULISTA
# 708875                           46º D.P. PERUS
# 709034                       01º D.P. GUARULHOS
# 709418                      DEL.POL.PORTO FELIZ
# 709535                          DEL.POL.ITUPEVA
# 709571                         DEL.POL.CAIEIRAS
# 709676                   DEL.POL.EMBU DAS ARTES
# 710279                     05º D.P. SANTO ANDRE
# 710601                        13º D.P. CAMPINAS
# 710869                          DEL.POL.GUARUJA
# 710955                           46º D.P. PERUS
# 719449                 100º D.P. JDIM HERCULANO
# 719503                 100º D.P. JDIM HERCULANO
# 719504                          73º D.P. JACANA
# 719818                      63º D.P. VILA JACUI
# 719898                      DEL.POL.NOVA ODESSA
# 720160                         04º D.P. LIMEIRA
# 720259                         04º D.P. DIADEMA
# 720336                     DEL.POL.FRANCO ROCHA

# %% [markdown]
# Podemos escolher uma como prioridade, mas não podemos relacionar uma com a outra com base nos dados que temos, uma vez que existem muitos dados com diferenças não trataveis. Tem DELEGACIA_ELABORAÇÃO não se relaciona diretamente com a
#  DELEGACIA_CIRCUNSCRIÇÃO tem muitos dados em que elas são completamente diferentes

# %% [markdown]
# ### Conversão Flagrante

# %%
# Converte a coluna para string e preenche os valores nulos com "DESCONHECIDO"
df['FLAGRANTE'] = df['FLAGRANTE'].astype('string').fillna('DESCONHECIDO')

# %% [markdown]
# ### Conversão FLAG_VITIMA_FATAL

# %%
# Converte a coluna para string e preenche os valores nulos com "DESCONHECIDO"
df['FLAG_VITIMA_FATAL'] = df['FLAG_VITIMA_FATAL'].astype('string').fillna('DESCONHECIDO')

# %% [markdown]
# ### Conversão de várias colunas para String

# %% [markdown]
# As colunas também tiveram preenchimento dos dados nulos (naN- not a Number) para a string "DESCONHECIDO", para melhor clareza. Segue abaixo lista de colunas convertidas para o tipo string:
#
# * CODIGO_BOLETIM
# * NATUREZA_APURADA
# * PERIODO_OCORRENCIA
# * LOGRADOURO
# * BAIRRO
# * UF
# * TIPO_LOCAL
# * DELEGACIA_ELABORACAO
# * DEPARTAMENTO_ELABORACAO
# * SECCIONAL_ELABORACAO
# * DELEGACIA_CIRCUNSCRICAO
# * DEPARTAMENTO_CIRCUNSCRICAO
# * SECCIONAL_CIRCUNSCRICAO
# * TIPO_PESSOA
# * SEXO_PESSOA
# * COR_PELE
# * PROFISSAO
# * PLACA_VEICULO
# * UF_VEICULO
# * MARCA_VEICULO
# * MODELO_VEICULO
# * TIPO_VEICULO
# * MARCA_CELULAR
# * BO_AUTORIA
# * EXAME
# * SOLUCAO
# * ESPECIE
# * STATUS
# * DESDOBRAMENTO

# %%
colunas = ['CODIGO_BOLETIM', 'NATUREZA_APURADA', 'PERIODO_OCORRENCIA',
           'LOGRADOURO','BAIRRO','UF','TIPO_LOCAL','DELEGACIA_ELABORACAO',
           'DEPARTAMENTO_ELABORACAO','SECCIONAL_ELABORACAO','DELEGACIA_CIRCUNSCRICAO',
           'DEPARTAMENTO_CIRCUNSCRICAO','SECCIONAL_CIRCUNSCRICAO','TIPO_PESSOA',
           'SEXO_PESSOA','COR_PELE','PROFISSAO','PLACA_VEICULO',
           'UF_VEICULO','COR_VEICULO','MARCA_VEICULO','MODELO_VEICULO','TIPO_VEICULO',
           'MARCA_CELULAR','BO_AUTORIA','EXAME','SOLUCAO','ESPECIE',
           'STATUS','DESDOBRAMENTO']  # Lista das colunas a converter

df[colunas] = df[colunas].astype('string').fillna('DESCONHECIDO')

# %% [markdown]
# ### Conversão BO_INICIADO e BO_EMITIDO

# %% [markdown]
# A conversão para datetime permite fazer cálculos e análises com maior facilidade, além de ser possível calcular a diferença entre duas datas diretamente. Além disso podemos facilmente extrair o ano, mês ou dia de uma data.

# %%
df['BO_INICIADO'] = pd.to_datetime(df['BO_INICIADO'], errors='coerce')

# %%
df['BO_EMITIDO'] = pd.to_datetime(df['BO_EMITIDO'], errors='coerce')

# %% [markdown]
# ### Conversão PERIODO_OCORRENCIA

# %% [markdown]
# Realiza o tratamento da coluna `PERIODO_OCORRENCIA` para garantir que todos os valores estejam padronizados e em formato `string`:

# %%
df['PERIODO_OCORRENCIA'] = df['PERIODO_OCORRENCIA'].fillna('DESCONHECIDO').replace('EM HORA INCERTA', 'DESCONHECIDO').astype('string')

# %% [markdown]
# ### Tratamento de veículos diferentes com o mesmo número de boletim

# %% [markdown]
# Percebe-se que existem muitos números de boletins com valores repetidos, dessa maneira utilizamos a coluna PLACA_VEICULO que é um dado único de cada carro para verificar se há números de boletins duplicados devido a se referir a um mesmo crime onde houve mais de um veículo envolvido.

# %%
# Remove linhas com placa nula
df_validas = df[df['PLACA_VEICULO'].notna()]

# Agrupa por NUM_BO e conta quantas placas únicas existem
placas_por_bo = df_validas.groupby('NUM_BO')['PLACA_VEICULO'].nunique()

# Seleciona apenas os NUM_BO com mais de uma placa diferente
bo_multiplos_veiculos = placas_por_bo[placas_por_bo > 1].index

# Filtra o DataFrame original para mostrar esses boletins
resultado = df_validas[df_validas['NUM_BO'].isin(bo_multiplos_veiculos)]

resultado[['NUM_BO', 'PLACA_VEICULO']].head(20)
# Out:
#     NUM_BO PLACA_VEICULO
# 0       21  DESCONHECIDO
# 1      312  DESCONHECIDO
# 2      253  DESCONHECIDO
# 3      305  DESCONHECIDO
# 4        6  DESCONHECIDO
# 5        7  DESCONHECIDO
# 6      125  DESCONHECIDO
# 7      203  DESCONHECIDO
# 8       77  DESCONHECIDO
# 9      289  DESCONHECIDO
# 10      92  DESCONHECIDO
# 11     239  DESCONHECIDO
# 12     239  DESCONHECIDO
# 13     336  DESCONHECIDO
# 14     496  DESCONHECIDO
# 15     132  DESCONHECIDO
# 16     424  DESCONHECIDO
# 17     593  DESCONHECIDO
# 18     128  DESCONHECIDO
# 19     419  DESCONHECIDO

# %% [markdown]
# - Quantos boletins únicos têm mais de um veículo?

# %%
print(resultado['NUM_BO'].nunique())
# Out:
# 13964

# %% [markdown]
# - Quantos veículos únicos (placas distintas)?

# %%
print(resultado['PLACA_VEICULO'].nunique())
# Out:
# 79037

# %% [markdown]
# Como resultado é possível notar que boletins de ocorrência diferentes estão envolvendo o mesmo veículo, e também que os mesmos boletins de ocorrência estão envolvendo veículos diferentes. O que significa pode significar?

# %% [markdown]
# # Tratamento de Duplicatas

# %% [markdown]
# Observamos que muitos registros possuem o mesmo NUM_BO, mas não correspondem ao mesmo crime – provavelmente por conta de erros de digitação. Para identificar registros únicos, não podemos confiar apenas no campo NUM_BO. Assim, optamos por utilizar a combinação das seguintes colunas para diferenciar cada linha única:
#
# - NUM_BO
# - DATA_HORA_ELABORACAO
# - DEPARTAMENTO_ELABORACAO
# - DATA_NASCIMENTO_PESSOA
# - NATUREZA_APURADA
#
# A ideia é agrupar os dados por essas colunas e contar quantas vezes cada combinação ocorre. Identificamos que algumas combinações aparecem mais de uma vez, sendo registros idênticos, o que nos permite removê-los. Para os demais registros, incluímos um identificador específico para garantir que cada BO seja único

# %%
# Lista de valores desconhecidos
valores_nulos_personalizados = ['DESCONHECIDO']

# Função para contar nulos reais + "falsos nulos" do tipo string
def contar_nulos(col):
    return col.isna().sum() + col.isin(valores_nulos_personalizados).sum()

# Aplicar para todas as colunas
nulos = df.apply(contar_nulos).reset_index()
nulos.columns = ['coluna', 'valores_nulos']
nulos['porcentagem_nulos'] = 100 * nulos['valores_nulos'] / len(df)

# Ordenar por quantidade de nulos
nulos = nulos.sort_values(by='valores_nulos', ascending=False)

# Exibir resultado
print(nulos)
# Out:
#                         coluna  valores_nulos  porcentagem_nulos
# 48           FLAG_VITIMA_FATAL         718167          99.688511
# 44                       EXAME         712973          98.967534
# 25                    COR_PELE         701081          97.316809
# 26                   PROFISSAO         700131          97.184940
# 24      DATA_NASCIMENTO_PESSOA         692312          96.099588
# 23                IDADE_PESSOA         691518          95.989373
# 20     SECCIONAL_CIRCUNSCRICAO         691032          95.921911
# 19  DEPARTAMENTO_CIRCUNSCRICAO         691032          95.921911
# 16     DEPARTAMENTO_ELABORACAO         691032          95.921911
# 17        SECCIONAL_ELABORACAO         691032          95.921911
# 49               DESDOBRAMENTO         689324          95.684824
# 22                 SEXO_PESSOA         689219          95.670249
# 21                 TIPO_PESSOA         688944          95.632077
# 29              CIDADE_VEICULO         466184          64.710839
# 28                  UF_VEICULO         465849          64.664337
# 35                TIPO_VEICULO         464049          64.414480
# 32              MODELO_VEICULO         463361          64.318979
# 30                 COR_VEICULO         463005          64.269563
# 27               PLACA_VEICULO         462904          64.255543
# 31               MARCA_VEICULO         462850          64.248047
# 37               QUANT_CELULAR         410582          56.992744
# 36               MARCA_CELULAR         303317          42.103327
# 5              HORA_OCORRENCIA         157312          21.836424
# 14                   LONGITUDE         114127          15.841929
# 13                    LATITUDE         114127          15.841929
# 50                 NOME_CIDADE         111365          15.458537
# 7                       CIDADE         111365          15.458537
# 34                  ANO_MODELO         110702          15.366506
# 6           PERIODO_OCORRENCIA          77935          10.818130
# 8                   LOGRADOURO          53472           7.422430
# 10                      BAIRRO          39786           5.522681
# 33              ANO_FABRICACAO          37242           5.169549
# 42                  BO_AUTORIA          36231           5.029212
# 11                          UF          30172           4.188165
# 46                     ESPECIE          29379           4.078089
# 43                   FLAGRANTE          29379           4.078089
# 41            DATA_COMUNICACAO          29379           4.078089
# 39                  BO_EMITIDO          29379           4.078089
# 38                 BO_INICIADO          29379           4.078089
# 47                      STATUS          29379           4.078089
# 45                     SOLUCAO          29379           4.078089
# 9            NUMERO_LOGRADOURO           2458           0.341194
# 40        DATA_HORA_ELABORACAO            699           0.097028
# 4              DATA_OCORRENCIA            698           0.096889
# 12                  TIPO_LOCAL              7           0.000972
# 18     DELEGACIA_CIRCUNSCRICAO              0           0.000000
# 15        DELEGACIA_ELABORACAO              0           0.000000
# 1                       ANO_BO              0           0.000000
# 0                       NUM_BO              0           0.000000
# 3             NATUREZA_APURADA              0           0.000000
# 2               CODIGO_BOLETIM              0           0.000000

# %%
# Colunas que ajudam a definir o que seria um registro "duplicado"
colunas_chave = ['NUM_BO', 'DEPARTAMENTO_ELABORACAO', 'NATUREZA_APURADA', 'CODIGO_BOLETIM', 'DELEGACIA_CIRCUNSCRICAO', 'TIPO_LOCAL', 'ANO_BO', 'DATA_OCORRENCIA', 'DATA_HORA_ELABORACAO', 'PLACA_VEICULO', 'DATA_NASCIMENTO_PESSOA', 'PERIODO_OCORRENCIA', 'ESPECIE', 'BO_EMITIDO']

# Contar quantas vezes cada combinação aparece
contagens = df.groupby(colunas_chave).size().reset_index(name='count')

# Filtrar duplicatas (ocorrências > 1)
duplicados = contagens[contagens['count'] > 1]

# Somar quantos registros duplicados "a mais" existem
qtd_duplicadas = (duplicados['count'] - 1).sum()

print(f'Número total de registros únicos duplicados: {qtd_duplicadas}')
# Out:
# Número total de registros únicos duplicados: 379

# %% [markdown]
# Exemplo de dado repetido 9 vezes

# %%
df[(df['NUM_BO'] == 6.0) &
   (df['DATA_HORA_ELABORACAO'] == '2022-03-01 17:24:57') &
   (df['DEPARTAMENTO_ELABORACAO'] == 'DESCONHECIDO') &
   (df['DATA_NASCIMENTO_PESSOA'] == '2002-06-01') &
   (df['NATUREZA_APURADA'] == 'HOMICIDIO SIMPLES (ART. 121)')]
# Out:
#         NUM_BO  ANO_BO CODIGO_BOLETIM              NATUREZA_APURADA  \
# 30201        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 30202        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 30203        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 30204        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 30205        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 30206        6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 674681       6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 674682       6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
# 674683       6    2022         6/2022  HOMICIDIO SIMPLES (ART. 121)
#
#        DATA_OCORRENCIA HORA_OCORRENCIA PERIODO_OCORRENCIA   CIDADE  \
# 30201       2022-03-01        00:30:00            A TARDE  3515707
# 30202       2022-03-01        00:30:00            A TARDE  3515707
# 30203       2022-03-01        00:30:00            A TARDE  3515707
# 30204       2022-03-01        00:30:00            A TARDE  3515707
# 30205       2022-03-01        00:30:00            A TARDE  3515707
# 30206       2022-03-01        00:30:00            A TARDE  3515707
# 674681      2022-03-01        00:30:00            A TARDE  3515707
# 674682      2022-03-01        00:30:00            A TARDE  3515707
# 674683      2022-03-01        00:30:00            A TARDE  3515707
#
#                LOGRADOURO  NUMERO_LOGRADOURO             BAIRRO  UF  \
# 30201   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 30202   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 30203   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 30204   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 30205   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 30206   RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 674681  RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 674682  RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
# 674683  RUA DOS PEDREIROS               59.0  CIDADE TIRADENTES  SP
#
#          TIPO_LOCAL  LATITUDE  LONGITUDE DELEGACIA_ELABORACAO  \
# 30201   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 30202   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 30203   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 30204   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 30205   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 30206   VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 674681  VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 674682  VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
# 674683  VIA PUBLICA -23.60437 -46.398959  44º D.P. GUAIANAZES
#
#        DEPARTAMENTO_ELABORACAO SECCIONAL_ELABORACAO   DELEGACIA_CIRCUNSCRICAO  \
# 30201             DESCONHECIDO         DESCONHECIDO  54º D.P. CID. TIRADENTES
#
022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 30202   2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 30203   2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 30204   2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 30205   2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 30206   2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 674681  2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 674682  2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
# 674683  2022-03-01 17:24:57       2022-03-01  CONHECIDA       SIM
#
#                EXAME            SOLUCAO                              ESPECIE  \
# 30201   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 30202   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 30203   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 30204   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 30205   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 30206   DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 674681  DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 674682  DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
# 674683  DESCONHECIDO  BO PARA FLAGRANTE  TITULO I - PESSOA (ARTS. 121 A 154)
#
#            STATUS FLAG_VITIMA_FATAL  \
# 30201   CONSUMADO               SIM
# 30202   CONSUMADO               SIM
# 30203   CONSUMADO               SIM
# 30204   CONSUMADO               SIM
# 30205   CONSUMADO               SIM
# 30206   CONSUMADO               SIM
# 674681  CONSUMADO               SIM
# 674682  CONSUMADO               SIM
# 674683  CONSUMADO               SIM
#
#                                                               DESDOBRAMENTO  \
# 30201   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 30202   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 30203   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 30204   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 30205   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 30206   MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 674681  MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 674682  MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
# 674683  MORTE DECORRENTE DE INTERVENCAO POLICIAL (RES. SSP 05 - 07/01/2013)
#
#                   NOME_CIDADE
# 30201   Ferraz de Vasconcelos
# 30202   Ferraz de Vasconcelos
# 30203   Ferraz de Vasconcelos
# 30204   Ferraz de Vasconcelos
# 30205   Ferraz de Vasconcelos
# 30206   Ferraz de Vasconcelos
# 674681  Ferraz de Vasconcelos
# 674682  Ferraz de Vasconcelos
# 674683  Ferraz de Vasconcelos

# %% [markdown]
# Eliminação de duplicadas

# %%
# Colunas que ajudam a definir o que seria um registro "duplicado"
colunas_chave = ['NUM_BO', 'DEPARTAMENTO_ELABORACAO', 'NATUREZA_APURADA', 'CODIGO_BOLETIM', 'DELEGACIA_CIRCUNSCRICAO', 'TIPO_LOCAL',
                 'ANO_BO', 'DATA_OCORRENCIA', 'DATA_HORA_ELABORACAO', 'PLACA_VEICULO', 'DATA_NASCIMENTO_PESSOA',
                 'PERIODO_OCORRENCIA', 'ESPECIE', 'BO_EMITIDO']

# Remover duplicatas, mantendo apenas a primeira ocorrência de cada combinação completa
df_sem_duplicatas = df.drop_duplicates(subset=colunas_chave, keep='first')

# Conferindo quantos dados foram realmente removidos
print(f'Antes: {df.shape[0]}')
print(f'Depois: {df_sem_duplicatas.shape[0]}')
print(f'Redução real: {df.shape[0] - df_sem_duplicatas.shape[0]}')
# Out:
# Antes: 720411
# Depois: 630711
# Redução real: 89700

# %% [markdown]
# Cria um idetificador unico do BO

# %%
# Resetar o índice para garantir que ele seja sequencial
df = df.reset_index(drop=True)

# Criar uma nova coluna 'ID_BO' que contém um identificador único para cada registro
df['ID_BO'] = df.index + 1

# Exibir as primeiras linhas do DataFrame para conferir
df.head()
# Out:
#    NUM_BO  ANO_BO CODIGO_BOLETIM  NATUREZA_APURADA DATA_OCORRENCIA  \
# 0      21    2022        21/2022  HOMICIDIO DOLOSO      2021-12-31
# 1     312    2022       312/2022  HOMICIDIO DOLOSO      2022-01-20
# 2     253    2022       253/2022  HOMICIDIO DOLOSO      2022-01-16
# 3     305    2022       305/2022  HOMICIDIO DOLOSO      2022-01-22
# 4       6    2022         6/2022  HOMICIDIO DOLOSO      2022-01-01
#
#   HORA_OCORRENCIA PERIODO_OCORRENCIA        CIDADE  \
# 0        15:40:00            A TARDE  DESCONHECIDO
# 1        07:00:00         PELA MANHA       3550308
# 2        05:48:00       DE MADRUGADA       3550308
# 3        19:50:00       DESCONHECIDO       3550308
# 4             NaN       DESCONHECIDO       3550308
#
#                                      LOGRADOURO  NUMERO_LOGRADOURO  \
# 0  DA VEDACAO DA DIVULGACAO DOS DADOS RELATIVOS                NaN
# 1                             PRACA DA BANDEIRA               10.0
# 2                                    RUA PRATES              536.0
# 3                                   RUA GUARANI              427.0
# 4                            PRACA DA REPUBLICA                9.0
#
#          BAIRRO            UF   TIPO_LOCAL   LATITUDE  LONGITUDE  \
# 0  DESCONHECIDO  DESCONHECIDO   RESIDENCIA        NaN        NaN
# 1  DESCONHECIDO  DESCONHECIDO  VIA PUBLICA -23.550235 -46.639255
# 2  DESCONHECIDO  DESCONHECIDO  VIA PUBLICA -23.525989 -46.634852
# 3  DESCONHECIDO  DESCONHECIDO  VIA PUBLICA -23.528916 -46.633914
# 4  DESCONHECIDO  DESCONHECIDO  VIA PUBLICA -23.542956 -46.641287
#
#       DELEGACIA_ELABORACAO DEPARTAMENTO_ELABORACAO SECCIONAL_ELABORACAO  \
# 0  DEL.POL.PLANTAO BIRIGUI  DEINTER 10 - ARACATUBA    DEL.SEC.ARACATUBA
# 1            08º D.P. BRAS                   DECAP    DEL.SEC.1º CENTRO
# 2      02º D.P. BOM RETIRO                   DECAP    DEL.SEC.1º CENTRO
# 3      02º D.P. BOM RETIRO                   DECAP    DEL.SEC.1º CENTRO
# 4      02º D.P. BOM RETIRO                   DECAP    DEL.SEC.1º CENTRO
#
#    DELEGACIA_CIRCUNSCRICAO DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO  \
# 0             DM - BIRIGUI                 DEINTER 10           SEC ARACATUBA
# 1              001 DP - SE                      DECAP                  1ª SEC
# 2      002 DP - BOM RETIRO                      DECAP                  1ª SEC
# 3      002 DP - BOM RETIRO                      DECAP                  1ª SEC
# 4  003 DP - CAMPOS ELISIOS                      DECAP                  1ª SEC
#
#   TIPO_PESSOA SEXO_PESSOA  IDADE_PESSOA DATA_NASCIMENTO_PESSOA COR_PELE  \
# 0      VITIMA    FEMININO          55.0             1966-08-15    PARDA
# 1      VITIMA   MASCULINO          34.0             1987-02-15    PARDA
# 2      VITIMA   MASCULINO          21.0             2000-06-10    PARDA
# 3      VITIMA   MASCULINO          48.0             1974-01-06    PARDA
# 4      VITIMA   MASCULINO           NaN                    NaT    PARDA
#
#       PROFISSAO PLACA_VEICULO    UF_VEICULO CIDADE_VEICULO   COR_VEICULO  \
# 0  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO   DESCONHECIDO  DESCONHECIDO
# 1  DESEMPREGADO  DESCONHECIDO  DESCONHECIDO   DESCONHECIDO  DESCONHECIDO
# 2  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO   DESCONHECIDO  DESCONHECIDO
# 3   AUTONOMO(A)  DESCONHECIDO  DESCONHECIDO   DESCONHECIDO  DESCONHECIDO
# 4  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO   DESCONHECIDO  DESCONHECIDO
#
#   MARCA_VEICULO MODELO_VEICULO  ANO_FABRICACAO  ANO_MODELO  TIPO_VEICULO  \
# 0  DESCONHECIDO   DESCONHECIDO             NaN         NaN  DESCONHECIDO
# 1  DESCONHECIDO   DESCONHECIDO             NaN         NaN  DESCONHECIDO
# 2  DESCONHECIDO   DESCONHECIDO             NaN         NaN  DESCONHECIDO
# 3  DESCONHECIDO   DESCONHECIDO             NaN         NaN  DESCONHECIDO
# 4  DESCONHECIDO   DESCONHECIDO             NaN         NaN  DESCONHECIDO
#
#   MARCA_CELULAR  QUANT_CELULAR BO_INICIADO BO_EMITIDO DATA_HORA_ELABORACAO  \
# 0  DESCONHECIDO            NaN         NaT        NaT  2021-12-31 00:00:00
# 1  DESCONHECIDO            NaN         NaT        NaT  2022-01-20 09:45:00
# 2  DESCONHECIDO            NaN         NaT        NaT  2022-01-16 00:00:00
# 3  DESCONHECIDO            NaN         NaT        NaT  2022-01-22 00:00:00
# 4  DESCONHECIDO            NaN         NaT        NaT  2022-01-01 00:00:00
#
#   DATA_COMUNICACAO    BO_AUTORIA     FLAGRANTE         EXAME       SOLUCAO  \
# 0              NaT  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
# 1              NaT  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
# 2              NaT  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
# 3              NaT  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
# 4              NaT  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
#
#         ESPECIE        STATUS FLAG_VITIMA_FATAL DESDOBRAMENTO   NOME_CIDADE  \
# 0  DESCONHECIDO  DESCONHECIDO      DESCONHECIDO  DESCONHECIDO  DESCONHECIDO
# 1  DESCONHECIDO  DESCONHECIDO      DESCONHECIDO  DESCONHECIDO     São Paulo
# 2  DESCONHECIDO  DESCONHECIDO      DESCONHECIDO  DESCONHECIDO     São Paulo
# 3  DESCONHECIDO  DESCONHECIDO      DESCONHECIDO  DESCONHECIDO     São Paulo
# 4  DESCONHECIDO  DESCONHECIDO      DESCONHECIDO  DESCONHECIDO     São Paulo
#
#    ID_BO
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5

# %% [markdown]
# # Tratamento de Dados

# %% [markdown]
# ### Espaço extras e em branco

# %% [markdown]
# Nesse trecho, foi feita a alteração de espaço extras e em branco em colunas do tipo object e string pela string "DESCONHECIDO", devido a uma melhor interpretação.

# %%
#Passo 1: Selecionar colunas de TEXTO (onde pode haver espaços em branco no lugar de dados ou NaN)
colunas_texto = df.select_dtypes(include=['object', 'string']).columns

#Passo 2: Substituir por DESCONHECIDO
for coluna in colunas_texto:
    df[coluna] = df[coluna].replace(r'^\s*$', 'DESCONHECIDO', regex=True)

#Passo 3: Remover espaços extras no inicio e final de strings para ficar mais "uniforme"
for coluna in colunas_texto:
    df[coluna] = df[coluna].str.strip()

# %% [markdown]
# ### Estimativa do Período da Ocorrência

# %% [markdown]
# Uma função `atribuir_periodo` é definida para estimar o período do dia com base na hora da ocorrência. Essa função é aplicada para preencher valores nulos na coluna `PERIODO_OCORRENCIA`.

# %%
def atribuir_periodo(hora):
    """
    Função que recebe uma string de hora e retorna o período do dia.
    Caso a hora não seja válida, retorna 'EM HORA INCERTA'.
    """
    try:
        # Converte a string para um objeto datetime e extrai a hora
        hora_convertida = pd.to_datetime(hora, format="%H:%M:%S")
        hora_valor = hora_convertida.hour
    except Exception:
        # Se não conseguir converter, retorna NaN
        return pd.NA

    # Define os períodos com base na hora
    if 0 <= hora_valor < 6:
        return "DE MADRUGADA"
    elif 6 <= hora_valor < 12:
        return "PELA MANHA"
    elif 12 <= hora_valor < 18:
        return "A TARDE"
    elif 18 <= hora_valor <= 23:
        return "A NOITE"
    else:
        return "EM HORA INCERTA"

# %% [markdown]
# Aplica a função "atribuir_periodo" que passa como parâmetro a linha HORA_OCORRENCIA, o retorno é escrito na coluna PERIODO_OCORRENCIA se for um valor nulo, fazendo uma boa estimativa do possível período da ocorrência.

# %%
# Preenche somente os valores nulos de PERIODO_OCORRENCIA
df['PERIODO_OCORRENCIA'] = df.apply(
    lambda row: atribuir_periodo(row['HORA_OCORRENCIA']) if pd.isna(row['PERIODO_OCORRENCIA']) else row['PERIODO_OCORRENCIA'],
    axis=1)

# %% [markdown]
# ### Outliers

# %% [markdown]
# ### Deletando outlier de Idade

# %%
#Deletando possível outlier considerando a idade e também muitos valores nulos
df.drop(df[df['IDADE_PESSOA'] == 122.0].index, inplace=True)

# %% [markdown]
# ### Deletando outlier de DATA_OCORRENCIA

# %% [markdown]
# Foi identificado no código anos que poderia ser identificados como possíveis outliers, como o ano 1700. Dessa maneira, o grupo decidiu remover dados com anos inferiores há 2000, tendo em vista que são poucos.

# %%
(df['DATA_OCORRENCIA'].dt.year < 2000).sum()
# Out:
# np.int64(243)

# %% [markdown]
# ### Outliers de datas

# %%
# Filtrar para manter apenas datas a partir do ano 1900
df = df[df["DATA_OCORRENCIA"].dt.year >= 1900]

# %% [markdown]
# Verificando se outras datas estão com anos anteriores ao ano 1900.

# %%
(df['DATA_COMUNICACAO'].dt.year < 1900).sum()
# Out:
# np.int64(0)

# %%
(df['DATA_HORA_ELABORACAO'].dt.year < 1900).sum()
# Out:
# np.int64(0)

# %%
df['DATA_OCORRENCIA'].value_counts()
# Out:
# DATA_OCORRENCIA
# 2022-06-19    4001
# 2022-12-04    3656
# 2022-12-05    3090
# 2022-10-30    3071
# 2022-11-30    3036
# 2022-09-30    3017
# 2022-02-12    2997
# 2022-11-17    2993
# 2022-11-24    2984
# 2022-09-11    2938
# 2022-12-17    2921
# 2022-02-09    2792
# 2022-06-10    2774
# 2022-05-20    2774
# 2022-10-22    2714
# 2022-10-14    2700
# 2022-10-26    2689
# 2022-10-11    2674
# 2022-12-16    2672
# 2022-07-12    2663
# 2022-11-19    2657
# 2022-01-12    2647
# 2022-03-25    2644
# 2022-10-21    2631
# 2022-03-11    2622
# 2022-11-18    2614
# 2022-12-15    2602
# 2022-09-06    2589
# 2022-08-11    2587
# 2022-04-11    2585
# 2022-08-10    2581
# 2022-11-10    2580
# 2022-12-14    2576
# 2022-10-29    2574
# 2022-07-10    2565
# 2022-01-10    2560
# 2022-09-09    2558
# 2022-12-13    2542
# 2022-11-16    2541
# 2022-09-29    2535
# 2022-10-19    2525
# 2022-08-26    2519
# 2022-09-12    2518
# 2022-10-20    2517
# 2022-09-22    2515
# 2011-12-11       1
# 2018-10-24       1
# 2017-08-15       1
# 2000-11-02       1
# 2019-01-04       1
# 2010-10-03       1
# 2020-10-23       1
# 2020-11-09       1
# 2017-06-10       1
# 2014-07-22       1
# 2016-10-08       1
# 2007-08-16       1
# Name: count, dtype: int64

# %% [markdown]
# # Criação de novos Atributos

# %% [markdown]
# ## Faixa etária de idades

# %% [markdown]
# A criação do atributo `FAIXA_ETARIA` permite categorizar os indivíduos em "MENOR", "ADULTO" e "IDOSO" com base na idade, por meio da funçao faixa_etaria.

# %%
def faixa_etaria(idade):
    if idade < 18:
        return 'MENOR'
    elif idade < 60:
        return 'ADULTO'
    else:
        return 'IDOSO'

df['FAIXA_ETARIA'] = df['IDADE_PESSOA'].apply(faixa_etaria)
df['FAIXA_ETARIA'].value_counts()
# Out:
# FAIXA_ETARIA
# IDOSO     702480
# ADULTO     15905
# MENOR       1325
# Name: count, dtype: int64

# %%
# Verificar se há NaN na coluna 'DATA_OCORRENCIA'
nan_data_ocorrencia = df['DATA_OCORRENCIA'].isna()

# Exibir as linhas que contêm NaN na coluna 'DATA_OCORRENCIA'
#print(df[nan_data_ocorrencia])

df = df.dropna(subset=['DATA_OCORRENCIA'])

# %% [markdown]
# ## Dia da semana

# %% [markdown]
# A conversão da data de ocorrência para o dia da semana e o mapeamento para nomes para ajudar na análise temporal dos dados, considerando que há uma pergunta criada que utilizará essa informação.

# %%
# Cria coluna do dia da semana:
dias_da_semana = {
    'Monday': 'SEGUNDA-FEIRA',
    'Tuesday': 'TERÇA-FEIRA',
    'Wednesday': 'QUARTA-FEIRA',
    'Thursday': 'QUINTA-FEIRA',
    'Friday': 'SEXTA-FEIRA',
    'Saturday': 'SÁBADO',
    'Sunday': 'DOMINGO'
}

df['DIA_OCORRENCIA'] = df['DATA_OCORRENCIA'].dt.day_name()
df['DIA_OCORRENCIA'] = df['DIA_OCORRENCIA'].map(dias_da_semana)
df['DIA_OCORRENCIA'].head(10)
# Out:
# 0      SEXTA-FEIRA
# 1     QUINTA-FEIRA
# 2          DOMINGO
# 3           SÁBADO
# 4           SÁBADO
# 5           SÁBADO
# 6          DOMINGO
# 7    SEGUNDA-FEIRA
# 8     QUINTA-FEIRA
# 9    SEGUNDA-FEIRA
# Name: DIA_OCORRENCIA, dtype: object

# %% [markdown]
# ## Data Hora Ocorrência

# %% [markdown]
# Foi criada uma nova coluna chamada DATA_HORA_OCORRENCIA que combina os dados de DATA_OCORRENCIA e HORA_OCORRENCIA, pois pode facilitar a análise de dados para responder uma das perguntas criadas. Facilita extrair as componentes da data, o cálculo de diferença de datas e também possibilita filtrar dados de maneira mais eficiente (podemos por exemplo filtrar por hora).

# %%
df['DATA_HORA_OCORRENCIA'] = pd.to_datetime(
    df['DATA_OCORRENCIA'].astype(str) + ' ' + df['HORA_OCORRENCIA'].astype(str),
    errors='coerce'
)

# %% [markdown]
# ## Conversão DIA_OCORRENCIA e FAIXA_ETARIA

# %% [markdown]
# Como esses dois atributos (`DIA_OCORRENCIA` e `FAIXA_ETARIA`) foram criados após o tratamento, suas respectivas conversões precisam estar depois de suas declarações.

# %%
colunas = ['DIA_OCORRENCIA','FAIXA_ETARIA']  # Lista das colunas a converter

df[colunas] = df[colunas].astype('string').fillna('DESCONHECIDO')

# %% [markdown]
# ## Tipos de dados após conversões

# %%
df.dtypes
# Out:
# NUM_BO                                 int64
# ANO_BO                                 int64
# CODIGO_BOLETIM                string[python]
# NATUREZA_APURADA              string[python]
# DATA_OCORRENCIA               datetime64[ns]
# HORA_OCORRENCIA                       object
# PERIODO_OCORRENCIA                    object
# CIDADE                        string[python]
# LOGRADOURO                    string[python]
# NUMERO_LOGRADOURO                    float64
# BAIRRO                        string[python]
# UF                            string[python]
# TIPO_LOCAL                    string[python]
# LATITUDE                             float64
# LONGITUDE                            float64
# DELEGACIA_ELABORACAO          string[python]
# DEPARTAMENTO_ELABORACAO       string[python]
# SECCIONAL_ELABORACAO          string[python]
# DELEGACIA_CIRCUNSCRICAO       string[python]
# DEPARTAMENTO_CIRCUNSCRICAO    string[python]
# SECCIONAL_CIRCUNSCRICAO       string[python]
# TIPO_PESSOA                   string[python]
# SEXO_PESSOA                   string[python]
# IDADE_PESSOA                         float64
# DATA_NASCIMENTO_PESSOA        datetime64[ns]
# COR_PELE                      string[python]
# PROFISSAO                     string[python]
# PLACA_VEICULO                 string[python]
# UF_VEICULO                    string[python]
# CIDADE_VEICULO                        object
# COR_VEICULO                   string[python]
# MARCA_VEICULO                 string[python]
# MODELO_VEICULO                string[python]
# ANO_FABRICACAO                       float64
# ANO_MODELO                           float64
# TIPO_VEICULO                  string[python]
# MARCA_CELULAR                 string[python]
# QUANT_CELULAR                        float64
# BO_INICIADO                   datetime64[ns]
# BO_EMITIDO                    datetime64[ns]
# DATA_HORA_ELABORACAO          datetime64[ns]
# DATA_COMUNICACAO              datetime64[ns]
# BO_AUTORIA                    string[python]
# FLAGRANTE                     string[python]
# EXAME                         string[python]
# SOLUCAO                       string[python]
# ESPECIE                       string[python]
# STATUS                        string[python]
# FLAG_VITIMA_FATAL             string[python]
# DESDOBRAMENTO                 string[python]
# NOME_CIDADE                           object
# ID_BO                                  int64
# FAIXA_ETARIA                  string[python]
# DIA_OCORRENCIA                string[python]
# DATA_HORA_OCORRENCIA          datetime64[ns]
# dtype: object

# %% [markdown]
# ## Natureza apurada

# %% [markdown]
# ### Criação das máscaras para filtragem

# %%
# Crimes contra a Pessoa
CrimesPessoa = [
    "PERTURBACAO DO TRABALHO",
    "HOMICIDIO DOLOSO",
    "HOMICIDIO SIMPLES (ART. 121)",
    "HOMICIDIO QUALIFICADO (ART. 121, §2O.)",
    "HOMICIDIO CULPOSO NA DIRECAO DE VEICULO AUTOMOTOR (ART. 302)",
    "LESAO CORPORAL (ART. 129)",
    "LESAO CORPORAL (ART 129 § 9º)",
    "LESAO CORPORAL CULPOSA NA DIRECAO DE VEICULO AUTOMOTOR (ART. 303)",
    "LESAO CORPORAL CULPOSA (ART. 129. §6O.)",
    "LESAO CORPORAL SEGUIDA DE MORTE (ART. 129, §3O.)",
    "AUTO LESAO",
    "ESTUPRO (ART. 213)",
    "A.I.-ESTUPRO (ART.213)",
    "ART. 213 - ESTUPRO",
    "ART. 215A - IMPORTUNACAO SEXUAL",
    "UTILIZAR-SE DE CRIANCA OU ADOLESCENTE EM CENA DE SEXO EXPLICITO (ART. 240)",
    "VIOLENCIA DOMESTICA",
    "VIOLENCIA PSICOLOGICA CONTRA A MULHER (ART. 147-B)",
    "AMEACA (ART. 147)",
    "A.I.-AMEACA (ART. 147)",
    "PERSEGUIR (ART. 147-A)",
    "SEQÜESTRO E CARCERE PRIVADO (ART. 148)",
    "OMISSAO DE SOCORRO (ART. 304)",
    "VIOLACAO DE DOMICILIO (ART. 150)",
    "ATROPELAMENTO",
    "FUGA CONSUMADA",
    "DESAPARECIMENTO DE PESSOA",
    "ABANDONAR IDOSO OU NAO PROVER SUAS NECESSIDADES ( ART.98)",
    "APROPRIAR-SE DE BENS DO IDOSO (ART. 102)",
    "VIAS DE FATO (ART. 21)",
    "DESCUMPRIMENTO DE MEDIDA PROTETIVA DE URGENCIA (ART. 24-A)",
    "A.I.-INJURIA REAL (ART. 140, §2O.)",
    "ESTUPRO DE VULNERAVEL (ART.217-A)",
    "A.I.-HOMICIDIO SIMPLES (ART. 121)",
    "A.I.-LESAO CORPORAL (ART. 129 §12)",
    "EVASAO MEDIANTE VIOLENCIA CONTRA A PESSOA (ART. 352)",
    "TORTURA (ART. 1º)",
    "PERIGO PARA A VIDA OU SAUDE DE OUTREM (ART. 132)",
    "ART. 216A - ASSEDIO SEXUAL",
    "88-PRATICAR, INDUZIR OU INCITAR DISCRIMINACAO DE PESSOA",
    "CONSTRANGIMENTO ILEGAL",
    "A.I. LESAO CORPORAL",
    "ABANDONO DE INCAPAZ (ART. 133)",
    "PRATICAR A DISCRIMINACAO",
    "V - DIVULGAR A CONDICAO DO PORTADOR DO HIV OU DE DOENTE DE AIDS, COM INTUITO",
    "A.I.-ESTUPRO (ART.213)	"
]
maskPessoa = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesPessoa))

# Crimes contra o Patrimônio
CrimesPatrimoniais = [
    # Furtos e variantes
    "FURTO",
    "FURTO (ART. 155) - INTERIOR DE VEICULO",
    "FURTO (ART. 155) - TRANSEUNTE",
    "FURTO (ART. 155) - OUTROS",
    "FURTO (ART. 155) - ESTABELECIMENTO COMERCIAL",
    "FURTO (ART. 155) - VEICULO",
    "FURTO QUALIFICADO (ART. 155, §4O.) - INTERIOR DE VEICULO",
    "FURTO QUALIFICADO (ART. 155, §4O.) - RESIDENCIA",
    "FURTO (ART. 155) - RESIDENCIA",
    "FURTO QUALIFICADO (ART. 155, §4O.) - ESTABELECIMENTO COMERCIAL",
    "FURTO (ART. 155) - APLICATIVO DE MOBILIDADE URBANA",
    "FURTO (ART. 155) - CONDOMINIO RESIDENCIAL",
    "A.I.-FURTO (ART. 155) - RESIDENCIA",
    "FURTO (ART. 155) - INTERIOR ESTABELECIMENTO",
    "FURTO QUALIFICADO (ART. 155, §4O.) - OUTROS",
.I.-FURTO QUALIFICADO (ART. 155, §4O.) - OUTROS",
    "A.I.-FURTO QUALIFICADO (ART. 155, §4O.) - INTERIOR ESTABELECIMENTO",
    "FURTO (ART. 155) - VEICULO COMPARTILHADO",
    "FURTO QUALIFICADO (ART. 155, §4O.) - CONDOMINIO COMERCIAL",
    "EXTORSAO",
    "EXTORSAO (ART. 158) - PESSOA",
    "A.I.-FURTO (ART. 155) - CARGA",
    "RECEPTACAO (ART. 180) - OUTROS",
    "RECEPTACAO (ART. 180) - VEICULO",
    "RECEPTACAO QUALIFICADA (ART. 180, §1O.) - VEICULO",
    "RECEPTACAO QUALIFICADA (ART. 180, §1O.) - CARGA",
    "RECEPTACAO CULPOSA (ART. 180, §3O.) - OUTROS",
    "SUPRESSAO DE DOCUMENTO (ART. 305)",
    "RETENCAO DE DOCUMENTO (ART. 3º)",
    "ALTERACAO DE LIMITES (ART. 161)",
    "CAPOTAMENTO",
    "ABALROAMENTO",
    "REPRODUCAO OU ADULTERACAO DE SELO OU PECA FILATELICA (ART. 303)",
    "FURTO (ART. 155) - JOALHERIA",
    "FURTO (ART. 155) - CARGA",
    "FURTO (ART. 155)",
    "A.I.-FURTO (ART. 155) - OUTROS",
    "DANO EM COISA DE VALOR ARTISTICO, ARQUEOLOGICO OU HISTORICO (ART. 165)"
]
maskPatrimonial = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesPatrimoniais))

# Crimes contra a Administração Pública
CrimesAdmin = [
    "CORRUPCAO ATIVA (ART. 333)",
    "ASSOCIACAO CRIMINOSA (ART. 288)",
    "FRAUDE PROCESSUAL (ART. 347)",
    "FALSIDADE IDEOLOGICA (ART. 299)",
    "FRAUDES E ABUSOS NA FUNDACAO OU ADMINISTRACAO DE SOCIEDADE POR ACOES (ART. 177)",
    "CAPUT CORROMPER OU FACILITAR A CORRUPCAO DE MENOR DE 18 ANOS (244B)",
    "A.I.-ART 2º - PROMOVER, CONSTITUIR, FINANCIAR OU INTEGRAR ORGANIZACAO CRIMINOSA",
    "ASSOCIAREM-SE DUAS OU MAIS PESSOAS - ARTS. 33, CAPUT E § 1O, E 34 (ART.35,CAPUT)",
    "FALSIFICACAO DE DOCUMENTO PUBLICO (ART. 297)",
    "A.I.-DIRIGIR SEM PERMISSAO OU HABILITACAO (ART. 309)",
    "EMBRIAGUEZ AO VOLANTE (ART. 306)",
    "A.I.-ADULTERACAO DE SINAL IDENTIFICADOR DE VEICULO AUTOMOTOR (ART. 311)",
    "FAVORECIMENTO PESSOAL (ART. 348)",
    "OUTRAS FRAUDES (ART. 176)",
    "ADULTERACAO DE SINAL IDENTIFICADOR DE VEICULO AUTOMOTOR (ART. 311)",
    "PERMITIR DIRECAO DE VEICULO AUTOMOTOR A PESSOA NAO HABILITADA (ART. 310)",
    "CORRUPCAO DE MENORES (ART. 218)",
    "USURPACAO DE FUNCAO PUBLICA (ART. 328)",
    "FRAUDES E ABUSOS NA FUNDACAO OU ADMINISTRACAO DE SOCIEDADE POR ACOES (ART. 177)",
    "A.I.-USO DE DOCUMENTO FALSO (ART. 304)",
    "A.I.-FALSA IDENTIDADE (ART. 307)",
    "COACAO NO CURSO DO PROCESSO",
    "RESISTENCIA (ART. 329)"
]
maskAdmin = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesAdmin))

# Crimes Ambientais
CrimesAmbientais = [
    "MATAR ESPECIMES DA FAUNA SILVESTRE (ART. 29)",
    "TOMBAMENTO",
    "PRATICAR ATO DE ABUSO A ANIMAIS (ART. 32)"
]
maskAmbientais = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesAmbientais))

# Crimes de Imprensa e Contra a Honra
CrimesImprensaHonra = [
    "CALUNIA (ART. 138)",
    "INJURIA (ART. 140)",
    "DIFAMACAO (ART. 139)",
    "DENUNCIACAO CALUNIOSA (ART. 339)",
    "COMUNICACAO FALSA DE CRIME OU CONTRAVENCAO (ART. 340)",
    "DESACATO (ART. 331)",
    "A.I.-INJURIA (ART. 140)",
    "DIVULGACAO DE CENA DE ESTUPRO E IMAGENS DE NUDEZ, SEXO OU PORNOGRAFIA(ART.218-C)",
    "USO ILEGITIMO DE UNIFORME OU DISTINTIVO (ART. 46)"
]
maskImprensaHonra = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesImprensaHonra))

# Crimes contra a Propriedade Imaterial
CrimesPropriedadeImaterial = [
    "FALSIFICACAO DE DOCUMENTO PARTICULAR OU FALSIFICACAO DE CARTAO",
    "USO DE DOCUMENTO FALSO (ART. 353)",
    "USO DE DOCUMENTO FALSO (ART. 304)",
    "FALSIFICACAO DE SELO OU SINAL PUBLICO (ART. 296)",
    "REPRODUCAO OU ADULTERACAO DE SELO OU PECA FILATELICA (ART. 303)"
]
maskPropriedadeImaterial = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in CrimesPropriedadeImaterial))

# Itens que não se encaixam claramente nas categorias acima
Outros = [
    "MORTE SUSPEITA",
    "OUTROS NAO CRIMINAL",
    "PENDENTE DE VALIDACAO",
    "INDEFERIDO",
    "ESTRITO CUMPRIMENTO DEVER LEGAL (ART. 23, III)",
    "LEGITIMA DEFESA (ART. 23, II)",
    "INVASAO DE DISPOSITIVO INFORMATICO",
    "DELITOS DE INFORMATICA",
    "FUGA DE LOCAL DE ACIDENTE (ART. 305)",
    "CAPTURA DE PROCURADO",
    "EXERCICIO ARBITRARIO DAS PROPRIAS RAZOES (ART. 345)",
    "MAUS-TRATOS (ART. 136)",
    "ESTADO DE NECESSIDADE (ART. 23, I)",
    "INVADIR OU ADENTRAR, CLANDESTINA OU ASTUCIOSAMENTE, OU A REVELIA DA... (ART.22)",
    "EXCESSO NA COBRANCA DE DIVIDAS (ART. 71)",
    "USURA PECUNIARIA OU REAL (ART. 4º)",
    "COMUNICACAO DE OBITO",
    "QUEDA ACIDENTAL",
    "ENCONTRO DE PESSOA",
    "RETER CARTAO MAGNETICO OU OUTRO DOCUMENTO (ART. 104)",
    "CHOQUE",
    "DROGAS PARA CONSUMO PESSOAL SEM AUTORIZACAO OU EM DESACORDO (ART.28,CAPUT)",
    "POSSE IRREGULAR DE ARMA DE FOGO DE USO PERMITIDO (ART.16)",
    "DROGAS SEM AUTORIZACAO OU EM DESACORDO (ART.33, CAPUT)",
    "AUTO-ACUSACAO FALSA (ART. 341)",
    "COMUNICACAO DE OBITO",
    "POSSE OU PORTE ILEGAL DE ARMA DE FOGO DE USO RESTRITO (ART. 16)",
    "DISPARO DE ARMA DE FOGO (ART. 15)",
    "TRAFEGAR EM VELOCIDADE INCOMPATIVEL (ART. 311)",
    "A.I.-DESACATO (ART. 331)",
    "FALSIFICACAO DE SELO OU SINAL PUBLICO (ART. 296)",
    "SUICIDIO TENTADO",
    "RECEPTACAO (ART. 180)",
    "ENCONTRO DE PESSOA",
    "A.I.-DROGAS PARA CONSUMO PESSOAL SEM AUTORIZACAO OU EM DESACORDO (ART.28,CAPUT)",
    "DISPARO DE ARMA DE FOGO (ART. 28)",
    "EXCESSO NA COBRANCA DE DIVIDAS (ART. 71)",
    "COMUNICACAO DE OBITO",
    "A.I.-CONSTRANGIMENTO ILEGAL (ART. 146)",
    "INDUZIR, INSTIGAR OU AUXILIAR ALGUEM AO USO INDEVIDO DE DROGA(ART.33,§2º)",
    "ABORTO PROVOCADO POR TERCEIRO SEM O CONSENTIMENTO DA GESTANTE (ART. 125)",
    "A.I.-SEQUESTRO E CARCERE PRIVADO (ART. 148)",
    "RECUSA DADOS SOBRE PROPRIA IDENTIDADE/QUALIFIC. (ART. 68)",
    "OMISSAO DE CAUTELA (ART. 13, CAPUT)",
    "A.I.-INCENDIO (ART. 250, CAPUT)",
    "DANO QUALIFICADO (ART.163,PAR.UNICO, II)",
    "EXTORSAO MEDIANTE SEQÜESTRO (ART. 159) - CAIXA ELETRONICO",
    "EXTORSAO MEDIANTE SEQÜESTRO (ART. 159) - PESSOA",
    "A.I.-CONSTRANGIMENTO ILEGAL (ART. 146)",
    "POSSE NAO JUSTIFICADA DE INSTR. DE EMPR. NO FURTO (ART. 25)",
    "CAPOTAMENTO",
    "COMUNICACAO DE OBITO",
    "A.I.-USO DE DOCUMENTO FALSO (ART. 304)",
    "A.I.-LESAO CORPORAL CULPOSA NA DIRECAO DE VEICULO AUTOMOTOR (ART. 303)",
    "RECEPTACAO CULPOSA (ART. 180, §3O.) - VEICULO",
    "DIRIGIR SEM PERMISSAO OU HABILITACAO (ART. 309)",
    "ENTREGA DE VEICULO",
    "ESTRITO CUMPRIMENTO DE DEVER LEGAL",
    "APROPRIACAO DE COISA HAVIDA POR ERRO",
    "PORTE DE ARMA",
    "ENTREGA DE OBJETO LOCALIZADO",
    "CUMPRIMENTO DE MANDADO DE BUSCA E APREENSAO",
    "POSSE IRREGULAR DE ARMA DE FOGO DE USO PERMITIDO",
    "LOCALIZACAO/APREENSAO DE VEICULO",
    "APREENSAO DE ADOLESCENTE",
    "FALTA DE HABILITACAO PARA DIRIGIR VEICULO (ART. 32)",
    "A.I.-DESOBEDIENCIA (ART. 330)",
    "ART. 308-PARTICIPAR, NA DIRECAO DE VEICULO AUTOMOTOR, EM VIA PUBLICA, DE CORRIDA",
    "APREENSAO DE ADOLESCENTE",
    "A.I.-QUADRILHA OU BANDO (ART. 288)",
    "ART 2º - PROMOVER, CONSTITUIR, FINANCIAR OU INTEGRAR ORGANIZACAO CRIMINOSA",
    "PORTE ILEGAL DE ARMA DE FOGO DE USO PERMITIDO (ART. 14)",
    "DESOBEDIENCIA (ART. 330)",
    "JOGO DE AZAR (ART. 50)",
    "DANO QUALIFICADO",
    "A.I.-DIRECAO PERIGOSA DE VEICULO NA VIA PUBLICA",
    "CUMPRIMENTO DE MANDADO DE PRISAO TEMPORARIA",
    "EVASAO/FUGA DE PACIENTE DE ESTABELECIMENTO HOSPITALAR CONSUMADA",
    "DIRECAO PERIGOSA DE VEICULO NA VIA PUBLICA (ART. 34)"
]
maskOutros = df['NATUREZA_APURADA'].apply(lambda x: any(kw in str(x) for kw in Outros))

# %% [markdown]
# ###Criação e classificação da coluna para a categoria do crime

# %%
def classificar_crime(natureza):
    natureza = str(natureza)
    if any(kw in natureza for kw in CrimesPessoa):
        return 'Pessoa'
    elif any(kw in natureza for kw in CrimesPatrimoniais):
        return 'Patrimonial'
    elif any(kw in natureza for kw in CrimesAdmin):
        return 'Administração Pública'
    elif any(kw in natureza for kw in CrimesAmbientais):
        return 'Ambiental'
    elif any(kw in natureza for kw in CrimesImprensaHonra):
        return 'Imprensa / Honra'
    elif any(kw in natureza for kw in CrimesPropriedadeImaterial):
        return 'Propriedade Imaterial'
    elif any(kw in natureza for kw in Outros):
        return 'Outros'
    else:
        return 'Não classificado'

# Criar nova coluna com a categoria
df['CATEGORIA_CRIME'] = df['NATUREZA_APURADA'].apply(classificar_crime)

# %%
df['CATEGORIA_CRIME'].value_counts()
# Out:
# CATEGORIA_CRIME
# Patrimonial              650404
# Outros                    53853
# Pessoa                     9425
# Administração Pública      4917
# Imprensa / Honra            605
# Não classificado            442
# Propriedade Imaterial        47
# Ambiental                    17
# Name: count, dtype: int64

# %%
df[df['CATEGORIA_CRIME'] == 'Não classificado'].head(100)
# Out:
#          NUM_BO  ANO_BO CODIGO_BOLETIM  \
# 33197        22    2022        22/2022
# 36209        38    2022        38/2022
# 39933        39    2022        39/2022
# 39934        39    2022        39/2022
# 39935        39    2022        39/2022
# 42137       307    2022       307/2022
# 42138       307    2022       307/2022
# 42139       307    2022       307/2022
# 42140       307    2022       307/2022
# 42141       307    2022       307/2022
# 45272       537    2022       537/2022
# 46821      1579    2022      1579/2022
# 54990       718    2022       718/2022
# 61556      2250    2022      2250/2022
# 62108        25    2022        25/2022
# 62486   1016393    2022   1016393/2022
# 62743      1032    2022      1032/2022
# 80959     28316    2022     28316/2022
# 80993      4742    2022      4742/2022
# 80994      4742    2022      4742/2022
# 85573      3933    2022      3933/2022
# 105672      701    2022       701/2022
# 111934     4343    2022      4343/2022
# 111935     4343    2022      4343/2022
# 112898     3495    2022      3495/2022
# 117104     5251    2022      5251/2022
# 117121     5252    2022      5252/2022
# 247824                              RUA CAMAROES               10.0
# 252487          RUA ERMENIO DE OLIVEIRA PENTEADO               30.0
# 252488          RUA ERMENIO DE OLIVEIRA PENTEADO               30.0
# 252489          RUA ERMENIO DE OLIVEIRA PENTEADO               30.0
# 260551                       RUA VICENTE SANTORO               49.0
# 260552                       RUA VICENTE SANTORO               49.0
# 260553                       RUA VICENTE SANTORO               49.0
# 260554                       RUA VICENTE SANTORO               49.0
# 261066                       AVENIDA DOM PEDRO I              601.0
# 261067                       AVENIDA DOM PEDRO I              601.0
# 262327              RUA COMENDADOR KOEIJI ADACHI             1000.0
# 262328              RUA COMENDADOR KOEIJI ADACHI             1000.0
# 262329              RUA COMENDADOR KOEIJI ADACHI             1000.0
# 266876                   ESTRADA DO MORRO GRANDE             1165.0
# 266877                   ESTRADA DO MORRO GRANDE             1165.0
# 268680              RUA FRANCISCO DA CRUZ MELLAO              100.0
# 268681              RUA FRANCISCO DA CRUZ MELLAO              100.0
# 269875                ACESSO RODOVIA DOS TAMOIOS              999.0
# 269876                ACESSO RODOVIA DOS TAMOIOS              999.0
#
#                                    BAIRRO            UF  \
# 33197                           REPUBLICA            SP
# 36209                           REPUBLICA            SP
# 39933   JD BELA VISTA E JD DONA ANTONIETA            SP
# 39934   JD BELA VISTA E JD DONA ANTONIETA            SP
# 39935   JD BELA VISTA E JD DONA ANTONIETA            SP
# 42137                              CENTRO            SP
# 42138                              CENTRO            SP
# 42139                              CENTRO            SP
# 42140                              CENTRO            SP
# 42141                              CENTRO            SP
# 45272                  TERRAS DE SAO JOSE            SP
# 46821                     JARDIM PAULISTA            SP
# 54990                          VILA SONIA            SP
# 61556                         SAO GERALDO            SP
# 62108                                 LUZ            SP
# 62486                       VILA SAO JOAO            SP
# 62743                           JABAQUARA            SP
# 80959                          BELA VISTA            SP
# 80993                         TRES MARIAS            SP
# 80994                         TRES MARIAS            SP
# 85573                           SAPOPEMBA            SP
# 105672                          REPUBLICA            SP
# 111934                 PARQUE ARTUR ALVIM            SP
# 111935                 PARQUE ARTUR ALVIM            SP
# 112898                            TATUAPE            SP
# 117104                          SAPOPEMBA            SP
# 117121                          SAPOPEMBA            SP
# 125563                            TATUAPE            SP
# 127239                   REFUGIO DA SERRA            SP
# 134235                         BOM RETIRO            SP
# 149210                       DESCONHECIDO            SP
# 152965                      CAPAO REDONDO            SP
# 164010                          REPUBLICA            SP
# 164070                          REPUBLICA            SP
# 167115                 ERMELINO MATARAZZO            SP
# 167116                 ERMELINO MATARAZZO            SP
# 185166         BALNEARIO PRAIA PERNAMBUCO            SP
# 203672                     JARDIM AMERICA            SP
# 203673                     JARDIM AMERICA            SP
# 203674                     JARDIM AMERICA            SP
# 203675                     JARDIM AMERICA            SP
# 203676                     JARDIM AMERICA            SP
# 204520                      PQ SAO MATEUS            SP
# 204521                      PQ SAO MATEUS            SP
# 211896                      VERANEIO IJAL            SP
# 211897                      VERANEIO IJAL            SP
# 214840                     ANTENOR GARCIA            SP
# 214841                     ANTENOR GARCIA            SP
# 218183                        CAMPO LIMPO            SP
# 218184                        CAMPO LIMPO            SP
# 218521                           ELDORADO            SP
# 218522                           ELDORADO            SP
# 218523                           ELDORADO            SP
# 218591                           ELDORADO            SP
# 218592                           ELDORADO            SP
# 218593                           ELDORADO            SP
# 220000                      VL INDUSTRIAL            SP
# 220001                      VL INDUSTRIAL            SP
# 221897                  JARDIM FERRAZENSE            SP
# 221898                  JARDIM FERRAZENSE            SP
# 230286                       VILA BELMIRO            SP
# 230287                       VILA BELMIRO            SP
# 234061                          BOQUEIRAO            SP
# 234062                          BOQUEIRAO            SP
# 235525                          VL MARCIA            SP
# 236920          RECREIO DA BORDA DO CAMPO            SP
# 236921          RECREIO DA BORDA DO CAMPO            SP
# 236930          RECREIO DA BORDA DO CAMPO            SP
# 236931          RECREIO DA BORDA DO CAMPO            SP
# 237168                          SAPOPEMBA            SP
# 237169                          SAPOPEMBA            SP
# 237170                          SAPOPEMBA            SP
# 239237                            ITAPURA            SP
# 239238                            ITAPURA            SP
# 240354                           TREMEMBE            SP
# 240355                           TREMEMBE            SP
# 241704                              RURAL            SP
# 241705                              RURAL            SP
# 244484                       DESCONHECIDO  DESCONHECIDO
# 244485                       DESCONHECIDO  DESCONHECIDO
# 247823                           PIRITUBA            SP
# 247824                           PIRITUBA            SP
# 252487               BAIRRO DAS LARANJEIR            SP
# 252488               BAIRRO DAS LARANJEIR            SP
# 252489               BAIRRO DAS LARANJEIR            SP
# 260551                              AREAO            SP
# 260552                              AREAO            SP
# 260553                              AREAO            SP
# 260554                              AREAO            SP
# 261066                        TRES MARIAS            SP
# 261067                        TRES MARIAS            SP
# 262327             JARDIM SANTOS DUMONT I            SP
# 262328             JARDIM SANTOS DUMONT I            SP
# 262329             JARDIM SANTOS DUMONT I            SP
# 266876                          DOS FINCO            SP
# 266877                          DOS FINCO            SP
# 268680                        CAMPO LIMPO            SP
# 268681                        CAMPO LIMPO            SP
# 269875                              RURAL            SP
# 269876                              RURAL            SP
#
#                              TIPO_LOCAL   LATITUDE  LONGITUDE  \
# 33197                        RESIDENCIA        NaN        NaN
# 36209                        RESIDENCIA        NaN        NaN
# 39933               COMERCIO E SERVICOS -22.841263 -47.604150
# 39934               COMERCIO E SERVICOS -22.841263 -47.604150
# 39935               COMERCIO E SERVICOS -22.841263 -47.604150
# 42137                 LAZER E RECREACAO -22.551151 -47.917047
# 42138                 LAZER E RECREACAO -22.551151 -47.917047
# 42139                 LAZER E RECREACAO -22.551151 -47.917047
# 42140                 LAZER E RECREACAO -22.551151 -47.917047
# 42141                 LAZER E RECREACAO -22.551151 -47.917047
# 45272               COMERCIO E SERVICOS -23.658758 -47.577314
# 46821                       VIA PUBLICA -23.567682 -46.648984
# 54990                        RESIDENCIA        NaN        NaN
# 61556                        RESIDENCIA        NaN        NaN
# 62108                       VIA PUBLICA -23.528034 -46.630878
# 62486                          INTERNET -23.359793 -46.743943
# 62743                  TERMINAL/ESTACAO -23.634099 -46.643014
# 80959                 LAZER E RECREACAO -23.555064 -46.655367
# 80993                       VIA PUBLICA -23.023842 -45.537769
# 240354                      VIA PUBLICA -23.446685 -46.577792
# 240355                      VIA PUBLICA -23.446685 -46.577792
# 241704                      VIA PUBLICA -21.844189 -46.903954
# 241705                      VIA PUBLICA -21.844189 -46.903954
# 244484                      VIA PUBLICA        NaN        NaN
# 244485                      VIA PUBLICA        NaN        NaN
# 247823                      VIA PUBLICA -23.496312 -46.718868
# 247824                      VIA PUBLICA -23.496312 -46.718868
# 252487                      VIA PUBLICA -23.387027 -46.713601
# 252488                      VIA PUBLICA -23.387027 -46.713601
# 252489                      VIA PUBLICA -23.387027 -46.713601
# 260551                      VIA PUBLICA -23.006719 -45.560496
# 260552                      VIA PUBLICA -23.006719 -45.560496
# 260553                      VIA PUBLICA -23.006719 -45.560496
# 260554                      VIA PUBLICA -23.006719 -45.560496
# 261066                      VIA PUBLICA -23.023842 -45.537769
# 261067                      VIA PUBLICA -23.023842 -45.537769
# 262327                      VIA PUBLICA -23.576837 -46.218801
# 262328                      VIA PUBLICA -23.576837 -46.218801
# 262329                      VIA PUBLICA -23.576837 -46.218801
# 266876                      VIA PUBLICA -23.793127 -46.536178
# 266877                      VIA PUBLICA -23.793127 -46.536178
# 268680                      VIA PUBLICA -23.653685 -46.768862
# 268681                      VIA PUBLICA -23.653685 -46.768862
# 269875                    UNIDADE RURAL -23.393760 -45.655066
# 269876                    UNIDADE RURAL -23.393760 -45.655066
#
#                  DELEGACIA_ELABORACAO DEPARTAMENTO_ELABORACAO  \
# 33197   DEIC-3ª DCCIBER-VIOLACAO D.E.            DESCONHECIDO
# 36209   DEIC-3ª DCCIBER-VIOLACAO D.E.            DESCONHECIDO
# 39933          DEL.POL.RIO DAS PEDRAS            DESCONHECIDO
# 39934          DEL.POL.RIO DAS PEDRAS            DESCONHECIDO
# 39935          DEL.POL.RIO DAS PEDRAS            DESCONHECIDO
# 42137      DEL.SEC.PIRACICABA PLANTAO            DESCONHECIDO
# 42138      DEL.SEC.PIRACICABA PLANTAO            DESCONHECIDO
# 42139      DEL.SEC.PIRACICABA PLANTAO            DESCONHECIDO
# 42140      DEL.SEC.PIRACICABA PLANTAO            DESCONHECIDO
# 42141      DEL.SEC.PIRACICABA PLANTAO            DESCONHECIDO
# 45272      DEL.POL.PLANTAO VOTORANTIM            DESCONHECIDO
# 46821                78º D.P. JARDINS            DESCONHECIDO
# 54990          87º D.P. V. P. BARRETO            DESCONHECIDO
# 61556      DEL.SEC.ARARAQUARA PLANTAO            DESCONHECIDO
# 62108     DHPP 02ª DEL.DIV.HOMICIDIOS            DESCONHECIDO
# 62486            DELEGACIA ELETRONICA            DESCONHECIDO
# 62743        57º D.P. PARQUE DA MOOCA            DESCONHECIDO
# 80959          DELEGACIA ELETRONICA 1            DESCONHECIDO
# 80993         DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 80994         DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
#
# 239237       PLANTAO - 01 DP CAMPINAS            DESCONHECIDO
# 239238       PLANTAO - 01 DP CAMPINAS            DESCONHECIDO
# 240354                73º D.P. JACANA            DESCONHECIDO
# 240355                73º D.P. JACANA            DESCONHECIDO
# 241704   DEL.POL.VARGEM GRANDE DO SUL            DESCONHECIDO
# 241705   DEL.POL.VARGEM GRANDE DO SUL            DESCONHECIDO
# 244484                    02ª DDM SUL            DESCONHECIDO
# 244485                    02ª DDM SUL            DESCONHECIDO
# 247823                05º D.P. OSASCO            DESCONHECIDO
# 247824                05º D.P. OSASCO            DESCONHECIDO
# 252487               DEL.POL.CAIEIRAS            DESCONHECIDO
# 252488               DEL.POL.CAIEIRAS            DESCONHECIDO
# 252489               DEL.POL.CAIEIRAS            DESCONHECIDO
# 260551        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 260552        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 260553        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 260554        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 261066        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 261067        DEL.SEC.TAUBATE PLANTAO            DESCONHECIDO
# 262327    DEL.SEC.MOGI CRUZES PLANTAO            DESCONHECIDO
# 262328    DEL.SEC.MOGI CRUZES PLANTAO            DESCONHECIDO
# 262329    DEL.SEC.MOGI CRUZES PLANTAO            DESCONHECIDO
# 266876   03º D.P. S.BERNARDO DO CAMPO            DESCONHECIDO
# 266877   03º D.P. S.BERNARDO DO CAMPO            DESCONHECIDO
# 268680         89º D.P. JARDIM TABOAO            DESCONHECIDO
# 268681         89º D.P. JARDIM TABOAO            DESCONHECIDO
# 269875              DEL.POL.PARAIBUNA            DESCONHECIDO
# 269876              DEL.POL.PARAIBUNA            DESCONHECIDO
#
#        SECCIONAL_ELABORACAO        DELEGACIA_CIRCUNSCRICAO  \
# 33197          DESCONHECIDO        03º D.P. CAMPOS ELISEOS
# 36209          DESCONHECIDO        03º D.P. CAMPOS ELISEOS
# 39933          DESCONHECIDO         DEL.POL.RIO DAS PEDRAS
# 39934          DESCONHECIDO         DEL.POL.RIO DAS PEDRAS
# 39935          DESCONHECIDO         DEL.POL.RIO DAS PEDRAS
# 42137          DESCONHECIDO                DEL.POL.S.PEDRO
# 42138          DESCONHECIDO                DEL.POL.S.PEDRO
# 42139          DESCONHECIDO                DEL.POL.S.PEDRO
# 42140          DESCONHECIDO                DEL.POL.S.PEDRO
# ...
# 260554               TITULO X - FE PUBLICA (ARTS. 289 A 311)  CONSUMADO
# 261066               TITULO X - FE PUBLICA (ARTS. 289 A 311)  CONSUMADO
# 261067               TITULO X - FE PUBLICA (ARTS. 289 A 311)  CONSUMADO
# 262327                                       ATO INFRACIONAL  CONSUMADO
# 262328                                       ATO INFRACIONAL  CONSUMADO
# 262329                                       ATO INFRACIONAL  CONSUMADO
# 266876  TITULO VIII - INCOLUMIDADE PUBLICA (ARTS. 250 A 285)  CONSUMADO
# 266877  TITULO VIII - INCOLUMIDADE PUBLICA (ARTS. 250 A 285)  CONSUMADO
# 268680  TITULO VIII - INCOLUMIDADE PUBLICA (ARTS. 250 A 285)  CONSUMADO
# 268681  TITULO VIII - INCOLUMIDADE PUBLICA (ARTS. 250 A 285)  CONSUMADO
# 269876        IDOSO         SÁBADO  2022-01-08 20:00:00  Não classificado

# %% [markdown]
# ## Tipo do local do crime

# %%
df['TIPO_LOCAL'].value_counts()
# Out:
# TIPO_LOCAL
# VIA PUBLICA                        529829
# RESIDENCIA                          44385
# OUTROS                              26425
# COMERCIO E SERVICOS                 22808
# TERMINAL/ESTACAO                    20764
# SAUDE                               12180
# RODOVIA/ESTRADA                      9668
# CONDOMINIO RESIDENCIAL               4587
# UNIDADE RURAL                        4467
# LAZER E RECREACAO                    4460
# GARAGEM OU ABRIGO DE RESIDENCIA      4458
# VEICULO EM MOVIMENTO                 4379
# RESTAURANTE E AFINS                  4099
# CONDOMINIO COMERCIAL                 3918
# CENTRO COMERC./EMPRESARIAL           3616
# ESTACIONAMENTO PUBLICO               3394
# AREA NAO OCUPADA                     2500
# ESTACIONAMENTO PARTICULAR            2287
# SHOPPING CENTER                      1803
# ESCRITORIO                           1209
# ESTABELECIMENTO DE ENSINO            1191
# GARAGEM COLETIVA DE PREDIO           1091
# ESTACIONAMENTO COM VIGILANCIA         928
# SERVICOS E BENS PUBLICOS              904
# REPARTICAO PUBLICA                    803
# HOSPEDAGEM                            704
# LOCAL CLANDESTINO/ILEGAL              609
# FAVELA                                470
# ESTABELECIMENTO BANCARIO              440
# ENTIDADE ASSISTENCIAL                 368
# TEMPLO E AFINS                        312
# ESTABELECIMENTO INDUSTRIAL            307
# INTERNET                              196
# ESTABELECIMENTO PRISIONAL             135
# ESTRADA DE FERRO                        9
# DESCONHECIDO                            4
# SINDICATO                               2
# ESTABELECIMENTO COMERCIAL               1
# Name: count, dtype: Int64

# %% [markdown]
# # Padronização de marcas de celular e veículo

# %%
def padronizar_marca_celular(marca):
    marca = str(marca).strip().upper()

    if any(palavra in marca for palavra in ['SAMSUNG', 'SANSUNG', 'SAMSUMG', 'GALAXY', 'M10', 'SAMSNG', 'SAMSSUNG', 'SANSUMG', 'SAMGUNG']):
        return 'SAMSUNG'
    elif any(palavra in marca for palavra in ['IPHONE', 'IFONE', 'APPLE', 'I PHONE 8']):
        return 'APPLE'
    elif any(palavra in marca for palavra in ['MOTOROLA', 'MOTO']):
        return 'MOTOROLA'
    elif any(palavra in marca for palavra in ['XIAOMI', 'REDMI', 'POCO', 'XIOMI', 'XAIOMI', 'XIOME', 'XAOMI']):
        return 'XIAOMI'
    elif 'ASUS' in marca or 'ZENFONE' in marca:
        return 'ASUS'
    elif 'LG' in marca:
        return 'LG'
    elif 'MULTILASER' in marca or 'LEYSER' in marca:
        return 'MULTILASER'
    elif marca in ['SMARTPHONE', 'CELULAR', 'OUTROS', '356714081167096']:
        return 'DESCONHECIDO'
    else:
        return marca

df['MARCA_CELULAR'] = df['MARCA_CELULAR'].apply(padronizar_marca_celular)

# %%
# Limpeza inicial para remover números/caracteres especiais
df['MARCA_VEICULO'] = df['MARCA_VEICULO'].str.replace(r'\d+', '', regex=True).str.strip().str.upper()

mapa_marcas = {}

marcas_variacoes = {
    # Marcas válidas (reconhecidas internacionalmente ou no Brasil)
    'VOLKSWAGEN': ['VW', 'VOLKSWAGEM', 'VOLKWAGEN', 'VOLKS', 'QUANTUM GL 1800'],
    'CHEVROLET': ['GM', 'CHEV', 'CHEVROLT', 'CHEVROLET CAMARO SS 6.2 V8'],
    'FIAT': ['FIAT UNO 1.6', 'IFIAT UNO MILLE EP'],
    'CITROEN': ['CITREN', 'CITROEN PICASSO II20GLXA'],
    'RENAULT': ['REANAULT', 'RENALT'],
    'HYUNDAI': ['HYUNDA', 'HYUNDAY'],
    'MERCEDES-BENZ': ['M.BENZ', 'M.B.', 'M. BENZ', 'MBENZ'],
    'TOYOTA': [
        'TOYOTA ETIOS SD XS', 'TOYOTA ETIOS SD XLS', 'TOYOTA ETIOS SD X',
        'TOYOTA ETIOS HB X', 'TOYOTA ETIOS HB XLS', 'TOYOTA ETIOS HB XS', 'TOYOTA ETIOS HB'
    ],
    'HONDA': ['H', 'R'],
    'NISSAN': ['NISAN', 'NISSAN KICKS SL 1.6 16V FLEX'],
    'FORD': ['FORD KA 1.0', 'FORD RANGER XLT 3.2'],
    'PEUGEOT': ['PEUGEOT 208 GRIFFE 1.6'],
    'BMW': ['BMW 320I SPORT'],
    'AUDI': ['AUDI A4 2.0 TFSI'],
    'VOLVO': ['VOLVO XC60 T8'],
    'SUZUKI': ['JTA-SUZUKI', 'JTA-SUZUKI GSX-S750 AZ'],
    'MITSUBISHI': ['MMC'],
    'YAMAHA': ['Y'],
    'KTM': ['KTM 390 DUKE'],
    'LAND ROVER': ['LR'],
    'IVECO': ['IVECOFIAT'],
    'CHRYSLER': ['CHRY'],
    'JEEP': ['JEEP RENEGADE SPORT 1.8'],
    'DODGE': ['DODGE RAM 2500'],
    'GMC': ['GMC SIERRA 1500'],
    'SCANIA': ['SCANIA R500'],

    # Marcas de motos ou nicho
    'HARLEY-DAVIDSON': ['HARLEY DAVIDSON', 'HARLEYDAVIDSON', 'H.DAVIDSON'],
    'KAWASAKI': ['KAWA'],
    'DAFRA': ['DAFRA 150'],
    'SHINERAY': ['SHINERAY XY 250'],

    # Categorias especiais (não são marcas)
    'DESCONHECIDO': ['XXXXXXX', 'IMP', 'IM', 'REB'],
    'FABRICACAO PROPRIA': ['SOUSA', 'SR.SILVA'],
    'MOTORHOME': ['MOTOR-CASA'],

    # Outros (marcas menos comuns/descontinuadas)
    'GURGEL': ['GURGEL BRASILIA'],
    'TROLLER': ['TROLLER T4'],
    'AGRALE': ['AGRALE MARRUÁ'],

    # Não-marcas ou erros (agrupados em "OUTROS")
    'OUTROS': [
        'MA', 'MR', 'M.A.', 'MO', 'HTA', 'MIA', 'BP', '5W', 'CENTERMARINE 1 B',
        'MEDVID', 'AUTO CROSS', 'SR', 'TRAXX', 'HOME CAR', 'ATMAN', 'HAOBAO',
        'COFAVE', 'SUNDOWN', 'SUNDOW', 'CALOI', 'KASINSKI', 'TITAN', 'BRAMONT',
        'ENGESA', 'MARCOPOLO', 'IVEL', 'RANDON', 'MV AGUSTA', 'BUEL', 'BUELL',
        'PIAGGIO', 'EFFA', 'DAELIM', 'FOTON', 'JTZ', 'JTA', 'TVS', 'AVA', 'IROS', 'DAF'
    ]
}

# Construção do dicionário final
mapa_marcas = {var: marca for marca, variacoes in marcas_variacoes.items() for var in variacoes}

df['MARCA_VEICULO']=df['MARCA_VEICULO'].replace(mapa_marcas)

# %% [markdown]
# # Análise exploratória dos dados

# %% [markdown]
# **Descrição**: Com os dados preparados e
# entendidos, nesta etapa o grupo deve gerar **estatísticas descritivas, gráficos e
# tabelas** para conhecer os dados. Todo conhecimento importante extraído deverá ser
# documentado e discutido. Pensem fora da caixa e tentem extrair correlações não
# óbvias entre os atributos e objetos. Nesta etapa, o objetivo é responder **parte das
# perguntas** elaboradas.

# %% [markdown]
# Nesse trecho do projeto será feito o uso da função describe().
# Para colunas numéricas, ele exibe:
#
# * count: número de valores não nulos
# * mean: média
# * std: desvio padrão
# * min: valor mínimo
# * 25%: primeiro quartil (Q1)
# * 50%: mediana (Q2)
# * 75%: terceiro quartil (Q3)
# * max: valor máximo
#
# Para colunas não numéricas (objetos/categorias), ele exibe:
#
# * count: número de valores não nulos
# * unique: número de valores únicos
# * top: valor mais frequente
# * freq: frequência do valor mais frequente

# %% [markdown]
# # Perguntas

# %% [markdown]
# ### Pergunta 1: Quais foram os anos nos quais mais houveram ocorrências registradas em 2022?

# %% [markdown]
# Foi utilizado o método describe em cada um dos atributos relacionados a pergunta.

# %%
df["DATA_OCORRENCIA"].dt.year.describe()
# Out:
# count    719710.000000
# mean       2021.960508
# std           0.888365
# min        1922.000000
# 25%        2022.000000
# 50%        2022.000000
# 75%        2022.000000
# max        2022.000000
# Name: DATA_OCORRENCIA, dtype: float64

# %% [markdown]
# Primeiro, foi utilizado o boxplot para visualizar a distribuição dos dados e identificar possíveis outliers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Criar uma cópia do DataFrame original
df_box = df.copy()

# Extrair o ano da coluna de data
df_box['Ano'] = df_box['DATA_OCORRENCIA'].dt.year

# Contar o número de ocorrências por ano
contagem_anos = df_box['Ano'].value_counts().sort_index()

# Criar um DataFrame para o boxplot
df_boxplot = pd.DataFrame({'Ano': contagem_anos.index, 'Ocorrencias': contagem_anos.values})

# Configurar o estilo do Seaborn
sns.set_style('whitegrid')
sns.set_context('talk')

# Criar o boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Ocorrencias', data=df_boxplot, orient='h')
plt.title('Distribuição das Ocorrências por Ano')
plt.xlabel('Número de Ocorrências')
plt.tight_layout()
plt.show()

# %% [markdown]
# Esse gráfico mostra que, ao longo dos anos, houve uma grande variação no número de ocorrências registradas, com um ano **(2022)** com muito mais ocorrências do que os demais, o que faz sentido considerando que os registros dos crimes foram feitos em 2022. No entanto, é interessante verificar a *grande variação de anos*, pois não é porque um crime já aconteceu há algum tempo que signifique ele não possa ser denunciado.

# %% [markdown]
# Comos os dados apresentam uma grande disparidade entre os valores, decidimos aplicar uma escala logarítmica ao eixo pode ajudar a reduzir o impacto visual dos valores extremos, permitindo que as diferenças sejam mais perceptíveis.​ E também considerando apenas os 15 anos com maiores números de ocorrências.

# %%
import matplotlib.pyplot as plt

# Criar uma cópia do DataFrame original
df_log = df.copy()

# Extrair o ano da coluna de data
df_log['Ano'] = df_log['DATA_OCORRENCIA'].dt.year

# Contar o número de ocorrências por ano
contagem_anos = df_log['Ano'].value_counts()

# Selecionar os 15 anos com mais ocorrências
top_15 = contagem_anos.nlargest(15).sort_values()

# Criar o gráfico de barras horizontal com escala logarítmica
plt.figure(figsize=(10, 8))
plt.barh(top_15.index.astype(str), top_15.values)
plt.xscale('log')  # Escala logarítmica no eixo X
plt.ylabel('Ano')
plt.xlabel('Número de Ocorrências (Escala Logarítmica)')
plt.title('Top 15 Anos com Mais Ocorrências (Escala Logarítmica)')

# Formatar ticks para legibilidade
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pergunta 3: Qual a natureza e espécie de crimes mais comuns?

# %% [markdown]
# Podemos observar o seguinte:
#
# O gráfico de barras horizontais apresenta a contagem de ocorrências para as diferentes categorias de crimes, mostrando quais categorias são mais comuns no conjunto de dados.
#
# Claramente, a categoria "Patrimonial" é a mais predominante, com um número significativamente maior de ocorrências (464.175) em comparação com as outras categorias. Isso indica que crimes relacionados a patrimônio (como roubos, furtos, estelionato, etc.) são os mais frequentes neste dataset.

# %% [markdown]
# Para responder à pergunta "Qual a natureza e espécie de crimes mais comuns?", realizamos uma análise exploratória nos dados disponíveis. O objetivo é identificar os tipos de crimes que ocorrem com maior frequência, tanto pela sua natureza apurada quanto pela espécie relacionada.
#
# O código a seguir primeiro calcula a contagem de ocorrências para cada categoria nas colunas 'CATEGORIA_CRIME' e 'ESPECIE'(Optamos por usar categoria do crime para facilitar a visualização). Em seguida, seleciona as categorias mais frequentes em cada uma dessas colunas.

# %%
import matplotlib.pyplot as plt
import pandas as pd


top_natureza = df['CATEGORIA_CRIME'].value_counts().head(10).sort_values()

plt.figure(figsize=(20, 10))
bars_natureza = plt.barh(top_natureza.index, top_natureza.values, color='skyblue')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Categoria do crime')
plt.title('Top Categorias de Crimes Mais Comuns')

for bar in bars_natureza:
    width = bar.get_width()
    plt.text(width + max(top_natureza.values) * 0.01, bar.get_y() + bar.get_height()/2,
             f'{int(width):,}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %%
top_10_especie = df['ESPECIE'].value_counts().head(10).sort_values()

plt.figure(figsize=(20, 10))
bars_especie = plt.barh(top_10_especie.index, top_10_especie.values, color='lightcoral')
plt.xlabel('Número de Ocorrências')
plt.ylabel('Espécie de Crime')
plt.title('Top 10 Espécies de Crimes Mais Comuns')

for bar in bars_especie:
    width = bar.get_width()
    plt.text(width + max(top_10_especie.values) * 0.01, bar.get_y() + bar.get_height()/2,
             f'{int(width):,}', va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Podemos analisar o seguinte:
#
# Este gráfico de barras horizontais visualiza as espécies de crimes que ocorreram com maior frequência no conjunto de dados.
#
# A espécie de crime mais comum, de longe, é "TITULO II - PATRIMONIO (ARTS. 155 A 183)", registrando impressionantes 444.514 ocorrências. Este título no Código Penal Brasileiro geralmente abrange crimes contra o patrimônio, como furto, roubo, dano, estelionato, etc., o que corrobora a observação do gráfico anterior sobre a predominância de crimes patrimoniais por categoria.

# %% [markdown]
# ### Pergunta 4: Qual é o tempo médio entre a ocorrência, a elaboração do boletim e a comunicação dos fatos?

# %%
df['DATA_COMUNICACAO'] = pd.to_datetime(df['DATA_COMUNICACAO'], errors='coerce')
df['DATA_ELABORACAO'] = pd.to_datetime(df['DATA_HORA_ELABORACAO'], errors='coerce')
df['DATA_ELABORACAO'] = df['DATA_ELABORACAO'].dt.date # Necessário para manter só a data e descartar as horas
df['DATA_ELABORACAO'] = pd.to_datetime(df['DATA_ELABORACAO']) # Convertendo novamente para datetime mantendo apenas a data

# %%
# Verificar se há valores nulos
print(df['DATA_OCORRENCIA'].isnull().sum())  # Conta quantos valores nulos existem
print(df['DATA_COMUNICACAO'].isnull().sum())  # Conta quantos valores nulos existem
print(df['DATA_HORA_ELABORACAO'].isnull().sum())  # Conta quantos valores nulos existem
# Out:
# 0
# 28680
# 1

# %% [markdown]
# Data ocorrência não apresenta valores nulos, data comunicação apresenta vários valores nulos e data de elaboração apenas 1 valor nulo

# %%
# Calcular a diferença entre duas datas em DIAS
# Valores não podem estar nulos
df['tempo_elaboracao_comunicacao_dias'] = (df['DATA_COMUNICACAO'] - df['DATA_ELABORACAO']).apply(lambda x: x.days if pd.notnull(x) else None)
df['tempo_ocorrencia_elaboracao_dias'] = (df['DATA_ELABORACAO'] - df['DATA_OCORRENCIA']).apply(lambda x: x.days if pd.notnull(x) else None)
df['tempo_ocorrencia_comunicacao_dias'] = (df['DATA_COMUNICACAO'] - df['DATA_OCORRENCIA']).apply(lambda x: x.days if pd.notnull(x) else None)
df['tempo_elaboracao_comunicacao_dias'] = (df['DATA_COMUNICACAO'] - df['DATA_ELABORACAO']).apply(lambda x: x.days if pd.notnull(x) else None)


# Exibir estatísticas descritivas
print("\nTempo entre Ocorrência e Elaboração do Boletim:")
print(df['tempo_ocorrencia_elaboracao_dias'].describe())

print("\nTempo entre Ocorrência e Comunicação dos Fatos:")
print(df['tempo_ocorrencia_comunicacao_dias'].describe())

print("\nTempo entre Elaboração do Boletim e Comunicação:")
print(df['tempo_elaboracao_comunicacao_dias'].describe())
# Out:
# Tempo entre Ocorrência e Elaboração do Boletim:
# count    719709.000000
# mean         15.347035
# std         329.322596
# min        -333.000000
# 25%           0.000000
# 50%           1.000000
# 75%           6.000000
# max       36526.000000
# Name: tempo_ocorrencia_elaboracao_dias, dtype: float64
#
# Tempo entre Ocorrência e Comunicação dos Fatos:
# count    691030.000000
# mean         14.478489
# std         333.209553
# min        -333.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max       36525.000000
# Name: tempo_ocorrencia_comunicacao_dias, dtype: float64
#
# Tempo entre Elaboração do Boletim e Comunicação:
# count    691030.000000
# mean         -1.469625
# std          47.671305
# min        -748.000000
# 25%          -1.000000
# 50%           0.000000
# 75%           0.000000
# max         474.000000
# Name: tempo_elaboracao_comunicacao_dias, dtype: float64

# %%
# Excluir os valores negativos na coluna 'tempo_ocorrencia_elaboracao_dias'
df_negativos = df[df['tempo_ocorrencia_elaboracao_dias'] < 0]
print(df_negativos[['DATA_COMUNICACAO', 'DATA_ELABORACAO', 'DATA_OCORRENCIA']].head())
# Out:
#       DATA_COMUNICACAO DATA_ELABORACAO DATA_OCORRENCIA
# 2060               NaT      2022-09-06      2022-09-17
# 6454               NaT      2022-02-18      2022-02-19
# 7459               NaT      2022-02-01      2022-02-03
# 7518               NaT      2022-02-10      2022-02-13
# 34285       2022-12-01      2022-01-13      2022-12-01

# %% [markdown]
# ### Pergunta 5: Quais são os 3 tipos de relacionamentos possíveis entre veículos (marca, modelo, ano de fabricação e cidade) e crimes patrimoniais?

# %% [markdown]
# ### Pergunta 6: Existe alguma relação entre período das ocorrências e a ocorrência de incidentes fatais?

# %%
df['FLAG_VITIMA_FATAL'].value_counts()
# Out:
# FLAG_VITIMA_FATAL
# DESCONHECIDO    717466
# SIM               2244
# Name: count, dtype: Int64

# %%
# Primeiro filtramos onde FLAG_VITIMA_FATAL é SIM e depois seleciono as colunas de meu interesse
print(df[df['FLAG_VITIMA_FATAL'] == 'SIM'][['FLAG_VITIMA_FATAL', 'NATUREZA_APURADA']].head(10))
# Out:
#       FLAG_VITIMA_FATAL              NATUREZA_APURADA
# 30201               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30202               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30203               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30204               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30205               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30206               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30251               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30252               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30253               SIM  HOMICIDIO SIMPLES (ART. 121)
# 30254               SIM  HOMICIDIO SIMPLES (ART. 121)

# %% [markdown]
# Há muitos valores nulos, para tentar contornar isso podemos tentar considerar a coluna de NATUREZA_APURADA

# %%
df['NATUREZA_APURADA'].value_counts()
# Out:
# NATUREZA_APURADA
# FURTO (ART. 155) - OUTROS                                                           119292
# FURTO (ART. 155) - VEICULO                                                          115161
# ROUBO (ART. 157) - VEICULO                                                          112206
# ROUBO (ART. 157) - OUTROS                                                            96643
# LOCALIZACAO/APREENSAO E ENTREGA DE VEICULO                                           49533
# ROUBO (ART. 157) - TRANSEUNTE                                                        46299
# MORTE SUSPEITA                                                                       25581
# FURTO (ART. 155) - TRANSEUNTE                                                        18178
# ENTREGA DE VEICULO LOCALIZADO/APREENDIDO                                             10588
# FURTO (ART. 155) - INTERIOR DE VEICULO                                               10561
# LOCALIZACAO/APREENSAO DE VEICULO                                                     10513
# FURTO (ART. 155) - RESIDENCIA                                                         8620
# ROUBO (ART. 157) - CARGA                                                              8615
# ROUBO (ART. 157) - RESIDENCIA                                                         6703
# ROUBO (ART. 157) - INTERIOR DE VEICULO                                                5370
# FURTO (ART. 155) - INTERIOR ESTABELECIMENTO                                           4421
# LOCALIZACAO/APREENSAO DE OBJETO                                                       4307
# FURTO (ART. 155) - ESTABELECIMENTO COMERCIAL                                          4238
# ROUBO (ART. 157) - ESTABELECIMENTO COMERCIAL                                          4138
# FURTO (ART. 155) - INTERIOR TRANSPORTE COLETIVO                                       3738
# LOCALIZACAO/APREENSAO E ENTREGA DE OBJETO                                             3316
# EXTORSAO (ART. 158)                                                                   3269
# RECEPTACAO (ART. 180) - VEICULO                                                       3030
# HOMICIDIO DOLOSO                                                                      3015
# A.I.-ROUBO (ART. 157) - VEICULO                                                       2760
# USURPACAO DE FUNCAO PUBLICA (ART. 328)                                                   1
# RUFIANISMO (ART. 230)                                                                    1
# ESBULHO POSSESSORIO (ART. 161, §1O., II)                                                 1
# A.I.-INJURIA (ART. 140)                                                                  1
# RECEPTACAO CULPOSA (ART. 180, §3O.) - OUTROS                                             1
# MAUS-TRATOS (ART. 136)                                                                   1
# LESAO CORPORAL SEGUIDA DE MORTE (ART. 129, §3O.)                                         1
# ALTERACAO DE LIMITES (ART. 161)                                                          1
# A.I.-FURTO QUALIFICADO (ART. 155, §4O.) - OUTROS                                         1
# RUFIANISMO (ART.230)                                                                     1
# FURTO DE COISA COMUM (ART. 156) - CAIXA ELETRONICO                                       1
# RETENCAO DE DOCUMENTO (ART. 3º)                                                          1
# FURTO QUALIFICADO (ART. 155, §4O.) - SAIDINHA DE BANCO                                   1
# A.I.-ROUBO (ART. 157) - ESTABELECIMENTO-OUTROS                                           1
# ABANDONAR IDOSO OU NAO PROVER SUAS NECESSIDADES ( ART.98)                                1
# A.I.-FURTO QUALIFICADO (ART. 155, §4O.) - TRANSEUNTE                                     1
# AUTO-ACUSACAO FALSA (ART. 341)                                                           1
# A.I.-FURTO (ART. 155) - APLICATIVO DE MOBILIDADE URBANA                                  1
# USURA PECUNIARIA OU REAL (ART. 4º)                                                       1
# EXCESSO NA COBRANCA DE DIVIDAS (ART. 71)                                                 1
# A.I.-FURTO (ART. 155) - ESTABELECIMENTO-OUTROS                                           1
# FURTO DE COISA COMUM (ART. 156) - ESTABELECIMENTO ENSINO                                 1
# DANO EM COISA DE VALOR ARTISTICO, ARQUEOLOGICO OU HISTORICO (ART. 165)                   1
# EXTORSAO MEDIANTE SEQÜESTRO (ART. 159) - CAIXA ELETRONICO                                1
# INDUZIR, INSTIGAR OU AUXILIAR ALGUEM AO USO INDEVIDO DE DROGA(ART.33,§2º)                1
# DANO QUALIFICADO (ART.163,PAR.UNICO, II)                                                 1
# A.I.-INCENDIO (ART. 250, CAPUT)                                                          1
# SUICIDIO TENTADO                                                                         1
# A.I.-ESTUPRO (ART.213)                                                                   1
# ABORTO PROVOCADO POR TERCEIRO SEM O CONSENTIMENTO DA GESTANTE (ART. 125)                 1
# Name: count, dtype: Int64

# %% [markdown]
# Vamos considerar os crimes que envolvem fatalidade para a análise, com o objetivo de aumentar a amostra, além de considerar onde FLAG_VITIMA_FATAL indica que houve fatalidade **(FALTA CONSIDERAR NATUREZA_APURADA SO CONSIDEREI A FLAG_VITIMA_FATAL AQUI)**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar os dados para remover "DESCONHECIDO" e valores nulos em FLAG_VITIMA_FATAL e PERIODO_OCORRENCIA
df_filtrado = df[df['FLAG_VITIMA_FATAL'].notna()]  # Remove valores nulos em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'] != 'DESCONHECIDO']  # Remove "DESCONHECIDO" em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['PERIODO_OCORRENCIA'] != 'DESCONHECIDO']  # Remove "DESCONHECIDO" em PERIODO_OCORRENCIA
df_filtrado = df_filtrado[df_filtrado['PERIODO_OCORRENCIA'].notna()]  # Remove valores nulos em PERIODO_OCORRENCIA

# Filtrar para apenas os casos em que FLAG_VITIMA_FATAL é 'SIM'
df_fatal = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'].str.upper() == 'SIM']

# Agrupar os dados por PERIODO_OCORRENCIA e contar o número de ocorrências fatais
fatalidade_por_periodo = df_fatal.groupby('PERIODO_OCORRENCIA').size().reset_index(name='total_fatais')

paleta_cores = ['#9c27b0', '#e91e63', '#f07c9c', '#f4c1d9']

# Gráfico de barras em rosa
plt.figure(figsize=(14, 8))
sns.barplot(data=fatalidade_por_periodo, x='PERIODO_OCORRENCIA', y='total_fatais', palette=paleta_cores, hue='PERIODO_OCORRENCIA', alpha=1)
plt.title('Distribuição de Fatalidades por Período de Ocorrência')
plt.xlabel('Período de Ocorrência')
plt.ylabel('Total de Fatalidades')
plt.xticks(rotation=0)
plt.grid(False)
plt.show()

# %% [markdown]
# ### Pergunta 7: Qual é a distribuição dos periodos do dia (manhã, tarde, noite, madrugada) nas ocorrências?

# %%
df.groupby("PERIODO_OCORRENCIA")['PERIODO_OCORRENCIA'].count().sort_values(ascending=True).plot(kind='bar', figsize=(6, 3))
# Out:
# <Axes: xlabel='PERIODO_OCORRENCIA'>

# %%
import matplotlib.pyplot as plt

# Cria um df com os valorez normalizados e multiplicados em 100 para obter as porcentagens.
periodos = df['PERIODO_OCORRENCIA'].value_counts(normalize=True) * 100

# Ordenando apóis o calculo.
periodos_ordenados = periodos.sort_values(ascending=True)

# Criando o gráfico com as porcentagens
graf = periodos_ordenados.plot(kind='bar', figsize=(6, 3))
graf.set_ylabel("Porcentagem")

# Adicionar as legendas com as porcentagens.
for p in graf.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    graf.annotate(f'{height:.1f}%', (x + width/2, y + height/2), ha='center', va='center')

plt.show()

# %%
acidentes_por_PERIODO_OCORRENCIA = df.groupby(['PERIODO_OCORRENCIA']).size().reset_index(name='total')

ordemPeriodoOcorrencia = ['DE MADRUGADA', 'PELA MANHA', 'A TARDE', 'A NOITE', 'DESCONHECIDO']
acidentes_por_PERIODO_OCORRENCIA['PERIODO_OCORRENCIA'] = pd.Categorical(acidentes_por_PERIODO_OCORRENCIA['PERIODO_OCORRENCIA'], categories=ordemPeriodoOcorrencia, ordered=True)
acidentes_por_PERIODO_OCORRENCIA = acidentes_por_PERIODO_OCORRENCIA.sort_values('PERIODO_OCORRENCIA')
acidentes_por_PERIODO_OCORRENCIA
# Out:
#   PERIODO_OCORRENCIA   total
# 2       DE MADRUGADA  116418
# 4         PELA MANHA  154189
# 1            A TARDE  152685
# 0            A NOITE  218751
# 3       DESCONHECIDO   77667

# %%
import seaborn as sns
sns.set_style("whitegrid")
plt.figure(figsize=(10, 5))
sns.lineplot(data=acidentes_por_PERIODO_OCORRENCIA, x='PERIODO_OCORRENCIA', y='total', marker='o')

plt.title('Ocorrências por Fase do Dia')
plt.xlabel('Fase do Dia')
plt.ylabel('Quantidade de ocorrências')
plt.show()

# %% [markdown]
# Pergunta 2: Como se distribuem os perfis de pessoas envolvidas (vítimas/autores) em termos de idade, sexo e cor de pele (fatores demográficos)?

# %%
df['COR_PELE'].value_counts()
# Out:
# COR_PELE
# DESCONHECIDO    714139
# BRANCA            2956
# PARDA             2134
# PRETA              454
# AMARELA             24
# VERMELHA             2
# OUTROS               1
# Name: count, dtype: Int64

# %%
df['IDADE_PESSOA'].value_counts().sum()
# Out:
# np.int64(28272)

# %%
df['TIPO_PESSOA'].value_counts()
# Out:
# TIPO_PESSOA
# DESCONHECIDO           688942
# VITIMA                  28989
# AUTOR/VITIMA             1391
# ENCONTRO DE CADAVER       338
# ADOLESCENTE INF/VIT        34
# VITIMA DE SUICIDIO          5
# DESAPARECIDO                5
# ADOLESCENTE                 2
# INDICIADO                   2
# ENCONTRADO                  1
# CRIANCA                     1
# Name: count, dtype: Int64

# %% [markdown]
# ### Pergunta 8: Há alguma tendência de aumento ou diminuição nas ocorrências fatais ao longo dos anos?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar os dados para remover "DESCONHECIDO" e valores nulos em FLAG_VITIMA_FATAL e DATA_OCORRENCIA
df_filtrado = df[df['FLAG_VITIMA_FATAL'].notna()]  # Remove valores nulos em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'] != 'DESCONHECIDO']  # Remove "DESCONHECIDO" em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['DATA_OCORRENCIA'].notna()]  # Remove valores nulos em DATA_OCORRENCIA

# Filtrar para apenas os casos em que FLAG_VITIMA_FATAL é 'SIM'
df_fatal = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'].str.upper() == 'SIM'].copy()  # Usando .copy() aqui

# Usando loc para adicionar a nova coluna 'Ano' de forma segura
df_fatal.loc[:, 'Ano'] = df_fatal['DATA_OCORRENCIA'].dt.year

# Contar o número de ocorrências fatais por ano
fatalidades_por_ano = df_fatal.groupby('Ano').size().reset_index(name='total_fatais')

# Visualizar a distribuição das fatalidades por ano
plt.figure(figsize=(14, 8))
sns.barplot(data=fatalidades_por_ano, x='Ano', y='total_fatais', color='skyblue')
plt.title('Número de Fatalidades por Ano de Ocorrência')
plt.xlabel('Ano de Ocorrência')
plt.ylabel('Total de Fatalidades')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Liberando essas variáveis para evitar inconsistências em outras análises
del df_filtrado
del df_fatal

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Definir as categorias de crime grave
crimes_graves = [
    "HOMICIDIO DOLOSO",
    "HOMICIDIO SIMPLES (ART. 121)",
    "HOMICIDIO QUALIFICADO (ART. 121, §2O.)",
    "HOMICIDIO CULPOSO NA DIRECAO DE VEICULO AUTOMOTOR (ART. 302)",
    "LESAO CORPORAL SEGUIDA DE MORTE (ART. 129, §3O.)",
    "A.I.-HOMICIDIO SIMPLES (ART. 121)",
    "MORTE SUSPEITA"
]

# Filtrar os dados para remover "DESCONHECIDO" e valores nulos em FLAG_VITIMA_FATAL e DATA_OCORRENCIA
df_filtrado = df[df['FLAG_VITIMA_FATAL'].notna()]  # Remove valores nulos em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'] != 'DESCONHECIDO']  # Remove "DESCONHECIDO" em FLAG_VITIMA_FATAL
df_filtrado = df_filtrado[df_filtrado['DATA_OCORRENCIA'].notna()]  # Remove valores nulos em DATA_OCORRENCIA

# Filtrar para apenas os casos onde NATUREZA_APURADA está dentro dos crimes graves
df_filtrado = df_filtrado[df_filtrado['NATUREZA_APURADA'].isin(crimes_graves)]

# Filtrar para apenas os casos em que FLAG_VITIMA_FATAL é 'SIM'
df_fatal = df_filtrado[df_filtrado['FLAG_VITIMA_FATAL'].str.upper() == 'SIM'].copy()  # Usando .copy() aqui

# Usando loc para adicionar a nova coluna 'Ano' de forma segura
df_fatal.loc[:, 'Ano'] = df_fatal['DATA_OCORRENCIA'].dt.year

# Contar o número de ocorrências fatais por NATUREZA_APURADA
fatalidades_por_crime = df_fatal.groupby('NATUREZA_APURADA').size().reset_index(name='total_fatais')

# Visualizar a distribuição das fatalidades por tipo de crime (NATUREZA_APURADA) com barras horizontais
plt.figure(figsize=(14, 8))
sns.barplot(data=fatalidades_por_crime, x='total_fatais', y='NATUREZA_APURADA', color='pink')
plt.title('Número de Fatalidades por Tipo de Crime')
plt.xlabel('Total de Fatalidades')
plt.ylabel('Tipo de Crime (NATUREZA_APURADA)')
plt.grid(True)
plt.show()

# %% [markdown]
# Há alguma tendência de aumento ou diminuição nas ocorrências fatais ao longo dos **meses**?

# %% [markdown]
# ### Pergunta 9: Quais perfis demográficos (sexo, profissão, cor de pele) estão mais presentes em ocorrências fatais?

# %%
df_sem_nulos = df[df['COR_PELE'] != "DESCONHECIDO"]
df_sem_nulos['COR_PELE'].describe()
# Out:
# count       5571
# unique         6
# top       BRANCA
# freq        2956
# Name: COR_PELE, dtype: object

# %%
df_sem_nulos = df[df['SEXO_PESSOA'] != "DESCONHECIDO"]
df_sem_nulos['SEXO_PESSOA'].describe()
# Out:
# count         30493
# unique            3
# top       MASCULINO
# freq          22489
# Name: SEXO_PESSOA, dtype: object

# %%
df_sem_nulos = df[df['PROFISSAO'] != "DESCONHECIDO"]
df_sem_nulos['PROFISSAO'].describe()
# Out:
# count             11787
# unique              396
# top       APOSENTADO(A)
# freq               3384
# Name: PROFISSAO, dtype: object

# %%
df_sem_nulos = df[df['FLAG_VITIMA_FATAL'] != "DESCONHECIDO"]
df_sem_nulos['FLAG_VITIMA_FATAL'].describe()
# Out:
# count     2244
# unique       1
# top        SIM
# freq      2244
# Name: FLAG_VITIMA_FATAL, dtype: object

# %%
df['FLAG_VITIMA_FATAL'].value_counts()
# Out:
# FLAG_VITIMA_FATAL
# DESCONHECIDO    717466
# SIM               2244
# Name: count, dtype: Int64

# %% [markdown]
# O número de dados não nulos na coluna FLAG_VITIMA_FATAL é pequeno, será necessário analisar o tipo do crime para tentar encontrar a possibilidade de vítima fatal.

# %% [markdown]
# ### Pergunta 10: Existe uma faixa etária que apresenta maior probabilidade de fatalidades em determinados tipo de ocorrência?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Transformar indicador de fatalidade em binário (1 = SIM, 0 = não/Sem informação)
df['fatal'] = df['FLAG_VITIMA_FATAL'].astype(str).str.upper().eq('SIM').astype(int)

# Agrupar para calcular totais e taxa
fatalidade = (
    df
    .groupby(['FAIXA_ETARIA', 'CATEGORIA_CRIME'])['fatal']
    .agg(total_ocorrencias='count', total_fatais='sum')
    .reset_index()
)
fatalidade['fatal_rate'] = (
    fatalidade['total_fatais'] / fatalidade['total_ocorrencias']
)

# Pivot para preparar o heatmap
heatmap_data = (
    fatalidade
    .pivot(index='CATEGORIA_CRIME', columns='FAIXA_ETARIA', values='fatal_rate')
    .fillna(0)
)

# Ordem fixa das faixas etárias (ajuste conforme necessário)
ordem_faixas = ['MENOR', 'ADULTO', 'IDOSO', 'DESCONHECIDO']
heatmap_data = heatmap_data[[f for f in ordem_faixas if f in heatmap_data.columns]]

# Plot
plt.figure(figsize=(14, 10))
sns.heatmap(
    heatmap_data,
    annot=True,
    fmt=".1%",
    cmap="YlOrRd",
    linewidths=.5,
    cbar_kws={'label': 'Taxa de Fatalidade'}
)
plt.title('Heatmap de Taxa de Fatalidade por Natureza do Crime e Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Categoria do Crime')
plt.tight_layout()
plt.show()

# %% [markdown]
# Com base no heatmap da Taxa de Fatalidade por Natureza do Crime e Faixa Etária que analisamos, podemos resumir as principais conclusões de forma um pouco mais detalhada:
#
# O mapa de calor ilustra claramente como a probabilidade de uma ocorrência criminal resultar em fatalidade varia significativamente dependendo da Natureza do Crime e da Faixa Etária das pessoas envolvidas.
#
# Observa-se que as categorias de crime contra o Patrimônio e contra a Administração Pública exibem as taxas de fatalidade mais elevadas. Dentro dessas categorias, as faixas etárias Adulto e Menor (para crimes Patrimoniais) parecem ser particularmente vulneráveis a desfechos fatais em ocorrências registradas. As taxas de fatalidade podem atingir valores muito altos em combinações específicas, como 100% para Administração Pública envolvendo Adultos, 91.9% para Patrimonial envolvendo Menores e 73.8% para Patrimonial envolvendo Adultos, indicando um risco considerável nestes cenários.
#
# Em contraste, outras categorias de crimes apresentadas no heatmap, como Ambiental, Imprensa/Honra e Propriedade Imaterial, mostram taxas de fatalidade muito baixas ou inexistentes nas faixas etárias consideradas.
#
# Em suma, a análise visual através do heatmap aponta para uma distribuição desigual das fatalidades, com uma concentração de maior risco em crimes violentos ou contra o patrimônio, afetando de maneira mais proeminente as populações adulta e menor em certos contextos.

# %%
categoria_desejada = 'Administração Pública'
faixa_etaria_desejada = 'ADULTO'

if 'CATEGORIA_CRIME' not in df.columns or 'FAIXA_ETARIA' not in df.columns or 'FLAG_VITIMA_FATAL' not in df.columns:
    print("Erro: Colunas necessárias não encontradas no DataFrame: 'CATEGORIA_CRIME', 'FAIXA_ETARIA' ou 'FLAG_VITIMA_FATAL'.")
else:
    # Filtrar para a categoria e faixa etária específica
    df_filtro = df[
        (df['CATEGORIA_CRIME'] == categoria_desejada) &
        (df['FAIXA_ETARIA'] == faixa_etaria_desejada)
    ].copy() # Usar .copy() para evitar SettingWithCopyWarning

    # Contar o total de ocorrências neste grupo específico
    total_ocorrencias_grupo = df_filtro.shape[0]

    # Contar as ocorrências fatais neste grupo específico
    # Garantir que a comparação com 'SIM' seja case-insensitive e lide com NaNs
    fatal_ocorrencias_grupo = df_filtro[
        df_filtro['FLAG_VITIMA_FATAL'].astype(str).str.upper() == 'SIM'
    ].shape[0]

    # Calcular a taxa de fatalidade para o grupo
    taxa_fatalidade_grupo = (fatal_ocorrencias_grupo / total_ocorrencias_grupo) if total_ocorrencias_grupo > 0 else 0

    print(f"--- Análise para Categoria: '{categoria_desejada}' e Faixa Etária: '{faixa_etaria_desejada}' ---")
    print(f"Total de ocorrências neste grupo: {total_ocorrencias_grupo}")
    print(f"Ocorrências fatais neste grupo: {fatal_ocorrencias_grupo}")
    print(f"Taxa de fatalidade neste grupo: {taxa_fatalidade_grupo:.1%}") # Formata como porcentagem


    # Opcional: Mostrar a contagem total e fatal para a categoria em geral (como no seu outro output)
    print(f"\n--- Comparação com a Categoria Geral: '{categoria_desejada}' ---")
    total_ocorrencias_categoria = df[df['CATEGORIA_CRIME'] == categoria_desejada].shape[0]
    fatal_ocorrencias_categoria = df[
        (df['CATEGORIA_CRIME'] == categoria_desejada) &
        (df['FLAG_VITIMA_FATAL'].astype(str).str.upper() == 'SIM')
    ].shape[0]
    print(f"Total de ocorrências na categoria '{categoria_desejada}': {total_ocorrencias_categoria}")
    print(f"Total de ocorrências fatais na categoria '{categoria_desejada}': {fatal_ocorrencias_categoria}")
# Out:
# --- Análise para Categoria: 'Administração Pública' e Faixa Etária: 'ADULTO' ---
# Total de ocorrências neste grupo: 61
# Ocorrências fatais neste grupo: 61
# Taxa de fatalidade neste grupo: 100.0%
#
# --- Comparação com a Categoria Geral: 'Administração Pública' ---
# Total de ocorrências na categoria 'Administração Pública': 4917
# Total de ocorrências fatais na categoria 'Administração Pública': 108

# %% [markdown]
# Exemplo desse onde temos somente uma ocrrencia de adulto na Administração Pública com fatalidade

# %% [markdown]
# ### Pergunta 11: Qual é o município com mais ocorrências registradas em 2022 em valores absolutos e relativos a população do município?

# %% [markdown]
# Primerio vamos usar um CSV por fora para descobrir a população das cidades de São Paulo em 2022, encontramos um banco de dados que contem a estimativa da população em SP em https://repositorio.seade.gov.br/dataset/populacao-residente-estado-de-sao-paulo

# %%
df_populacao = pd.read_csv("/content/drive/MyDrive/estimativa_pop_indicadores_virgulas.csv", delimiter=",")

# %%
# Verificando se a coluna 'NOME_CIDADE' existe no DataFrame principal
if 'NOME_CIDADE' not in df.columns:
    print("Erro: Coluna 'NOME_CIDADE' não encontrada no DataFrame 'df'. Certifique-se de que o pré-processamento foi feito.")
else:
    # Contar ocorrências por nome de cidade
    contagem_crimes_por_municipio = df['NOME_CIDADE'].value_counts().reset_index()
    contagem_crimes_por_municipio.columns = ['municipio', 'total_ocorrencias']

    # Identificar município com mais ocorrências absolutas
    # Assume que o value_counts() já ordena do maior para o menor
    municipio_mais_ocorrencias_absolutas = contagem_crimes_por_municipio.iloc[0]

    # Opcional: Visualizar os Top 10 municípios por contagem absoluta
    top_10_absoluto = contagem_crimes_por_municipio.head(10).sort_values(by='total_ocorrencias')

    plt.figure(figsize=(12, 6))
    bars_abs = plt.barh(top_10_absoluto['municipio'], top_10_absoluto['total_ocorrencias'], color='teal')
    plt.xlabel('Número de Ocorrências')
    plt.ylabel('Município')
    plt.title('Top 10 Municípios com Mais Ocorrências (Absoluto)')
    # Adicionar rótulos de valor nas barras
    for bar in bars_abs:
        width = bar.get_width()
        plt.text(width + max(top_10_absoluto['total_ocorrencias']) * 0.01, bar.get_y() + bar.get_height()/2,
                 f'{int(width):,}', va='center', ha='left')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Este trecho analisamos a contagem total de ocorrências criminais para cada município no dataset de 2022. O código identifica automaticamente o município com o maior número absoluto de registros.
#
# O gráfico de barras horizontais "Top 10 Municípios com Mais Ocorrências (Absoluto)" visualiza os 10 municípios com as maiores contagens. Ele permite ver rapidamente quais localidades tiveram o maior volume de ocorrências registradas, com o município no topo da lista sendo aquele com o maior número total de crimes neste período, sem considerar o tamanho de sua população.

# %%
df_populacao_2022 = df_populacao[df_populacao['ano'] == 2022].copy()

# Selecionar e renomear colunas essenciais ('nome_mun' e 'populacao')
# O código falhará se estas colunas não existirem
df_populacao_2022 = df_populacao_2022[['nome_mun', 'populacao']]
df_populacao_2022.columns = ['municipio', 'populacao']

# --- Calcular e analisar a taxa de criminalidade ---
# Assume que contagem_crimes_por_municipio do passo anterior está disponível

# Mesclar contagem de crimes com dados de população
# Usa left merge para manter todos os municípios do df de crimes
df_crimes_populacao = pd.merge(
    contagem_crimes_por_municipio,
    df_populacao_2022,
    on='municipio',
    how='left'
)

# Calcular a taxa de criminalidade por 100.000 habitantes
# Lida com população zero ou nula, resultando em taxa 0
df_crimes_populacao['crime_rate_per_100k'] = df_crimes_populacao.apply(
    lambda row: (row['total_ocorrencias'] / row['populacao']) * 100000 if pd.notna(row['populacao']) and row['populacao'] > 0 else 0,
    axis=1
)

# Filtrar municípios com população válida para o ranking da taxa
# Exclui municípios sem população conhecida
df_crimes_populacao_valid = df_crimes_populacao[
     df_crimes_populacao['populacao'].notna() & (df_crimes_populacao['populacao'] > 0)
].copy().reset_index(drop=True)


# Classificar por taxa de criminalidade em ordem decrescente e encontrar o município com a maior taxa
# O código falhará se df_crimes_populacao_valid estiver vazio
municipio_maior_taxa_criminalidade = df_crimes_populacao_valid.sort_values(
    by='crime_rate_per_100k',
    ascending=False
).iloc[0]

# --- Visualização dos Top 10 Municípios por Taxa ---
# O código falhará se df_crimes_populacao_valid tiver menos de 10 linhas
top_10_rate = df_crimes_populacao_valid.sort_values(by='crime_rate_per_100k', ascending=False).head(10).sort_values(by='crime_rate_per_100k')

plt.figure(figsize=(12, 6))
bars_rate = plt.barh(top_10_rate['municipio'], top_10_rate['crime_rate_per_100k'], color='purple')
plt.xlabel('Taxa de Criminalidade (por 100 mil hab.)')
plt.ylabel('Município')
plt.title('Top 10 Municípios com Maior Taxa de Criminalidade')
# Adicionar rótulos de valor nas barras
for bar in bars_rate:
    width = bar.get_width()
    plt.text(width + max(top_10_rate['crime_rate_per_100k']) * 0.01, bar.get_y() + bar.get_height()/2,
             f'{width:.2f}', va='center', ha='left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Fizemos um analise da taxa de criminalidade por 100 mil habitantes complementa a contagem absoluta, oferecendo uma visão mais justa da incidência criminal ao considerar o tamanho da população de cada município. Esta abordagem permite comparar a segurança pública entre localidades de diferentes portes de forma mais precisa.
#
# O código realiza o cálculo dessa taxa combinando os dados de ocorrências com informações populacionais. O gráfico gerado, "Top 10 Municípios com Maior Taxa de Criminalidade", visualiza os municípios classificados por essa métrica.
#
# A interpretação do gráfico destaca onde o crime é mais prevalente por habitante. O município no topo da lista é aquele que registrou a maior taxa de crimes proporcionalmente à sua população, o que pode apresentar um cenário de risco diferente daquele mostrado pela simples contagem total de ocorrências.

# %%
df.shape[0]
# Out:
# 719710

# %% [markdown]
# ### Pergunta 12: Qual é o bairro e logradouro com mais ocorrências registradas em 2022 em valores absolutos?

# %% [markdown]
# Para utilizar o método describe(), é necessário remover os dados desconhecidos da análise, considerando que a aparição de "DESCONHECIDO" era a mais frequente.

# %%
df_sem_nulos = df[df['LOGRADOURO'] != "DESCONHECIDO"]
df_sem_nulos['LOGRADOURO'].describe()
# Out:
# count               666239
# unique               76799
# top       AVENIDA PAULISTA
# freq                  5206
# Name: LOGRADOURO, dtype: object

# %% [markdown]
# Para essa análise, foi considerada a coluna "LOGRADOURO". Como existem muitas ruas distintas registradas, e muitas delas possuem um número muito baixo ou dados desconhecidos, optou-se por filtrar apenas os 10 logradouros com o maior número de registros para tornar a análise mais objetiva.

# %%
# Contar os logradouros mais frequentes
top_logradouros = df_sem_nulos['LOGRADOURO'].value_counts().head(10)

# Criar tabela com os resultados
tabela_logradouros = pd.DataFrame({
    'Logradouro': top_logradouros.index,
    'Número de Ocorrências': top_logradouros.values
})

# Estilizar a tabela para exibição
styled_table = (
    tabela_logradouros.style
    .set_caption("Top 10 ruas com maior número crimes em SP (2022)")
    .set_table_styles([
        {'selector': 'caption',
         'props': [
             ('caption-side', 'top'),
             ('font-size', '16px'),
             ('font-weight', 'bold'),
             ('background-color', '#800000'),
             ('color', 'white'),
             ('padding', '8px')
         ]},
        {'selector': 'th', 'props': [('text-align', 'left')]},
    ])
    .set_properties(**{
        'font-family': 'Arial',
        'font-size': '14px'
    })
    # Alinhar a primeira coluna (Logradouro) à esquerda
    .set_properties(subset=['Logradouro'], **{'text-align': 'left'})
    # Alinhar a segunda coluna (Número de Ocorrências) à direita
    .set_properties(subset=['Número de Ocorrências'], **{'text-align': 'right'})
)
styled_table
# Out:
# <style type="text/css">
# #T_4c815 caption {
#   caption-side: top;
#   font-size: 16px;
#   font-weight: bold;
#   background-color: #800000;
#   color: white;
#   padding: 8px;
# }
# #T_4c815 th {
#   text-align: left;
# }
# #T_4c815_row0_col0, #T_4c815_row1_col0, #T_4c815_row2_col0, #T_4c815_row3_col0, #T_4c815_row4_col0, #T_4c815_row5_col0, #T_4c815_row6_col0, #T_4c815_row7_col0, #T_4c815_row8_col0, #T_4c815_row9_col0 {
#   font-family: Arial;
#   font-size: 14px;
#   text-align: left;
# }
# #T_4c815_row0_col1, #T_4c815_row1_col1, #T_4c815_row2_col1, #T_4c815_row3_col1, #T_4c815_row4_col1, #T_4c815_row5_col1, #T_4c815_row6_col1, #T_4c815_row7_col1, #T_4c815_row8_col1, #T_4c815_row9_col1 {
#   font-family: Arial;
#   font-size: 14px;
#   text-align: right;
# }
# </style>
# <table id="T_4c815" class="dataframe">
#   <caption>Top 10 ruas com maior número crimes em SP (2022)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c815_level0_col0" class="col_heading level0 col0" >Logradouro</th>
#       <th id="T_4c815_level0_col1" class="col_heading level0 col1" >Número de Ocorrências</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c815_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c815_row0_col0" class="data row0 col0" >AVENIDA PAULISTA</td>
#       <td id="T_4c815_row0_col1" class="data row0 col1" >5206</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c815_row1_col0" class="data row1 col0" >AVENIDA DO ESTADO</td>
#       <td id="T_4c815_row1_col1" class="data row1 col1" >3179</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c815_row2_col0" class="data row2 col0" >AVENIDA CRUZEIRO DO SUL</td>
#       <td id="T_4c815_row2_col1" class="data row2 col1" >2834</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c815_row3_col0" class="data row3 col0" >RUA DOS LAVRADORES</td>
#       <td id="T_4c815_row3_col1" class="data row3 col1" >2525</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c815_row4_col0" class="data row4 col0" >RUA AUGUSTA</td>
#       <td id="T_4c815_row4_col1" class="data row4 col1" >2192</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c815_row5_col0" class="data row5 col0" >PRACA DA REPUBLICA</td>
#       <td id="T_4c815_row5_col1" class="data row5 col1" >1871</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c815_row6_col0" class="data row6 col0" >PRACA DA LUZ</td>
#       <td id="T_4c815_row6_col1" class="data row6 col1" >1639</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c815_row7_col0" class="data row7 col0" >RUA DA CONSOLACAO</td>
#       <td id="T_4c815_row7_col1" class="data row7 col1" >1618</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4c815_row8_col0" class="data row8 col0" >AVENIDA BRIGADEIRO FARIA LIMA</td>
#       <td id="T_4c815_row8_col1" class="data row8 col1" >1515</td>
#     </tr>
#     <tr>
#       <th id="T_4c815_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4c815_row9_col0" class="data row9 col0" >AVENIDA PRESIDENTE CASTELO BRANCO</td>
#       <td id="T_4c815_row9_col1" class="data row9 col1" >1449</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# A Avenida Paulista lidera o ranking, com 5.130 ocorrências, sendo de longe o logradouro com maior volume de registros. Isso pode ser atribuído à sua localização central, grande fluxo de pessoas e intensa atividade comercial e cultural.

# %%
df_sem_nulos = df[df['BAIRRO'] != "DESCONHECIDO"]
df_sem_nulos['BAIRRO'].describe()
# Out:
# count     680623
# unique     15622
# top       CENTRO
# freq       37794
# Name: BAIRRO, dtype: object

# %% [markdown]
# Assim como nos logradouros, também foram selecionados os 10 bairros com maior número de ocorrências para uma visualização mais clara.

# %%
# Contar os logradouros mais frequentes
top_bairros = df_sem_nulos['BAIRRO'].value_counts().head(10)

# Criar tabela com os resultados
tabela_bairros = pd.DataFrame({
    'Bairro': top_bairros.index,
    'Número de Ocorrências': top_bairros.values
})

# Estilizar a tabela para exibição
styled_table = (
    tabela_bairros.style
    .set_caption("Top 10 bairros com maior número crimes em SP (2022)")
    .set_table_styles([
        {'selector': 'caption',
         'props': [
             ('caption-side', 'top'),
             ('font-size', '16px'),
             ('font-weight', 'bold'),
             ('background-color', '#DC143C'),
             ('color', 'white'),
             ('padding', '8px')
         ]},
        {'selector': 'th', 'props': [('text-align', 'left')]},
    ])
    .set_properties(**{
        'font-family': 'Arial',
        'font-size': '14px'
    })
    # Alinhar a primeira coluna (Bairro) à esquerda
    .set_properties(subset=['Bairro'], **{'text-align': 'left'})
    # Alinhar a segunda coluna (Número de Ocorrências) à direita
    .set_properties(subset=['Número de Ocorrências'], **{'text-align': 'right'})
)
styled_table
# Out:
# <style type="text/css">
# #T_9cc1b caption {
#   caption-side: top;
#   font-size: 16px;
#   font-weight: bold;
#   background-color: #DC143C;
#   color: white;
#   padding: 8px;
# }
# #T_9cc1b th {
#   text-align: left;
# }
# #T_9cc1b_row0_col0, #T_9cc1b_row1_col0, #T_9cc1b_row2_col0, #T_9cc1b_row3_col0, #T_9cc1b_row4_col0, #T_9cc1b_row5_col0, #T_9cc1b_row6_col0, #T_9cc1b_row7_col0, #T_9cc1b_row8_col0, #T_9cc1b_row9_col0 {
#   font-family: Arial;
#   font-size: 14px;
#   text-align: left;
# }
# #T_9cc1b_row0_col1, #T_9cc1b_row1_col1, #T_9cc1b_row2_col1, #T_9cc1b_row3_col1, #T_9cc1b_row4_col1, #T_9cc1b_row5_col1, #T_9cc1b_row6_col1, #T_9cc1b_row7_col1, #T_9cc1b_row8_col1, #T_9cc1b_row9_col1 {
#   font-family: Arial;
#   font-size: 14px;
#   text-align: right;
# }
# </style>
# <table id="T_9cc1b" class="dataframe">
#   <caption>Top 10 bairros com maior número crimes em SP (2022)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cc1b_level0_col0" class="col_heading level0 col0" >Bairro</th>
#       <th id="T_9cc1b_level0_col1" class="col_heading level0 col1" >Número de Ocorrências</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cc1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cc1b_row0_col0" class="data row0 col0" >CENTRO</td>
#       <td id="T_9cc1b_row0_col1" class="data row0 col1" >37794</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9cc1b_row1_col0" class="data row1 col0" >REPUBLICA</td>
#       <td id="T_9cc1b_row1_col1" class="data row1 col1" >10240</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9cc1b_row2_col0" class="data row2 col0" >BELA VISTA</td>
#       <td id="T_9cc1b_row2_col1" class="data row2 col1" >7369</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9cc1b_row3_col0" class="data row3 col0" >RURAL</td>
#       <td id="T_9cc1b_row3_col1" class="data row3 col1" >7117</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9cc1b_row4_col0" class="data row4 col0" >CONSOLACAO</td>
#       <td id="T_9cc1b_row4_col1" class="data row4 col1" >7110</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9cc1b_row5_col0" class="data row5 col0" >BRAS</td>
#       <td id="T_9cc1b_row5_col1" class="data row5 col1" >6152</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9cc1b_row6_col0" class="data row6 col0" >PINHEIROS</td>
#       <td id="T_9cc1b_row6_col1" class="data row6 col1" >6104</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9cc1b_row7_col0" class="data row7 col0" >SE</td>
#       <td id="T_9cc1b_row7_col1" class="data row7 col1" >5985</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9cc1b_row8_col0" class="data row8 col0" >TATUAPE</td>
#       <td id="T_9cc1b_row8_col1" class="data row8 col1" >5508</td>
#     </tr>
#     <tr>
#       <th id="T_9cc1b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9cc1b_row9_col0" class="data row9 col0" >VILA MARIANA</td>
#       <td id="T_9cc1b_row9_col1" class="data row9 col1" >5432</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# O Centro lidera com ampla vantagem, totalizando 29.008 ocorrências, o que indica uma alta densidade criminal na região central da cidade. Esse número expressivo pode ser explicado pela concentração de serviços, transporte público, comércio e população flutuante intensa, fatores que geralmente contribuem para a ocorrência de diversos tipos de crimes.

# %% [markdown]
# ### Pergunta 13: Quais foram os anos em que ocorreram mais crimes que só foram registrados em 2022, desconsiderando os crimes efetivamente cometidos em 2022

# %% [markdown]
# Se desconsiderarmos os valores do ano de 2022, podemos observar com mais clareza quais crimes ocorreram antes desse ano (em escala logarítmica), mas que só foram registrados em 2022.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criar uma cópia do DataFrame original
df_sem_2022 = df.copy()

# Extrair o ano da coluna de data
df_sem_2022['Ano'] = df_sem_2022['DATA_OCORRENCIA'].dt.year

# Filtrar os dados para excluir o ano de 2022
df_sem_2022 = df_sem_2022[df_sem_2022['Ano'] != 2022]

# Contar o número de ocorrências por ano
contagem_anos = df_sem_2022['Ano'].value_counts()

# Selecionar os 15 anos com mais ocorrências e ordenar do menor para o maior valor
top_15 = contagem_anos.nlargest(15).sort_values()

# Criar o gráfico de barras horizontal com escala logarítmica
plt.figure(figsize=(10, 8))
plt.barh(top_15.index.astype(str), top_15.values)
plt.xscale('log')  # Aplicando escala logarítmica no eixo X
plt.xlabel('Número de Ocorrências (Escala Logarítmica)')
plt.ylabel('Ano')
plt.title('Top 15 Anos com Mais Ocorrências (Excluindo 2022)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pegunta 14: Quais foram os meses nos quais mais houveram ocorrências registradas em 2022?

# %%
df["DATA_OCORRENCIA"].dt.month.describe()
# Out:
# count    719710.000000
# mean          6.730840
# std           3.464101
# min           1.000000
# 25%           4.000000
# 50%           7.000000
# 75%          10.000000
# max          12.000000
# Name: DATA_OCORRENCIA, dtype: float64

# %%
import matplotlib.pyplot as plt

# Extrair o mês da coluna de data
df_meses['Mes'] = df['DATA_OCORRENCIA'].dt.month

# Contar o número de ocorrências por mês
contagem_meses = df_meses['Mes'].value_counts().sort_index()

# Mapear números dos meses para nomes
nomes_meses = {
    1: 'Janeiro', 2: 'Fevereiro', 3: 'Março', 4: 'Abril',
    5: 'Maio', 6: 'Junho', 7: 'Julho', 8: 'Agosto',
    9: 'Setembro', 10: 'Outubro', 11: 'Novembro', 12: 'Dezembro'
}
contagem_meses.index = contagem_meses.index.map(nomes_meses)
mes_mais_ocorrencias = contagem_meses.idxmax()
cores = ['purple' if mes == mes_mais_ocorrencias else 'plum' for mes in contagem_meses.index]

# Criar o gráfico
plt.figure(figsize=(10, 6))
bars = plt.barh(contagem_meses.index, contagem_meses.values, color=cores, height=0.6)
plt.xlim(0, max(contagem_meses.values) * 1.2)
plt.xlabel('Número de Ocorrências')
plt.ylabel('Mês')
plt.title('Ocorrências por Mês')

# Adicionar valor na barra com maior ocorrência
for bar in bars:
    width = bar.get_width()
    cor = bar.get_facecolor()
    if cor == (0.5019607843137255, 0.0, 0.5019607843137255, 1.0):
      plt.text(width + max(contagem_meses.values) * 0.01,
              bar.get_y() + bar.get_height() / 2,
              f'{int(width):,}'.replace(',', '.'),
              va='center', ha='left', fontsize=13)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-264-1318779ab3af> in <cell line: 0>()
#       2
#       3 # Extrair o mês da coluna de data
# ----> 4 df_meses['Mes'] = df['DATA_OCORRENCIA'].dt.month
#       5
#       6 # Contar o número de ocorrências por mês
#
# NameError: name 'df_meses' is not defined

# %% [markdown]
# O gráfico mostra o número de ocorrências registradas mês a mês. A partir dele, dá para ver que outubro foi o mês com mais ocorrências registradas em 2022, com aproximadamente 48.752 casos. Novembro e dezembro também tiveram números altos, ficando logo atrás de outubro.
# No geral, o segundo semestre (de julho a dezembro) concentra a maioria dos meses com números mais elevados de ocorrências. Já meses como julho e fevereiro aparecem com quantidades menores em comparação.

# %% [markdown]
# ### Pergunta 15: Quais foram os dias da semana nos quais mais houveram ocorrências registradas em 2022?

# %% [markdown]
# Será utilizado o describe() no atributo que foi criado pelo grupo que é referente ao dia da semana em que ocorreu o crime.

# %%
df["DIA_OCORRENCIA"].describe()

# %%
import matplotlib.pyplot as plt

# Contar ocorrências por dia da semana
contagem_dias = df_dias['DIA_OCORRENCIA'].value_counts()

# Ordenar do menor para o maior
contagem_dias = contagem_dias.sort_values()

# Obter o dia com maior número de ocorrências
dia_top = contagem_dias.idxmax()
cores = ['pink' if dia != dia_top else 'deeppink' for dia in contagem_dias.index]

# Criar gráfico horizontal
plt.figure(figsize=(10, 6))
bars = plt.barh(contagem_dias.index, contagem_dias.values, color=cores, height=0.6)
plt.xlim(0, max(contagem_dias.values) * 1.2)
plt.xlabel('Número de Ocorrências')
plt.ylabel('Dia da Semana')
plt.title('Ocorrências por Dia da Semana')

# Adicionar rótulos ao lado de cada barra
for bar in bars:
    largura = bar.get_width()
    plt.text(largura + max(contagem_dias.values) * 0.01,
             bar.get_y() + bar.get_height()/2,
             f'{int(largura):,}'.replace(',', '.'),
             va='top', ha='left', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# O gráfico mostra a quantidade de ocorrências registradas em cada dia da semana. Nele, dá para perceber que sexta-feira foi o dia com o maior número de registros em 2022, com cerca de 74.310 ocorrências. Sábado, domingo e quarta-feira vêm logo em seguida, também com números bem próximos de sexta-feira.
# A segunda-feira teve o menor número de ocorrências registradas, ficando abaixo dos demais dias. Portanto, os dias com mais ocorrências foram ***sexta-feira, sábado, domingo e quarta-feira.***

# %% [markdown]
# ### Pergunta 16: Quais foram os horários nos quais mais houveram ocorrências registradas em 2022?

# %%
df['HORA_OCORRENCIA'].describe()

# %% [markdown]
# Como o formato dos dados não estão muito legíveis, será criado uma cópia do df nos quais eles passam do formato 00:00:00 para 00h00min para maior clareza, que será utilizado para a visualização dos dados.

# %%
# Copiando as colunas relevantes
df_horas = df[['HORA_OCORRENCIA', 'DIA_OCORRENCIA']].copy()

# Remove milissegundos se existirem e converte para datetime, depois formata para '20h00min'
df_horas['HORA_OCORRENCIA'] = pd.to_datetime(
    df_horas['HORA_OCORRENCIA'].astype(str).str.slice(0, 8), format='%H:%M:%S'
).dt.strftime('%Hh%Mmin')

# %% [markdown]
# Como a variedade de horários é muito grande, a visualização será feita em cima dos 10 horários nos quais mais aconteceram ocorrências.

# %%
import matplotlib.pyplot as plt

contagem_top10 = df_horas['HORA_OCORRENCIA'].value_counts().nlargest(10).sort_index()

plt.figure(figsize=(10, 6))
plt.barh(contagem_top10.index, contagem_top10.values, color='plum')
plt.ylabel('Hora do Dia')
plt.xlabel('Número de Ocorrências')
plt.title('Top 10 Horários com Mais Ocorrências')
plt.grid(axis='x', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(contagem_top10.index, contagem_top10.values, marker='o', linestyle='-', color='purple')
plt.xlabel('Hora do Dia')
plt.ylabel('Número de Ocorrências')
plt.title('Top 10 Horários com Mais Ocorrências')
plt.xticks(rotation=45)  # Rotaciona os horários no eixo X para melhor visualização
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
#  No gráfico de linha com marcadores, observamos que os horários com mais registros concentram-se principalmente no início da noite, com destaque para **20h00min, 21h00min e 22h00min**, que apresentam os maiores picos de ocorrência.
#
#   Essa visualização mostra uma tendência ascendente a partir do início da noite, seguida por uma leve queda após as 23h00min, o que pode indicar que esses eventos estão fortemente ligados à *rotina* noturna da população.

# %% [markdown]
# ### Pergunta 17: Quais são os dias da semana e horários específicos com maior número de ocorrências?

# %% [markdown]
# Como o formato dos dados não estão muito legíveis, nessa seção também será criado uma cópia do df nos quais eles passam do formato 00:00:00 para 00h00min para maior clareza, que será utilizado para a visualização dos dados.

# %%
# Copiando as colunas relevantes
df_horas = df[['HORA_OCORRENCIA', 'DIA_OCORRENCIA']].copy()

# Remove milissegundos se existirem e converte para datetime, depois formata para '20h00min'
df_horas['HORA_OCORRENCIA'] = pd.to_datetime(
    df_horas['HORA_OCORRENCIA'].astype(str).str.slice(0, 8), format='%H:%M:%S'
).dt.strftime('%Hh%Mmin')

# %%
import seaborn as sns

top10_horarios = contagem_top10.index
df_top10 = df_horas[df_horas['HORA_OCORRENCIA'].isin(top10_horarios)]

heatmap_data = pd.crosstab(df_top10['HORA_OCORRENCIA'], df_top10['DIA_OCORRENCIA'])

dias_ordenados = ['SEGUNDA-FEIRA', 'TERÇA-FEIRA', 'QUARTA-FEIRA',
                  'QUINTA-FEIRA', 'SEXTA-FEIRA', 'SÁBADO', 'DOMINGO']
heatmap_data = heatmap_data[dias_ordenados] if set(dias_ordenados).issubset(heatmap_data.columns) else heatmap_data

plt.figure(figsize=(10, 8))
sns.heatmap(
    heatmap_data,
    cmap='RdPu',  # Paleta
    linewidths=0.5,
    annot=True,
    fmt='d',
    cbar_kws={'label': 'Ocorrências'}
)
plt.xlabel('Dia da Semana')
plt.ylabel('Hora do Dia')
plt.title('Heatmap: Top 10 Horários por Dia da Semana')
plt.tight_layout()
plt.show()

# %% [markdown]
# Já o heatmap "Top 10 Horários por Dia da Semana" complementa essa análise ao apresentar como essas ocorrências se distribuem ao longo da semana. Percebe-se que, em geral, os horários **entre 19h00min e 22h00min** mantêm alta frequência em quase **todos os dias**, com um leve aumento às quintas e sextas-feiras. Isso pode sugerir maior movimentação social nesses dias, contribuindo para o aumento das ocorrências. Em contrapartida, horários como *00h30min e 18h00min possuem menor intensidade*, embora ainda relevantes.
